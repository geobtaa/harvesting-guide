# %% [markdown]
# ## Purpose:
#
# To harvest metadata from XML files in the MODS metadata format.
# Uses the Beautiful Soup XML features: https://beautiful-soup-4.readthedocs.io/en/latest/index.html#xml
#
#
# ### Files
#
# x.csv
# 	A local csv file stores existing urls that are prepared to parse.
# output_yyyymmdd.csv
# 	The output file after parsing and it is followed by the action date.
#
#
# ### Developers
# ----------
# Original created on xxxxx
# Created by Karen Majewicz  @karenmajewicz
#
# Updated December 14, 2020
# Updated by Ziying Cheng  @Ziiiiing
#
# Updated May 26, 2021 for Illinois Geospatial Data Clearinghouse
#
# Updated June 2, 2021 for MSU Digital Library
#
# '''

# %%
import csv
import time
import urllib.request
from bs4 import BeautifulSoup
import json
import lxml

# extract exising urls from local csv file
urls = []

with open('06d-01.csv') as fr:
    reader = csv.reader(fr)  # reader object
    for row in reader:
        urls.append(row)


# store parsed elements for all urls
parseElements = []

for url in urls:

    page = urllib.request.urlopen(url[0]).read()
    soup = BeautifulSoup(page, "xml")
        
        
#     url_link = requests.get(url)
#     file = bs.BeautifulSoup(url_link.text, "lxml")
    print(f'Parsing {url[0]}')
        

    #TITLE - works
    titleField = soup.find('mods:title')
    try:
        title = titleField.text.strip()
    except:
        title = 'undefined'

    
    #NOTE - works
    descriptionField = soup.find('mods:note')
    try:
        description = descriptionField.text.strip()
    except:
        description = 'undefined'

    
    #creator - works
    creatorField = soup.find('mods:namePart')
    try:
        creator = creatorField.text.strip()
    except:
        creator = 'undefined'
        
    #publisher - works
    publisherField = soup.find('mods:publisher')
    try:
        publisher = publisherField.text.strip()
    except:
        publisher = 'undefined'

    
    #date - works
    dateField = soup.find('mods:dateIssued')
    try:
        date = dateField.text.strip()
    except:
        date = 'undefined'

    
    #coordinates - works
    bBoxField = soup.find('mods:coordinates')
    try:
        bBox = bBoxField.text.strip()
    except:
        bBox = 'undefined'
 
    
    #place name - works
    placeNameField = soup.find('mods:geographic')
    try:
        placeName = placeNameField.text.strip()
    except:
        placeName = 'undefined'
    
    #scale - works
    scaleField = soup.find('mods:scale')
    try:
        scale = scaleField.text.strip()
    except:
        scale = 'undefined'
    
    #library catalog record - works
    libField = soup.find('mods:url',{"note": "catalog_record"})
    try:
        lib = libField.text.strip()
    except:
        lib = 'undefined'
        
    #ARK - works
    arkField = soup.find('mods:url',{"note": "ark"})
    try:
        ark = arkField.text.strip()
    except:
        ark = 'undefined'
        
    #Rights - works
    rightsField = soup.find('mods:accessCondition')
    try:
        rights = rightsField.text.strip()
    except:
        rights = 'undefined'
        
        
        
    language = 'eng'
    provider = 'University of Michigan'
    resourceClass = 'Maps'
#     resourceType = 'Cadastral maps'
#     subject = 'Real Property|Landowners'
    accessRights = 'Public'
    memberOf = '06d-01'
    fileType = 'TIFF'
    code = '06d-01'
    status = 'Active'
    accrualMethod = 'MODS'
    dateAccessioned = '2021-06-02'
    
    
        

   
                
#     #combine the scraped information
    parseElements.append([url,title,description,language,creator,publisher,provider,resourceClass,date,bBox,placeName,scale,fileType,lib,ark,memberOf,code,accessRights,status,dateAccessioned])

# # generate action date with format YYYYMMDD    
    
actionDate = time.strftime('%Y%m%d')

# # write outputs to local csv file
with open(f'output_06d-01_{actionDate}.csv', 'w') as fw:
    fields = ['link','Title','Description','Language','Creator','Publisher','Provider','Subject',
              'Date Issued','Bounding Box','Spatial Coverage','Scale','Format','Documentation','Identifier','Member Of','Code',
              'Access Rights','Status','Date Accessioned']

    writer = csv.writer(fw)
    writer.writerow(fields)           # fieldnames
    writer.writerows(parseElements)   # elements

    print('#### Job done ####')
# Out:
# Parsing https://d.lib.msu.edu/maps/1/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/2/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/3/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/4/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/5/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/6/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/7/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/8/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/9/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/10/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/11/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/12/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/13/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/14/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/15/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/16/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/17/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/18/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/19/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/20/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/21/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/23/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/24/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/25/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/26/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/27/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/28/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/29/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/30/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/31/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/32/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/33/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/34/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/35/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/36/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/37/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/38/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/39/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/40/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/41/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/42/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/43/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/44/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/45/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/46/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/47/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/48/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/49/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/50/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/51/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/52/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/53/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/54/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/55/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/56/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/57/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/58/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/59/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/60/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/61/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/62/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/63/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/64/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/65/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/66/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/67/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/68/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/69/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/70/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/71/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/72/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/73/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/74/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/75/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/76/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/77/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/78/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/79/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/80/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/81/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/82/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/83/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/84/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/85/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/86/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/87/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/88/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/89/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/90/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/91/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/92/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/93/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/94/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/95/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/96/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/97/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/98/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/99/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/100/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/101/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/102/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/103/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/104/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/105/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/106/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/107/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/108/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/109/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/110/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/111/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/112/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/113/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/114/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/115/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/116/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/117/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/118/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/119/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/120/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/121/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/122/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/123/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/124/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/125/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/126/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/127/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/128/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/129/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/130/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/131/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/132/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/133/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/134/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/135/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/136/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/137/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/138/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/139/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/140/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/141/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/142/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/143/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/144/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/145/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/146/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/147/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/148/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/149/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/150/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/151/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/152/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/153/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/154/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/155/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/156/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/157/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/158/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/159/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/160/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/161/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/162/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/163/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/164/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/165/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/166/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/167/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/168/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/169/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/170/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/171/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/172/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/173/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/174/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/175/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/176/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/177/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/178/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/179/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/180/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/181/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/182/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/183/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/184/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/185/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/186/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/187/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/188/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/189/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/190/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/191/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/192/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/193/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/194/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/195/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/196/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/197/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/198/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/199/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/200/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/201/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/202/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/203/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/204/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/205/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/206/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/207/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/208/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/209/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/210/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/211/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/212/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/213/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/214/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/215/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/216/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/217/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/218/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/219/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/220/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/221/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/222/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/223/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/224/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/225/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/226/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/227/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/228/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/229/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/230/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/231/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/232/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/233/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/234/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/235/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/236/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/237/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/238/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/239/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/240/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/241/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/242/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/243/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/244/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/245/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/246/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/247/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/248/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/249/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/250/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/251/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/252/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/253/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/254/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/255/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/256/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/257/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/258/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/259/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/260/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/261/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/262/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/263/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/264/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/265/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/266/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/267/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/268/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/269/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/270/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/271/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/272/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/273/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/274/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/275/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/276/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/277/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/278/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/279/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/280/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/281/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/282/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/283/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/284/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/285/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/286/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/287/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/288/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/289/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/290/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/291/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/292/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/293/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/294/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/295/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/296/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/297/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/298/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/299/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/300/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/301/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/302/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/303/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/304/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/305/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/306/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/307/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/308/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/309/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/310/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/311/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/312/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/313/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/314/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/315/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/316/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/317/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/318/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/319/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/320/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/321/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/322/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/323/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/324/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/325/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/326/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/327/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/328/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/329/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/330/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/331/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/332/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/333/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/334/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/335/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/336/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/337/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/338/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/339/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/340/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/341/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/342/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/343/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/344/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/345/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/346/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/347/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/348/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/349/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/350/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/351/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/352/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/353/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/354/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/355/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/356/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/357/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/358/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/359/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/360/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/361/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/362/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/363/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/364/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/365/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/366/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/367/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/368/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/369/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/370/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/371/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/372/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/373/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/374/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/375/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/376/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/377/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/378/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/379/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/380/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/381/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/382/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/383/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/384/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/385/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/386/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/387/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/388/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/389/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/390/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/391/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/392/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/393/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/394/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/395/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/396/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/397/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/398/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/399/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/400/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/401/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/402/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/403/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/404/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/405/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/406/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/407/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/408/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/409/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/410/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/411/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/412/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/413/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/414/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/415/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/416/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/417/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/418/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/419/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/420/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/421/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/422/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/423/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/424/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/425/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/426/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/427/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/428/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/429/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/430/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/431/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/432/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/433/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/434/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/435/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/436/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/437/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/438/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/439/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/440/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/441/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/442/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/443/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/444/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/445/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/446/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/447/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/448/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/449/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/450/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/451/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/452/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/453/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/454/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/455/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/456/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/457/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/458/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/459/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/460/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/461/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/462/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/463/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/464/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/465/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/466/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/467/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/468/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/469/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/470/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/471/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/472/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/473/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/474/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/475/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/476/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/477/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/478/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/479/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/480/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/481/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/482/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/483/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/484/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/485/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/486/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/487/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/488/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/489/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/490/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/491/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/492/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/493/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/494/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/495/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/496/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/497/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/498/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/499/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/500/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/501/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/502/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/503/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/504/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/505/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/506/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/507/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/508/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/509/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/510/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/511/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/512/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/513/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/514/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/515/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/516/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/517/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/518/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/519/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/520/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/521/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/522/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/523/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/524/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/525/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/526/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/527/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/528/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/529/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/530/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/531/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/532/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/533/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/534/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/535/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/536/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/537/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/538/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/539/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/540/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/541/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/542/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/543/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/544/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/545/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/546/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/547/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/548/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/549/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/550/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/551/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/552/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/553/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/554/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/555/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/556/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/557/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/558/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/559/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/560/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/561/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/562/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/563/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/564/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/565/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/566/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/567/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/568/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/569/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/570/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/571/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/572/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/573/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/574/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/575/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/576/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/577/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/578/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/579/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/580/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/581/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/582/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/583/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/584/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/585/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/586/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/587/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/588/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/589/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/590/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/591/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/592/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/593/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/594/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/595/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/596/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/597/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/598/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/599/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/600/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/601/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/602/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/603/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/604/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/605/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/606/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/607/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/608/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/609/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/610/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/611/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/612/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/613/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/614/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/615/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/616/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/617/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/618/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/619/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/620/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/621/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/622/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/623/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/624/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/625/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/626/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/627/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/628/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/629/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/630/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/631/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/632/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/633/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/634/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/635/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/636/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/637/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/638/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/639/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/640/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/641/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/642/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/643/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/644/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/645/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/646/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/647/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/648/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/649/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/650/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/651/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/652/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/653/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/654/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/655/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/656/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/657/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/658/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/659/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/660/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/661/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/662/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/663/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/664/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/665/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/666/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/667/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/668/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/669/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/670/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/671/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/672/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/673/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/674/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/675/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/676/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/677/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/678/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/679/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/680/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/681/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/682/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/683/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/684/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/685/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/686/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/687/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/688/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/689/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/690/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/691/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/692/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/693/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/694/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/695/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/696/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/697/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/698/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/699/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/700/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/701/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/702/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/703/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/704/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/705/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/706/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/707/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/708/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/709/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/710/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/711/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/712/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/713/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/714/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/715/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/716/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/717/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/718/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/719/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/720/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/721/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/722/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/723/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/724/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/725/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/726/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/727/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/728/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/729/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/730/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/731/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/732/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/733/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/734/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/735/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/736/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/737/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/738/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/739/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/740/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/741/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/742/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/743/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/744/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/745/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/746/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/747/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/748/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/749/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/750/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/751/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/752/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/753/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/754/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/755/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/756/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/757/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/758/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/759/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/760/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/761/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/762/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/763/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/764/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/765/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/766/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/767/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/768/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/769/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/770/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/771/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/772/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/773/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/774/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/775/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/776/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/777/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/778/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/779/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/780/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/781/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/782/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/783/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/784/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/785/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/786/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/787/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/788/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/789/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/790/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/791/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/792/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/793/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/794/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/795/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/796/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/797/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/798/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/799/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/800/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/801/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/802/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/803/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/804/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/805/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/806/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/807/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/808/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/809/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/810/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/811/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/812/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/813/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/814/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/815/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/816/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/817/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/818/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/819/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/820/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/821/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/822/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/823/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/824/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/825/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/826/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/827/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/828/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/829/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/830/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/831/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/832/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/833/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/834/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/835/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/836/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/837/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/838/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/839/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/840/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/841/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/842/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/843/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/844/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/845/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/846/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/847/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/848/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/849/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/850/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/851/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/852/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/853/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/854/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/855/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/856/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/857/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/858/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/859/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/860/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/861/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/862/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/863/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/864/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/865/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/866/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/867/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/868/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/869/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/870/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/871/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/872/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/873/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/874/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/875/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/876/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/877/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/878/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/879/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/880/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/881/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/882/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/883/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/884/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/885/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/886/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/887/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/888/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/889/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/890/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/891/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/892/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/893/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/894/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/895/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/896/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/897/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/898/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/899/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/900/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/901/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/902/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/903/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/904/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/905/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/906/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/907/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/908/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/909/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/910/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/911/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/912/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/913/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/914/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/915/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/916/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/917/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/918/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/919/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/920/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/921/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/922/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/923/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/924/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/925/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/926/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/927/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/928/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/929/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/930/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/931/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/932/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/933/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/934/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/935/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/936/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/937/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/938/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/939/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/940/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/941/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/942/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/943/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/944/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/945/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/946/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/947/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/948/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/949/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/950/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/951/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/952/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/953/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/954/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/955/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/956/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/957/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/958/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/959/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/960/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/961/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/962/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/963/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/964/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/965/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/966/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/967/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/968/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/969/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/970/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/971/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/972/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/973/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/974/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/975/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/976/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/977/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/978/datastream/MODS/view/
# Parsing https://d.lib.msu.edu/maps/979/datastream/MODS/view/
# #### Job done ####
