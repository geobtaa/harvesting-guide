# %% [markdown]
# # HTML Site Parsing (using BeautifulSoup module) with UMedia
# - This following tutorial will guide users through Hyper Text Mark-Up Language (HTML) site parsing using the BeautifulSoup Python module with BTAA's UMedia portal site.
# - In addition how to install the BeautifulSoup module, scan and list web pages, return titles, descriptions, and dates, then writing these to CSV format.

# %% [markdown]
# ## 1. Install Module BeautifulSoup and Import Neccessary Modules

# %% [markdown]
# - **Use this section if you don't have the BeautifulSoup Module installed**

# %%
# Use one of the following:

# pip install BeautifulSoup

# or  

# conda install BeautifulSoup
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
#
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - beautifulsoup
#
# Current channels:
#
#   - https://conda.anaconda.org/conda-forge/osx-64
#   - https://conda.anaconda.org/conda-forge/noarch
#   - https://conda.anaconda.org/conda/osx-64
#   - https://conda.anaconda.org/conda/noarch
#   - https://repo.anaconda.com/pkgs/main/osx-64
#   - https://repo.anaconda.com/pkgs/main/noarch
#   - https://repo.anaconda.com/pkgs/r/osx-64
#   - https://repo.anaconda.com/pkgs/r/noarch
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.
#
#
#
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# - **List of required modules needed to parse (scrape) websites, populate JSON list, return require fields and print results to a CSV**

# %%
import collections
import requests
import urllib.request 
from urllib import request
import csv
import json
import os
from bs4 import BeautifulSoup as bs

# %% [markdown]
# ## 2. Set directory to drive and name for CSV

# %% [markdown]
# - **Example parameters for setting the folder path and the name of CSV**

# %%
HTML_path = r'/Users/Thenewsguy/Documents/GitHub/harvesting-guide/docs/1-Tutorials/HTMLCSV/jsons' # point to the folder path
csv_name = "HTMLCSV" # name for the csv to be created

print("drive files")
# Out:
# drive files

# %% [markdown]
# ## 3. Opening JSON(s) and Populate them to empty list

# %% [markdown]
# - **Creating an empty list that takes JSONs from open webportals that have been scraped and populates them to said list**

# %%
# Create an empty list to store the JSON data
JSONMetadata = []

# Open the JSON file
with open('/Users/Thenewsguy/Documents/GitHub/harvesting-guide/docs/1-Tutorials/HTMLCSV/jsons/dateAdded_201712.json') as f:
    
    # Load the JSON data into a Python dictionary
    data_dict = json.load(f)
    
    # Iterate over the dictionary items and append them to the list
    JSONMetadata.append(data_dict)

# Print the populated list

print(JSONMetadata)
# Out:
# [[{'id': 'p16022coll230:306', 'object': 'https://cdm16022.contentdm.oclc.org/utils/getthumbnail/collection/p16022coll230/id/306', 'set_spec': 'p16022coll230', 'collection_name': 'General Map Collection', 'collection_name_s': 'General Map Collection', 'collection_description': "Maps from the general collection held by the University of Minnesota's Borchert Map Library.", 'title': 'A Chronological chart of ancient, modern and Biblical history', 'title_s': 'A Chronological chart of ancient, modern and Biblical history', 'title_t': 'A Chronological chart of ancient, modern and Biblical history', 'title_search': 'A Chronological chart of ancient, modern and Biblical history', 'title_sort': 'achronologicalchartofancientmodernandbiblicalhistory', 'date_created': ['1876'], 'date_created_ss': ['1876'], 'date_created_sort': '1876', 'creator': ['Adams, Sebastian C'], 'creator_ss': ['Adams, Sebastian C'], 'creator_sort': 'adamssebastianc', 'notes': '2d ed.', 'types': ['Cartographic'], 'format': ['Maps | http://vocab.getty.edu/aat/300028094'], 'format_name': ['Maps'], 'dimensions': 'color table on sheet ; 70 x 657 cm folded to 70 x 35 cm', 'subject': ['Chronology, Historical Charts, Diagrams, Etc'], 'subject_ss': ['Chronology, Historical Charts, Diagrams, Etc'], 'language': ['English'], 'scale': 'Not drawn to scale.', 'coordinates': ['W0202500 E1561400 N0784500 S0394900', '(W 20°25\'00"-E 156°14\'00"/N 78°45\'00"-S 39°49\'00")'], 'contributing_organization': 'University of Minnesota Libraries, John R. Borchert Map Library.', 'contributing_organization_name': 'University of Minnesota Libraries, John R. Borchert Map Library.', 'contributing_organization_name_s': 'University of Minnesota Libraries, John R. Borchert Map Library.', 'contact_information': 'University of Minnesota Libraries, John R. Borchert Map Library. S-76 Wilson Library, 309 19th Ave S, Minneapolis, MN 55455; https://www.lib.umn.edu/borchert', 'local_identifier': ['D11 .A3 1876'], 'barcode': 'UMN_BARCODE:31951P01139111S', 'system_identifier': 'UMN_ALMA:9951710020001701', 'dls_identifier': ['map04042'], 'persistent_url': 'http://purl.umn.edu/210880', 'local_rights': 'Use of this item may be governed by US and international copyright laws. You may be able to use this item, but copyright and other considerations may apply. For possible additional information or guidance on your use, please contact the contributing organization.', 'page_count': 0, 'record_type': 'primary', 'first_viewer_type': 'image', 'viewer_type': 'image', 'attachment': '17.jp2', 'document_type': 'item', 'featured_collection_order': 999, 'date_added': '2017-12-22T00:00:00Z', 'date_added_sort': '2017-12-22T00:00:00Z', 'date_modified': '2021-03-24T00:00:00Z', '_version_': 1721787005997678593, 'type': 'Cartographic', 'collection': 'p16022coll230', 'is_compound': False, 'parent_id': '306', 'thumb_url': 'https://cdm16022.contentdm.oclc.org/utils/getthumbnail/collection/p16022coll230/id/306', 'thumb_cdn_url': 'https://dkp5i0hinw9br.cloudfront.net/ae12499b33d45135f035afe0558ed9630187aef5.png'}, {'id': 'p16022coll230:318', 'object': 'https://cdm16022.contentdm.oclc.org/utils/getthumbnail/collection/p16022coll230/id/318', 'set_spec': 'p16022coll230', 'collection_name': 'General Map Collection', 'collection_name_s': 'General Map Collection', 'collection_description': "Maps from the general collection held by the University of Minnesota's Borchert Map Library.", 'title': 'A Chronological chart of ancient, modern and Biblical history', 'title_s': 'A Chronological chart of ancient, modern and Biblical history', 'title_t': 'A Chronological chart of ancient, modern and Biblical history', 'title_search': 'A Chronological chart of ancient, modern and Biblical history', 'title_sort': 'achronologicalchartofancientmodernandbiblicalhistory', 'description': "Cover title: Adams' synchronological chart or map of history. Includes illus., port., etc.", 'date_created': ['1878?'], 'date_created_ss': ['1878?'], 'date_created_sort': '1878 ...

# %% [markdown]
# ## 4. Return Title, Descriptions and Dates

# %% [markdown]
# - **Each cell shows the Title, HTML breakdown and Dates of the Umedia website https://umedia.lib.umn.edu/ for better understanding of the functionality of the BeautifulSoup module and web scrapping**

# %%
url = "https://umedia.lib.umn.edu/"
html = request.urlopen(url).read().decode('utf8')
html[:60]

from bs4 import BeautifulSoup
soup = BeautifulSoup(html, 'html.parser')
title = soup.find('title')

print(title) # Prints the tag
print(title.string) # Prints the tag string content
# Out:
# <title>UMedia</title>
# UMedia

# %%
url="https://umedia.lib.umn.edu/"

# Make a GET request to fetch the raw HTML content

html_content = requests.get(url).text


# Parse the html content

soup = BeautifulSoup(html_content, "lxml")

print(soup.prettify()) # Print the parsed data of html
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <title>
#    UMedia
#   </title>
#   <meta content="authenticity_token" name="csrf-param"/>
#   <meta content="2m+6Ut7bqnAJ6NqDN/OCF4tCJdfKAd02k4sKgvXuhqTGyeXdd/+otuhmRo0Vw0WwoBr3xYLwBX3/58MBDdhEpg==" name="csrf-token"/>
#   <meta name="csp-nonce"/>
#   <link data-turbolinks-track="reload" href="/assets/application-fdd2b06ca1616f0045241f4a13c3cba966fcfeb9182621ff356cc1edcd8b4810.css" media="all" rel="stylesheet"/>
#   <script data-turbolinks-track="reload" src="/assets/application-e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855.js">
#   </script>
#   <script src="/packs/js/application-a167eb968db527fdd849.js">
#   </script>
#   <script src="/packs/js/thumbnailer-895235c547f3aa7c1823.js">
#   </script>
#   <script src="/packs/js/details-toggle-582a99a7dc7aa4ff769a.js">
#   </script>
#   <script src="/packs/js/google_events_tracking-2c296b143c1c7ebd734b.js">
#   </script>
#   <script src="https://cdnapisec.kaltura.com/p/1369852/sp/136985200/embedIframeJs/uiconf_id/41902002/partner_id/1369852">
#   </script>
#   <script src="https://cdnapisec.kaltura.com/p/1369852/sp/136985200/embedIframeJs/uiconf_id/42156071/partner_id/1369852">
#   </script>
#   <link href="/assets/favicon-539cccf70fd25fb48c348d62856797ed949adf1937c69af62c58c85c634e28fa.ico" rel="shortcut icon"/>
#   <meta content="ysdtk2ODzHvZ3lvKwF7eMi-YL1q76zGBbTA5T-LI1hg" name="google-site-verification"/>
#   <meta content="width=device-width" name="viewport"/>
#  </head>
#  <body class="umedia">
#   <header role="banner">
#    <a class="screen-reader-text" href="#main">
#     Skip to main content
#    </a>
#    <div class="row">
#     <div class="container">
#      <a href="https://twin-cities.umn.edu/" id="university-wordmark">
#       <img alt="University of Minnesota" src="https://static.lib.umn.edu/assets/0.1.13/img/logos/NoM-D2D-gld-wht@2x.png"/>
#      </a>
#      <div class="pull-right d-none d-sm-block hidden-xs">
#       <ul class="list-inline pull-right">
#        <li class="list-inline-item">
#         <a href="https://onestop.umn.edu/">
#          One Stop
#         </a>
#        </li>
#        <li class="list-inline-item">
#         <a href="https://www.myu.umn.edu/">
#          MyU
#          <svg aria-hidden="true" class="glyph glyph-lock" role="presentation" viewbox="0 0 21 32">
#           <title>
#            Lock
#           </title>
#           <desc>
#            Authentication required
#           </desc>
#           <path d="M5.728 13.728h9.12v-3.456q0-1.888-1.344-3.232t-3.232-1.312-3.232 1.312-1.312 3.232v3.456zM20.576 15.424v10.304q0 0.704-0.512 1.184t-1.216 0.512h-17.12q-0.736 0-1.216-0.512t-0.512-1.184v-10.304q0-0.704 0.512-1.216t1.216-0.48h0.544v-3.456q0-3.264 2.368-5.632t5.632-2.368 5.664 2.368 2.336 5.632v3.456h0.576q0.736 0 1.216 0.48t0.512 1.216z">
#           </path>
#          </svg>
#         </a>
#        </li>
#        <li class="list-inline-item">
#         <a href="https://www.lib.umn.edu/#umnhf-h-search">
#          Search Libraries services
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#    </div>
#   </header>
#   <nav aria-label="Site" class="navbar navbar-expand-md navbar-dark navbar-umn-maroon" id="header-lib-nav" role="navigation">
#    <div class="container">
#     <div class="navbar-brand">
#      <span id="logo">
#       <a alt="Home" href="/">
#        <img alt="University of Minnesota" id="blockm" src="/assets/blockm-734f5f2a4d13d6d254240c675e4a187a73cac2358fa2de4223daf6372b3a1059.svg"/>
#       </a>
#      </span>
#      <div id="branding">
#       <h2 id="libraries">
#        <a alt="Home" href="/">
#         Libraries
#        </a>
#       </h2>
#       <h1 id="application">
#        <a alt="Home" href="/">
#         UMedia
#        </a>
#       </h1>
#      </div>
#     </div>
#     <div class="pull-right">
#      <nav role="navigation header-links">
#       <ul class="nav navbar-nav" id="primary-nav">
#        <li>
#         <a class="dropdown-toggle" data-toggle="dropdown" href="#">
#          <i class="icon-help-circled">
#          </i>
#          Help
#          <b class="caret">
#          </b>
#         </a>
#         <ul aria-labelledby="help" class="dropdown-menu" id="help" role="menu">
#          <li class="about-link">
#           <a href="/about">
#            About
#           </a>
#          </li>
#          <li class="contact-link">
#           <a href="/contact">
#            Contact
#           </a>
#          </li>
#         </ul>
#        </li>
#       </ul>
#      </nav>
#     </div>
#    </div>
#   </nav>
#   <div class="container" id="main" name="main">
#    <div data-controller="home" data-home-collection_rows="20" data-home-collections_page="1" data-home-collections_sort="collection_recency_sort desc" data-home-filter_q="" id="home-controller-data">
#     <div class="row">
#      <div class="home-hero">
#      </div>
#     </div>
#     <div class="home-search">
#      <form accept-charset="UTF-8" action="/search" method="get">
#       <input name="utf8" type="hidden" value="✓"/>
#       <input id="sort" name="sort" type="hidden"/>
#       <div class="input-group input-group-lg col-md-8 main-search">
#        <label for="q" style="display:none">
#         Search:
#        </label>
#        <input class="form-control" id="q" name="q" placeholder="Search UMedia..." type="text"/>
#        <span class="input-group-btn">
#         <button class="btn btn-umn-maroon search-btn" type="submit">
#          <span class="glyphicon glyphicon-search">
#          </span>
#          Go
#         </button>
#        </span>
#        <div class="input-group input-group-lg col-sm-12 hidden-xs">
#         <span class="input-group-btn">
#          <button aria-expanded="true" aria-haspopup="true" class="btn btn-umn-maroon" data-toggle="dropdown" id="search-browse" type="button">
#           Browse
#           <span class="caret">
#           </span>
#          </button>
#          <ul aria-labelledby="search-browse" class="dropdown-menu">
#           <li>
#            <a class="collection-browse-link" href="/facets?browse=true&amp;facet_field=collection_name_s&amp;facet_limit=25&amp;facet_sort=index">
#             Collection
#            </a>
#           </li>
#           <li>
#            <a class="type-browse-link" href="/facets?browse=true&amp;facet_field=types&amp;facet_limit=25&amp;facet_sort=index">
#             Type
#            </a>
#           </li>
#           <li>
#            <a class="format-browse-link" href="/facets?browse=true&amp;facet_field=format_name&amp;facet_limit=25&amp;facet_sort=index">
#             Format
#            </a>
#           </li>
#           <li>
#            <a class="date-browse-link" href="/facets?browse=true&amp;facet_field=date_created_ss&amp;facet_limit=25&amp;facet_sort=index">
#             Date
#            </a>
#           </li>
#           <li>
#            <a class="subject-browse-link" href="/facets?browse=true&amp;facet_field=subject_ss&amp;facet_limit=25&amp;facet_sort=index">
#             Subject
#            </a>
#           </li>
#           <li>
#            <a class="contributing-org-browse-link" href="/facets?browse=true&amp;facet_field=contributing_organization_name_s&amp;facet_limit=25&amp;facet_sort=index">
#             Contributing Organization
#            </a>
#           </li>
#          </ul>
#         </span>
#        </div>
#       </div>
#      </form>
#      <div class="home-search-description">
#       Discover 201,179 images, maps, manuscripts, video, audio, and more. UMedia provides open access to digitized materials from across the University of Minnesota.
#      </div>
#     </div>
#     <div id="collections-home">
#     </div>
#    </div>
#   </div>
#   <section id="site-map">
#    <div class="container">
#     <div class="row">
#      <div class="col-xs-12" id="footer-lib">
#       <div class="col-sm-10">
#        <div class="col-sm-3">
#         <h3>
#          Services
#         </h3>
#         <ul class="list-unstyled">
#          <li>
#           <a href="/about">
#            About UMedia
#           </a>
#          </li>
#          <li>
#           <a href="https://www.lib.umn.edu/digital">
#            Digital Library Services
#           </a>
#          </li>
#          <li>
#           <a href="https://github.com/UMNLibraries/digital_collection_apis">
#            Digital Collection APIs
#           </a>
#          </li>
#          <li>
#           <a href="https://www.lib.umn.edu/openaccess/policy">
#            Open Access Policy
#           </a>
#          </li>
#          <li>
#           <a href="https://drive.google.com/file/d/0B01AHtagDHqxV2VGbEhsc2E1LUk/view?usp=sharing">
#            Libraries Open Sharing Policy
#           </a>
#          </li>
#          <li>
#           <a href="https://www.lib.umn.edu/copyright">
#            Copyright Services
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="col-sm-3">
#         <h3>
#          Related Services
#         </h3>
#         <ul class="list-unstyled">
#          <li>
#           <a href="https://conservancy.umn.edu">
#            Digital Conservancy
#           </a>
#          </li>
#          <li>
#           <a href="https://www.umbrasearch.org">
#            Umbra Search
#           </a>
#          </li>
#          <li>
#           <a href="https://ojibwe.lib.umn.edu">
#            Ojibwe People’s Dictionary
#           </a>
#          </li>
#          <li>
#           <a href="http://gallery.lib.umn.edu">
#            Online Exhibits
#           </a>
#          </li>
#          <li>
#           <a href="https://mndigital.org">
#            Minnesota Digital Library
#           </a>
#          </li>
#          <li>
#           <a href="https://dp.la">
#            Digital Public Library of America
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="col-sm-3">
#         <h3>
#          Libraries
#         </h3>
#         <ul class="list-unstyled">
#          <li>
#           <a href="https://www.lib.umn.edu/about/collections">
#            Hours
#           </a>
#          </li>
#          <li>
#           <a href="https://www.continuum.umn.edu">
#            News &amp; Events
#           </a>
#          </li>
#          <li>
#           <a href="https://www.lib.umn.edu/about/staff">
#            Staff Directory
#           </a>
#          </li>
#          <li>
#           <a href="https://www.lib.umn.edu/about/selectors">
#            Subject Librarians
#           </a>
#          </li>
#          <li>
#           <a href="https://www.lib.umn.edu/about/goals">
#            Vision, Mission, &amp; Goals
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#       <div class="col-xs-12 col-sm-2">
#        <a href="http://www.lib.umn.edu">
#         <img alt="University Libraries" height="150" id="university-libraries" src="/assets/ulib-box_@2X-7f153bdee7d96ce0d382b2439b40aac3b0735b48da3793d649d668d263da65d0.png" title="University Libraries" width="150"/>
#        </a>
#       </div>
#      </div>
#     </div>
#    </div>
#   </section>
#   <!-- Global site tag (gtag.js) - Google Analytics -->
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-20973358-6">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-20973358-6');
#   </script>
#  </body>
# </html>

# %%
>>> s = '''<time class="jlist_date_image" datetime="2015-04-02 14:30:12">Idag <span class="list_date">14:30</span></time>'''
>>> soup = BeautifulSoup(s)
>>> for i in soup.findAll('time'):
        if i.has_attr('datetime'):
            print(i['datetime'])
# Out:
# 2015-04-02 14:30:12

# %% [markdown]
# ## 5. Print Results to CSV and Inspect

# %% [markdown]
# - Print JSON results to CSV to be viewed

# %%
with open('/Users/Thenewsguy/Documents/GitHub/harvesting-guide/docs/1-Tutorials/HTMLCSV/JSONresults.csv', 'r') as f:
  data = list(csv.reader(f))

counter = collections.defaultdict(int)
for row in data:
    counter[row[0]] += 1

writer = csv.writer(open('/Users/Thenewsguy/Documents/GitHub/harvesting-guide/docs/1-Tutorials/HTMLCSV/jsons/dateAdded_201712.json', 'w'))
for row in data:
    if counter[row[0]] >= 4:
        writer.writerow(row)
