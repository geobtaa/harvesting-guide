# %% [markdown]
# This script will convert a column of coordinates in d-m-s to d-d.

# %%
import pandas as pd
import numpy as np
import re

# %%
csv_file_path = '15d-01.csv'
data = pd.read_csv(csv_file_path, low_memory=False)

# %%
def convert_to_decimal(coordinate_str):
    try:
        print(f"Processing: {coordinate_str}")  # Debug print
        
        # Decode HTML entities
        coordinate_str = coordinate_str.replace("&#176;", "°").replace("&#697;", "'").replace("&#698;", '"').replace("ʹ", "'").replace("ʺ", '"')
        
        print(f"After HTML replacement: {coordinate_str}")  # Debug print
        
        # Check if already in decimal format
        if "." in coordinate_str:
            decimal_degrees = float(re.search(r"-?\d+\.\d+", coordinate_str).group())
        
        else:
            # Extract numerical values
            num_values = [float(x) for x in re.findall(r"\d+", coordinate_str)]
            
            print(f"Extracted numbers: {num_values}")  # Debug print
            
            # DMS to decimal with or without special characters
            if len(num_values) == 3:
                degrees, minutes, seconds = num_values
                decimal_degrees = degrees + (minutes / 60.0) + (seconds / 3600.0)
            
            # DM to decimal
            elif len(num_values) == 2:
                degrees, minutes = num_values
                decimal_degrees = degrees + (minutes / 60.0)
                
            # Only degrees
            elif len(num_values) == 1:
                degrees = num_values[0]
                decimal_degrees = degrees

            else:
                return None  # Unrecognized format

        if "S" in coordinate_str or "W" in coordinate_str:
            decimal_degrees *= -1

        return round(decimal_degrees, 4)

    except Exception as e:
        print(f"Error while converting coordinate: {e}")
        return None

def extract_bounding_box(coordinate_field):
    try:
        # Split latitude and longitude pairs
        lon_str, lat_str = coordinate_field.split("/")
        
        # Extract individual coordinates and convert to decimal
        west, east = map(convert_to_decimal, lon_str.split("--"))
        north, south = map(convert_to_decimal, lat_str.split("--"))
        
        # Check if any conversion failed
        if None in [west, east, north, south]:
            print("Conversion failed for one or more coordinates.")
            return None
        
        return f"{west},{south},{east},{north}"
    except Exception as e:
        print(f"Error while extracting bounding box: {e}")
        return None

data['Extracted Bounding Box'] = data['Coordinates'].apply(extract_bounding_box)
# Out:
# Processing: E 11°
# After HTML replacement: E 11°
# Extracted numbers: [11.0]
# Processing: E 20°
# After HTML replacement: E 20°
# Extracted numbers: [20.0]
# Processing:  S 4°
# After HTML replacement:  S 4°
# Extracted numbers: [4.0]
# Processing: S 19°
# After HTML replacement: S 19°
# Extracted numbers: [19.0]
# Processing: E 13°06'
# After HTML replacement: E 13°06'
# Extracted numbers: [13.0, 6.0]
# Processing: E 39°26'
# After HTML replacement: E 39°26'
# Extracted numbers: [39.0, 26.0]
# Processing: N 48°15'
# After HTML replacement: N 48°15'
# Extracted numbers: [48.0, 15.0]
# Processing: N 33°44'
# After HTML replacement: N 33°44'
# Extracted numbers: [33.0, 44.0]
# Processing: E 14°15'
# After HTML replacement: E 14°15'
# Extracted numbers: [14.0, 15.0]
# Processing: E 27°55'
# After HTML replacement: E 27°55'
# Extracted numbers: [27.0, 55.0]
# Processing: N 49°50'
# After HTML replacement: N 49°50'
# Extracted numbers: [49.0, 50.0]
# Processing: N 41°20'
# After HTML replacement: N 41°20'
# Extracted numbers: [41.0, 20.0]
# Processing: E 168°
# After HTML replacement: E 168°
# Extracted numbers: [168.0]
# Processing: W 2°
# After HTML replacement: W 2°
# Extracted numbers: [2.0]
# Processing: N 70°
# After HTML replacement: N 70°
# Extracted numbers: [70.0]
# Processing: N 5°
# After HTML replacement: N 5°
# Extracted numbers: [5.0]
# Processing: E 1°03ʹ00ʺ
# After HTML replacement: E 1°03'00"
# Extracted numbers: [1.0, 3.0, 0.0]
# Processing: E 7°42ʹ00ʺ
# After HTML replacement: E 7°42'00"
# Extracted numbers: [7.0, 42.0, 0.0]
# Processing: N 53°32ʹ00ʺ
# After HTML replacement: N 53°32'00"
# Extracted numbers: [53.0, 32.0, 0.0]
# Processing: N 50°32ʹ00ʺ
# After HTML replacement: N 50°32'00"
# Extracted numbers: [50.0, 32.0, 0.0]
# Processing: E 21°
# After HTML replacement: E 21°
# Extracted numbers: [21.0]
# Processing: E 39°
# After HTML replacement: E 39°
# Extracted numbers: [39.0]
# Processing: N 23°
# After HTML replacement: N 23°
# Extracted numbers: [23.0]
# Processing: N 4°
# After HTML replacement: N 4°
# Extracted numbers: [4.0]
# Processing: E 22°
# After HTML replacement: E 22°
# Extracted numbers: [22.0]
# Processing: E 38°
# After HTML replacement: E 38°
# Extracted numbers: [38.0]
# Processing: N 22°
# After HTML replacement: N 22°
# Extracted numbers: [22.0]
# Processing: N 2°
# After HTML replacement: N 2°
# Extracted numbers: [2.0]
# Processing: E 22°30'
# After HTML replacement: E 22°30'
# Extracted numbers: [22.0, 30.0]
# Processing: E 89°00'
# After HTML replacement: E 89°00'
# Extracted numbers: [89.0, 0.0]
# Processing: N 70°50'
# After HTML replacement: N 70°50'
# Extracted numbers: [70.0, 50.0]
# Processing: N 41°30'
# After HTML replacement: N 41°30'
# Extracted numbers: [41.0, 30.0]
# Processing: E 22⁰
# After HTML replacement: E 22⁰
# Extracted numbers: [22.0]
# Processing: E 49⁰
# After HTML replacement: E 49⁰
# Extracted numbers: [49.0]
# Processing: N 25⁰
# After HTML replacement: N 25⁰
# Extracted numbers: [25.0]
# Processing: N 8⁰
# After HTML replacement: N 8⁰
# Extracted numbers: [8.0]
# Processing: E 25°19ʹ00ʺ
# After HTML replacement: E 25°19'00"
# Extracted numbers: [25.0, 19.0, 0.0]
# Processing: E 55°18ʹ00ʺ
# After HTML replacement: E 55°18'00"
# Extracted numbers: [55.0, 18.0, 0.0]
# Processing: N 69°50ʹ00ʺ
# After HTML replacement: N 69°50'00"
# Extracted numbers: [69.0, 50.0, 0.0]
# Processing: N 56°14ʹ00ʺ
# After HTML replacement: N 56°14'00"
# Extracted numbers: [56.0, 14.0, 0.0]
# Processing: E 26°
# After HTML replacement: E 26°
# Extracted numbers: [26.0]
# Processing: E 35°
# After HTML replacement: E 35°
# Extracted numbers: [35.0]
# Processing:  S 18°
# After HTML replacement:  S 18°
# Extracted numbers: [18.0]
# Processing: S 23°
# After HTML replacement: S 23°
# Extracted numbers: [23.0]
# Processing: E 26°39ʹ00ʺ
# After HTML replacement: E 26°39'00"
# Extracted numbers: [26.0, 39.0, 0.0]
# Processing: E 50°46ʹ00ʺ
# After HTML replacement: E 50°46'00"
# Extracted numbers: [50.0, 46.0, 0.0]
# Processing: N 58°44ʹ00ʺ
# After HTML replacement: N 58°44'00"
# Extracted numbers: [58.0, 44.0, 0.0]
# Processing: N 45°15ʹ00ʺ
# After HTML replacement: N 45°15'00"
# Extracted numbers: [45.0, 15.0, 0.0]
# Processing: E 28°30ʹ
# After HTML replacement: E 28°30'
# Extracted numbers: [28.0, 30.0]
# Processing: E 31°
# After HTML replacement: E 31°
# Extracted numbers: [31.0]
# Processing: S 1°
# After HTML replacement: S 1°
# Extracted numbers: [1.0]
# Processing: S 4°30ʹ
# After HTML replacement: S 4°30'
# Extracted numbers: [4.0, 30.0]
# Processing: E 2°30'
# After HTML replacement: E 2°30'
# Extracted numbers: [2.0, 30.0]
# Processing: E 14°59'
# After HTML replacement: E 14°59'
# Extracted numbers: [14.0, 59.0]
# Processing: N 13°57'
# After HTML replacement: N 13°57'
# Extracted numbers: [13.0, 57.0]
# Processing: N 3°23'
# After HTML replacement: N 3°23'
# Extracted numbers: [3.0, 23.0]
# Processing: E 30°00ʹ
# After HTML replacement: E 30°00'
# Extracted numbers: [30.0, 0.0]
# Processing: E 39°00ʹ
# After HTML replacement: E 39°00'
# Extracted numbers: [39.0, 0.0]
# Processing: N 23°00ʹ
# After HTML replacement: N 23°00'
# Extracted numbers: [23.0, 0.0]
# Processing: N 12°00ʹ
# After HTML replacement: N 12°00'
# Extracted numbers: [12.0, 0.0]
# Processing: E 33°
# After HTML replacement: E 33°
# Extracted numbers: [33.0]
# Processing: E 48°30'
# After HTML replacement: E 48°30'
# Extracted numbers: [48.0, 30.0]
# Processing: N 18°
# After HTML replacement: N 18°
# Extracted numbers: [18.0]
# Processing: N 3°30'
# After HTML replacement: N 3°30'
# Extracted numbers: [3.0, 30.0]
# Processing: E 440
# After HTML replacement: E 440
# Extracted numbers: [440.0]
# Processing: E 730
# After HTML replacement: E 730
# Extracted numbers: [730.0]
# Processing: N 5225
# After HTML replacement: N 5225
# Extracted numbers: [5225.0]
# Processing: N 517
# After HTML replacement: N 517
# Extracted numbers: [517.0]
# Processing: E 4°00'
# After HTML replacement: E 4°00'
# Extracted numbers: [4.0, 0.0]
# Processing: E 45°00'
# After HTML replacement: E 45°00'
# Extracted numbers: [45.0, 0.0]
# Processing: N 71°30'
# After HTML replacement: N 71°30'
# Extracted numbers: [71.0, 30.0]
# Processing: N 53°30'
# After HTML replacement: N 53°30'
# Extracted numbers: [53.0, 30.0]
# Processing: E 4°00'
# After HTML replacement: E 4°00'
# Extracted numbers: [4.0, 0.0]
# Processing: E 8°06'
# After HTML replacement: E 8°06'
# Extracted numbers: [8.0, 6.0]
# Processing: N 49°48'
# After HTML replacement: N 49°48'
# Extracted numbers: [49.0, 48.0]
# Processing: N 47°46'
# After HTML replacement: N 47°46'
# Extracted numbers: [47.0, 46.0]
# Processing: E 4°30ʹ
# After HTML replacement: E 4°30'
# Extracted numbers: [4.0, 30.0]
# Processing: E 7°10ʹ
# After HTML replacement: E 7°10'
# Extracted numbers: [7.0, 10.0]
# Processing: N 44°30ʹ
# After HTML replacement: N 44°30'
# Extracted numbers: [44.0, 30.0]
# Processing: N 43°0ʹ
# After HTML replacement: N 43°0'
# Extracted numbers: [43.0, 0.0]
# Processing: E 5°
# After HTML replacement: E 5°
# Extracted numbers: [5.0]
# Processing: E 23°
# After HTML replacement: E 23°
# Extracted numbers: [23.0]
# Processing: N 56°
# After HTML replacement: N 56°
# Extracted numbers: [56.0]
# Processing: N 47°
# After HTML replacement: N 47°
# Extracted numbers: [47.0]
# Processing: E 7°49ʹ00ʺ
# After HTML replacement: E 7°49'00"
# Extracted numbers: [7.0, 49.0, 0.0]
# Processing: E 16°52ʹ00ʺ
# After HTML replacement: E 16°52'00"
# Extracted numbers: [16.0, 52.0, 0.0]
# Processing: N 41°31ʹ00ʺ
# After HTML replacement: N 41°31'00"
# Extracted numbers: [41.0, 31.0, 0.0]
# Processing: N 35°42ʹ00ʺ
# After HTML replacement: N 35°42'00"
# Extracted numbers: [35.0, 42.0, 0.0]
# Processing: E 9°39ʹ00ʺ
# After HTML replacement: E 9°39'00"
# Extracted numbers: [9.0, 39.0, 0.0]
# Processing: E 13°59ʹ00ʺ
# After HTML replacement: E 13°59'00"
# Extracted numbers: [13.0, 59.0, 0.0]
# Processing: N 45°10ʹ00ʺ
# After HTML replacement: N 45°10'00"
# Extracted numbers: [45.0, 10.0, 0.0]
# Processing: N 41°11ʹ00ʺ
# After HTML replacement: N 41°11'00"
# Extracted numbers: [41.0, 11.0, 0.0]
# Processing: W 001°36ʹ50ʺ
# After HTML replacement: W 001°36'50"
# Extracted numbers: [1.0, 36.0, 50.0]
# Error while extracting bounding box: not enough values to unpack (expected 2, got 1)
# Processing: W 008°25ʹ10ʺ
# After HTML replacement: W 008°25'10"
# Extracted numbers: [8.0, 25.0, 10.0]
# Error while extracting bounding box: not enough values to unpack (expected 2, got 1)
# Processing: W 0°
# After HTML replacement: W 0°
# Extracted numbers: [0.0]
# Processing: E 16°
# After HTML replacement: E 16°
# Extracted numbers: [16.0]
# Processing: N 23°20ʹ
# After HTML replacement: N 23°20'
# Extracted numbers: [23.0, 20.0]
# Processing: N 11°40ʹ
# After HTML replacement: N 11°40'
# Extracted numbers: [11.0, 40.0]
# Processing: W 0°14'42"
# After HTML replacement: W 0°14'42"
# Extracted numbers: [0.0, 14.0, 42.0]
# Processing: W 0°08'23"
# After HTML replacement: W 0°08'23"
# Extracted numbers: [0.0, 8.0, 23.0]
# Processing: N 5°39'21"
# After HTML replacement: N 5°39'21"
# Extracted numbers: [5.0, 39.0, 21.0]
# Processing: N 5°31'10"
# After HTML replacement: N 5°31'10"
# Extracted numbers: [5.0, 31.0, 10.0]
# Processing: W 10°00ʹ
# After HTML replacement: W 10°00'
# Extracted numbers: [10.0, 0.0]
# Processing: E 4°00ʹ
# After HTML replacement: E 4°00'
# Extracted numbers: [4.0, 0.0]
# Processing: N 46°00ʹ
# After HTML replacement: N 46°00'
# Extracted numbers: [46.0, 0.0]
# Processing: N 35°30ʹ
# After HTML replacement: N 35°30'
# Extracted numbers: [35.0, 30.0]
# Processing: W 10°43'00"
# After HTML replacement: W 10°43'00"
# Extracted numbers: [10.0, 43.0, 0.0]
# Processing: E 2°11'00"
# After HTML replacement: E 2°11'00"
# Extracted numbers: [2.0, 11.0, 0.0]
# Processing: N 59°21'00"
# After HTML replacement: N 59°21'00"
# Extracted numbers: [59.0, 21.0, 0.0]
# Processing: N 48°20'00"
# After HTML replacement: N 48°20'00"
# Extracted numbers: [48.0, 20.0, 0.0]
# Processing: W 111°00ʹ
# After HTML replacement: W 111°00'
# Extracted numbers: [111.0, 0.0]
# Processing: W 110°00ʹ
# After HTML replacement: W 110°00'
# Extracted numbers: [110.0, 0.0]
# Processing: N 45°00ʹ
# After HTML replacement: N 45°00'
# Extracted numbers: [45.0, 0.0]
# Processing: N 44°10ʹ
# After HTML replacement: N 44°10'
# Extracted numbers: [44.0, 10.0]
# Processing: W 112°30ʹ
# After HTML replacement: W 112°30'
# Extracted numbers: [112.0, 30.0]
# Processing: W 107°00ʹ
# After HTML replacement: W 107°00'
# Extracted numbers: [107.0, 0.0]
# Processing: N 44°00ʹ
# After HTML replacement: N 44°00'
# Extracted numbers: [44.0, 0.0]
# Processing: N 42°00ʹ
# After HTML replacement: N 42°00'
# Extracted numbers: [42.0, 0.0]
# Processing: W 119°00ʹ
# After HTML replacement: W 119°00'
# Extracted numbers: [119.0, 0.0]
# Processing: W 118°00ʹ
# After HTML replacement: W 118°00'
# Extracted numbers: [118.0, 0.0]
# Processing: N 37°00ʹ
# After HTML replacement: N 37°00'
# Extracted numbers: [37.0, 0.0]
# Processing: N 36°20ʹ
# After HTML replacement: N 36°20'
# Extracted numbers: [36.0, 20.0]
# Processing: W 11°0ʹ0ʺ
# After HTML replacement: W 11°0'0"
# Extracted numbers: [11.0, 0.0, 0.0]
# Processing: W 4°18ʹ0ʺ
# After HTML replacement: W 4°18'0"
# Extracted numbers: [4.0, 18.0, 0.0]
# Processing: N 55°25ʹ0ʺ
# After HTML replacement: N 55°25'0"
# Extracted numbers: [55.0, 25.0, 0.0]
# Processing: N 51°15ʹ0ʺ
# After HTML replacement: N 51°15'0"
# Extracted numbers: [51.0, 15.0, 0.0]
# Processing: W 11°12'
# After HTML replacement: W 11°12'
# Extracted numbers: [11.0, 12.0]
# Processing: W 0°56'
# After HTML replacement: W 0°56'
# Extracted numbers: [0.0, 56.0]
# Processing: N 36°15'
# After HTML replacement: N 36°15'
# Extracted numbers: [36.0, 15.0]
# Processing: N 29°17'
# After HTML replacement: N 29°17'
# Extracted numbers: [29.0, 17.0]
# Processing: W 125°
# After HTML replacement: W 125°
# Extracted numbers: [125.0]
# Processing: W 66°50'
# After HTML replacement: W 66°50'
# Extracted numbers: [66.0, 50.0]
# Processing: N 49°
# After HTML replacement: N 49°
# Extracted numbers: [49.0]
# Processing: N 25°
# After HTML replacement: N 25°
# Extracted numbers: [25.0]
# Processing: W 125°
# After HTML replacement: W 125°
# Extracted numbers: [125.0]
# Processing: W 67°
# After HTML replacement: W 67°
# Extracted numbers: [67.0]
# Processing: N 49°
# After HTML replacement: N 49°
# Extracted numbers: [49.0]
# Processing: N 24°
# After HTML replacement: N 24°
# Extracted numbers: [24.0]
# Processing: W 125°
# After HTML replacement: W 125°
# Extracted numbers: [125.0]
# Processing: W 67°
# After HTML replacement: W 67°
# Extracted numbers: [67.0]
# Processing: N 49°
# After HTML replacement: N 49°
# Extracted numbers: [49.0]
# Processing: N 24°
# After HTML replacement: N 24°
# Extracted numbers: [24.0]
# Processing: W 125°
# After HTML replacement: W 125°
# Extracted numbers: [125.0]
# Processing: W 75°
# After HTML replacement: W 75°
# Extracted numbers: [75.0]
# Processing: N 40°
# After HTML replacement: N 40°
# Extracted numbers: [40.0]
# Processing: N 15°
# After HTML replacement: N 15°
# Extracted numbers: [15.0]
# Processing: W 128°
# After HTML replacement: W 128°
# Extracted numbers: [128.0]
# Processing: W 64°
# After HTML replacement: W 64°
# Extracted numbers: [64.0]
# Processing: N 48°
# After HTML replacement: N 48°
# Extracted numbers: [48.0]
# Processing: N 24°
# After HTML replacement: N 24°
# Extracted numbers: [24.0]
# Processing: W 129°
# After HTML replacement: W 129°
# Extracted numbers: [129.0]
# Processing: W 65°
# After HTML replacement: W 65°
# Extracted numbers: [65.0]
# Processing: N 47°
# After HTML replacement: N 47°
# Extracted numbers: [47.0]
# Processing: N 20°
# After HTML replacement: N 20°
# Extracted numbers: [20.0]
# Processing: W 129°
# After HTML replacement: W 129°
# Extracted numbers: [129.0]
# Processing: W 65°
# After HTML replacement: W 65°
# Extracted numbers: [65.0]
# Processing: N 49°
# After HTML replacement: N 49°
# Extracted numbers: [49.0]
# Processing: N 25°
# After HTML replacement: N 25°
# Extracted numbers: [25.0]
# Processing: W 129°
# After HTML replacement: W 129°
# Extracted numbers: [129.0]
# Processing: W 65°
# After HTML replacement: W 65°
# Extracted numbers: [65.0]
# Processing: N 51°
# After HTML replacement: N 51°
# Extracted numbers: [51.0]
# Processing: N 25°
# After HTML replacement: N 25°
# Extracted numbers: [25.0]
# Processing: W 14°
# After HTML replacement: W 14°
# Extracted numbers: [14.0]
# Processing: E 22°
# After HTML replacement: E 22°
# Extracted numbers: [22.0]
# Processing: N 12°
# After HTML replacement: N 12°
# Extracted numbers: [12.0]
# Processing: N 7°30ʹ
# After HTML replacement: N 7°30'
# Extracted numbers: [7.0, 30.0]
# Processing: W 14°
# After HTML replacement: W 14°
# Extracted numbers: [14.0]
# Processing: E 4°
# After HTML replacement: E 4°
# Extracted numbers: [4.0]
# Processing: N 25°
# After HTML replacement: N 25°
# Extracted numbers: [25.0]
# Processing: N 10°
# After HTML replacement: N 10°
# Extracted numbers: [10.0]
# Processing: W 15⁰
# After HTML replacement: W 15⁰
# Extracted numbers: [15.0]
# Processing: E 15⁰
# After HTML replacement: E 15⁰
# Extracted numbers: [15.0]
# Processing: N 20⁰
# After HTML replacement: N 20⁰
# Extracted numbers: [20.0]
# Processing: S 5⁰
# After HTML replacement: S 5⁰
# Extracted numbers: [5.0]
# Processing: W 17°30ʹ
# After HTML replacement: W 17°30'
# Extracted numbers: [17.0, 30.0]
# Processing: E 11°15ʹ
# After HTML replacement: E 11°15'
# Extracted numbers: [11.0, 15.0]
# Processing: N 16°40ʹ
# After HTML replacement: N 16°40'
# Extracted numbers: [16.0, 40.0]
# Processing: N 12°20ʹ
# After HTML replacement: N 12°20'
# Extracted numbers: [12.0, 20.0]
# Processing: W 180°
# After HTML replacement: W 180°
# Extracted numbers: [180.0]
# Processing: E 180°
# After HTML replacement: E 180°
# Extracted numbers: [180.0]
# Processing: N 90°
# After HTML replacement: N 90°
# Extracted numbers: [90.0]
# Processing: S 90°
# After HTML replacement: S 90°
# Extracted numbers: [90.0]
# Processing: W 180°
# After HTML replacement: W 180°
# Extracted numbers: [180.0]
# Processing: E 180°
# After HTML replacement: E 180°
# Extracted numbers: [180.0]
# Processing: N 90°
# After HTML replacement: N 90°
# Extracted numbers: [90.0]
# Processing: S 90°
# After HTML replacement: S 90°
# Extracted numbers: [90.0]
# Processing: W 180°
# After HTML replacement: W 180°
# Extracted numbers: [180.0]
# Processing: E 180°
# After HTML replacement: E 180°
# Extracted numbers: [180.0]
# Processing: S 20°
# After HTML replacement: S 20°
# Extracted numbers: [20.0]
# Processing: S 90°
# After HTML replacement: S 90°
# Extracted numbers: [90.0]
# Processing: W 180°00'00"
# After HTML replacement: W 180°00'00"
# Extracted numbers: [180.0, 0.0, 0.0]
# Processing: E 180°00'00"
# After HTML replacement: E 180°00'00"
# Extracted numbers: [180.0, 0.0, 0.0]
# Processing: N 90°00'00"
# After HTML replacement: N 90°00'00"
# Extracted numbers: [90.0, 0.0, 0.0]
# Processing: S 90°00'00"
# After HTML replacement: S 90°00'00"
# Extracted numbers: [90.0, 0.0, 0.0]
# Processing: W 1°11'
# After HTML replacement: W 1°11'
# Extracted numbers: [1.0, 11.0]
# Processing: E 0°35'
# After HTML replacement: E 0°35'
# Extracted numbers: [0.0, 35.0]
# Processing: N 40°41'
# After HTML replacement: N 40°41'
# Extracted numbers: [40.0, 41.0]
# Processing: N 38°03'
# After HTML replacement: N 38°03'
# Extracted numbers: [38.0, 3.0]
# Processing: W 1°38'58"
# After HTML replacement: W 1°38'58"
# Extracted numbers: [1.0, 38.0, 58.0]
# Processing: W 1°35'24"
# After HTML replacement: W 1°35'24"
# Extracted numbers: [1.0, 35.0, 24.0]
# Processing: N 6°43'32"
# After HTML replacement: N 6°43'32"
# Extracted numbers: [6.0, 43.0, 32.0]
# Processing: N 6°39'23"
# After HTML replacement: N 6°39'23"
# Extracted numbers: [6.0, 39.0, 23.0]
# Processing: W 23°
# After HTML replacement: W 23°
# Extracted numbers: [23.0]
# Processing: E 24°
# After HTML replacement: E 24°
# Extracted numbers: [24.0]
# Processing: N 24°
# After HTML replacement: N 24°
# Extracted numbers: [24.0]
# Processing: N 4°
# After HTML replacement: N 4°
# Extracted numbers: [4.0]
# Processing: W 25°
# After HTML replacement: W 25°
# Extracted numbers: [25.0]
# Processing: E 60°
# After HTML replacement: E 60°
# Extracted numbers: [60.0]
# Processing: N 70°
# After HTML replacement: N 70°
# Extracted numbers: [70.0]
# Processing: N 30°
# After HTML replacement: N 30°
# Extracted numbers: [30.0]
# Processing: W 29°10ʹ
# After HTML replacement: W 29°10'
# Extracted numbers: [29.0, 10.0]
# Processing: W 22°20ʹ
# After HTML replacement: W 22°20'
# Extracted numbers: [22.0, 20.0]
# Processing: N 36°30ʹ
# After HTML replacement: N 36°30'
# Extracted numbers: [36.0, 30.0]
# Processing: N 41°12ʹ
# After HTML replacement: N 41°12'
# Extracted numbers: [41.0, 12.0]
# Processing: W 30⁰
# After HTML replacement: W 30⁰
# Extracted numbers: [30.0]
# Processing: E 70⁰
# After HTML replacement: E 70⁰
# Extracted numbers: [70.0]
# Processing: N 40⁰
# After HTML replacement: N 40⁰
# Extracted numbers: [40.0]
# Processing: S 40⁰
# After HTML replacement: S 40⁰
# Extracted numbers: [40.0]
# Processing: W 4°46'
# After HTML replacement: W 4°46'
# Extracted numbers: [4.0, 46.0]
# Processing:  W 3°04'
# After HTML replacement:  W 3°04'
# Extracted numbers: [3.0, 4.0]
# Processing: N 53°42'
# After HTML replacement: N 53°42'
# Extracted numbers: [53.0, 42.0]
# Processing:  N 52°25'
# After HTML replacement:  N 52°25'
# Extracted numbers: [52.0, 25.0]
# Processing: W 5°30ʹ
# After HTML replacement: W 5°30'
# Extracted numbers: [5.0, 30.0]
# Processing: E 1°40ʹ
# After HTML replacement: E 1°40'
# Extracted numbers: [1.0, 40.0]
# Processing: N 15°
# After HTML replacement: N 15°
# Extracted numbers: [15.0]
# Processing: N 9°30ʹ
# After HTML replacement: N 9°30'
# Extracted numbers: [9.0, 30.0]
# Processing: W 5°39'
# After HTML replacement: W 5°39'
# Extracted numbers: [5.0, 39.0]
# Processing: E 8°21'
# After HTML replacement: E 8°21'
# Extracted numbers: [8.0, 21.0]
# Processing: N 51°10'
# After HTML replacement: N 51°10'
# Extracted numbers: [51.0, 10.0]
# Processing: N 42°00'
# After HTML replacement: N 42°00'
# Extracted numbers: [42.0, 0.0]
# Processing: W 61°55ʹ00ʺ
# After HTML replacement: W 61°55'00"
# Extracted numbers: [61.0, 55.0, 0.0]
# Processing: W 61°39ʹ00ʺ
# After HTML replacement: W 61°39'00"
# Extracted numbers: [61.0, 39.0, 0.0]
# Processing: N 17°11ʹ00ʺ
# After HTML replacement: N 17°11'00"
# Extracted numbers: [17.0, 11.0, 0.0]
# Processing: N 16°59ʹ00ʺ
# After HTML replacement: N 16°59'00"
# Extracted numbers: [16.0, 59.0, 0.0]
# Processing: W 65°06ʹ00ʺ
# After HTML replacement: W 65°06'00"
# Extracted numbers: [65.0, 6.0, 0.0]
# Processing: W 65°03ʹ07ʺ
# After HTML replacement: W 65°03'07"
# Extracted numbers: [65.0, 3.0, 7.0]
# Processing: N 44°19ʹ13ʺ
# After HTML replacement: N 44°19'13"
# Extracted numbers: [44.0, 19.0, 13.0]
# Processing: N 44°17ʹ13ʺ
# After HTML replacement: N 44°17'13"
# Extracted numbers: [44.0, 17.0, 13.0]
# Processing: W 6°00ʹ
# After HTML replacement: W 6°00'
# Extracted numbers: [6.0, 0.0]
# Processing: E 1°40ʹ
# After HTML replacement: E 1°40'
# Extracted numbers: [1.0, 40.0]
# Processing: N 55°50ʹ
# After HTML replacement: N 55°50'
# Extracted numbers: [55.0, 50.0]
# Processing: N 49°50ʹ
# After HTML replacement: N 49°50'
# Extracted numbers: [49.0, 50.0]
# Processing: W 6°25ʹ
# After HTML replacement: W 6°25'
# Extracted numbers: [6.0, 25.0]
# Processing: E 1°45ʹ
# After HTML replacement: E 1°45'
# Extracted numbers: [1.0, 45.0]
# Processing: N 55°48ʹ
# After HTML replacement: N 55°48'
# Extracted numbers: [55.0, 48.0]
# Processing: N 49°51ʹ
# After HTML replacement: N 49°51'
# Extracted numbers: [49.0, 51.0]
# Processing: W 71°10'37"
# After HTML replacement: W 71°10'37"
# Extracted numbers: [71.0, 10.0, 37.0]
# Processing: W 71°00'59"
# After HTML replacement: W 71°00'59"
# Extracted numbers: [71.0, 0.0, 59.0]
# Processing: N 42°24'04"
# After HTML replacement: N 42°24'04"
# Extracted numbers: [42.0, 24.0, 4.0]
# Processing: N 42°15'15"
# After HTML replacement: N 42°15'15"
# Extracted numbers: [42.0, 15.0, 15.0]
# Processing: W 71°10'49"
# After HTML replacement: W 71°10'49"
# Extracted numbers: [71.0, 10.0, 49.0]
# Processing: W 70°59'46"
# After HTML replacement: W 70°59'46"
# Extracted numbers: [70.0, 59.0, 46.0]
# Processing: N 42°24'05"
# After HTML replacement: N 42°24'05"
# Extracted numbers: [42.0, 24.0, 5.0]
# Processing: N 42°13'58"
# After HTML replacement: N 42°13'58"
# Extracted numbers: [42.0, 13.0, 58.0]
# Processing: W 71°11'02"
# After HTML replacement: W 71°11'02"
# Extracted numbers: [71.0, 11.0, 2.0]
# Processing: W 71°00'31"
# After HTML replacement: W 71°00'31"
# Extracted numbers: [71.0, 0.0, 31.0]
# Processing: N 42°23'13"
# After HTML replacement: N 42°23'13"
# Extracted numbers: [42.0, 23.0, 13.0]
# Processing: N 42°13'58"
# After HTML replacement: N 42°13'58"
# Extracted numbers: [42.0, 13.0, 58.0]
# Processing: W 71°11'09"
# After HTML replacement: W 71°11'09"
# Extracted numbers: [71.0, 11.0, 9.0]
# Processing: W 70°59'17"
# After HTML replacement: W 70°59'17"
# Extracted numbers: [70.0, 59.0, 17.0]
# Processing: N 42°23'42"
# After HTML replacement: N 42°23'42"
# Extracted numbers: [42.0, 23.0, 42.0]
# Processing: N 42°14'02"
# After HTML replacement: N 42°14'02"
# Extracted numbers: [42.0, 14.0, 2.0]
# Processing: W 71°15'00"
# After HTML replacement: W 71°15'00"
# Extracted numbers: [71.0, 15.0, 0.0]
# Processing: W 65°53'00"
# After HTML replacement: W 65°53'00"
# Extracted numbers: [65.0, 53.0, 0.0]
# Processing: N 48°01'00"
# After HTML replacement: N 48°01'00"
# Extracted numbers: [48.0, 1.0, 0.0]
# Processing: N 43°05'00"
# After HTML replacement: N 43°05'00"
# Extracted numbers: [43.0, 5.0, 0.0]
# Processing: W 71°35ʹ
# After HTML replacement: W 71°35'
# Extracted numbers: [71.0, 35.0]
# Processing: W 70°35ʹ
# After HTML replacement: W 70°35'
# Extracted numbers: [70.0, 35.0]
# Processing: N 42°50ʹ
# After HTML replacement: N 42°50'
# Extracted numbers: [42.0, 50.0]
# Processing: N 42°20
# After HTML replacement: N 42°20
# Extracted numbers: [42.0, 20.0]
# Processing: W 73°59ʹ35ʺ
# After HTML replacement: W 73°59'35"
# Extracted numbers: [73.0, 59.0, 35.0]
# Processing: W 73°59ʹ35ʺ
# After HTML replacement: W 73°59'35"
# Extracted numbers: [73.0, 59.0, 35.0]
# Processing: N 40°43ʹ27ʺ
# After HTML replacement: N 40°43'27"
# Extracted numbers: [40.0, 43.0, 27.0]
# Processing: N 40°43ʹ27ʺ
# After HTML replacement: N 40°43'27"
# Extracted numbers: [40.0, 43.0, 27.0]
# Processing: W 74°
# After HTML replacement: W 74°
# Extracted numbers: [74.0]
# Processing: W 72°
# After HTML replacement: W 72°
# Extracted numbers: [72.0]
# Processing: N 42°
# After HTML replacement: N 42°
# Extracted numbers: [42.0]
# Processing: N 41°
# After HTML replacement: N 41°
# Extracted numbers: [41.0]
# Processing: W 74°55ʹ
# After HTML replacement: W 74°55'
# Extracted numbers: [74.0, 55.0]
# Processing: W 66°05ʹ
# After HTML replacement: W 66°05'
# Extracted numbers: [66.0, 5.0]
# Processing: N 49°05ʹ
# After HTML replacement: N 49°05'
# Extracted numbers: [49.0, 5.0]
# Processing: N 44°25ʹ
# After HTML replacement: N 44°25'
# Extracted numbers: [44.0, 25.0]
# Processing: W 75°25ʹ
# After HTML replacement: W 75°25'
# Extracted numbers: [75.0, 25.0]
# Processing: W 73°15ʹ
# After HTML replacement: W 73°15'
# Extracted numbers: [73.0, 15.0]
# Processing: N 45°00ʹ
# After HTML replacement: N 45°00'
# Extracted numbers: [45.0, 0.0]
# Processing: N 43°05ʹ
# After HTML replacement: N 43°05'
# Extracted numbers: [43.0, 5.0]
# Processing: W 79°
# After HTML replacement: W 79°
# Extracted numbers: [79.0]
# Processing: W 78°
# After HTML replacement: W 78°
# Extracted numbers: [78.0]
# Processing: N 39°
# After HTML replacement: N 39°
# Extracted numbers: [39.0]
# Processing: N 38°
# After HTML replacement: N 38°
# Extracted numbers: [38.0]
# Processing: W 7°35'
# After HTML replacement: W 7°35'
# Extracted numbers: [7.0, 35.0]
# Processing: W 1°11'
# After HTML replacement: W 1°11'
# Extracted numbers: [1.0, 11.0]
# Processing: N 59°20'
# After HTML replacement: N 59°20'
# Extracted numbers: [59.0, 20.0]
# Processing: N 54°45'
# After HTML replacement: N 54°45'
# Extracted numbers: [54.0, 45.0]
# Processing: W 80°
# After HTML replacement: W 80°
# Extracted numbers: [80.0]
# Processing: W 65°
# After HTML replacement: W 65°
# Extracted numbers: [65.0]
# Processing: N 25°
# After HTML replacement: N 25°
# Extracted numbers: [25.0]
# Processing: N 15°
# After HTML replacement: N 15°
# Extracted numbers: [15.0]
# Processing: W 83°13'00"
# After HTML replacement: W 83°13'00"
# Extracted numbers: [83.0, 13.0, 0.0]
# Processing: W 74°27'00"
# After HTML replacement: W 74°27'00"
# Extracted numbers: [74.0, 27.0, 0.0]
# Processing: N 46°13'00"
# After HTML replacement: N 46°13'00"
# Extracted numbers: [46.0, 13.0, 0.0]
# Processing: N 41°12'00"
# After HTML replacement: N 41°12'00"
# Extracted numbers: [41.0, 12.0, 0.0]
# Processing: W 84°
# After HTML replacement: W 84°
# Extracted numbers: [84.0]
# Processing: W 75°
# After HTML replacement: W 75°
# Extracted numbers: [75.0]
# Processing: N 38°
# After HTML replacement: N 38°
# Extracted numbers: [38.0]
# Processing: N 33°
# After HTML replacement: N 33°
# Extracted numbers: [33.0]
# Processing: W 84°00ʹ
# After HTML replacement: W 84°00'
# Extracted numbers: [84.0, 0.0]
# Processing: W 83°00ʹ
# After HTML replacement: W 83°00'
# Extracted numbers: [83.0, 0.0]
# Processing: N 36°00ʹ
# After HTML replacement: N 36°00'
# Extracted numbers: [36.0, 0.0]
# Processing: N 35°20ʹ
# After HTML replacement: N 35°20'
# Extracted numbers: [35.0, 20.0]
# Processing: W 87°42'28"
# After HTML replacement: W 87°42'28"
# Extracted numbers: [87.0, 42.0, 28.0]
# Processing: W 87°40'37"
# After HTML replacement: W 87°40'37"
# Extracted numbers: [87.0, 40.0, 37.0]
# Processing: N 42°04'12"
# After HTML replacement: N 42°04'12"
# Extracted numbers: [42.0, 4.0, 12.0]
# Processing: N 42°01'55"
# After HTML replacement: N 42°01'55"
# Extracted numbers: [42.0, 1.0, 55.0]
# Processing: W 87°46'50"
# After HTML replacement: W 87°46'50"
# Extracted numbers: [87.0, 46.0, 50.0]
# Processing: W 87°40'48"
# After HTML replacement: W 87°40'48"
# Extracted numbers: [87.0, 40.0, 48.0]
# Processing: N 42°05'18"
# After HTML replacement: N 42°05'18"
# Extracted numbers: [42.0, 5.0, 18.0]
# Processing: N 42°03'52"
# After HTML replacement: N 42°03'52"
# Extracted numbers: [42.0, 3.0, 52.0]
# Processing: W 87°50'44"
# After HTML replacement: W 87°50'44"
# Extracted numbers: [87.0, 50.0, 44.0]
# Processing: W 87°31'26"
# After HTML replacement: W 87°31'26"
# Extracted numbers: [87.0, 31.0, 26.0]
# Processing: N 42°04'01"
# After HTML replacement: N 42°04'01"
# Extracted numbers: [42.0, 4.0, 1.0]
# Processing: N 41°38'20"
# After HTML replacement: N 41°38'20"
# Extracted numbers: [41.0, 38.0, 20.0]
# Processing: W 87⁰37ʹ
# After HTML replacement: W 87⁰37'
# Extracted numbers: [87.0, 37.0]
# Error while extracting bounding box: not enough values to unpack (expected 2, got 1)
# Processing: W 88°15ʹ
# After HTML replacement: W 88°15'
# Extracted numbers: [88.0, 15.0]
# Processing: W 88°00ʹ
# After HTML replacement: W 88°00'
# Extracted numbers: [88.0, 0.0]
# Processing: N 41°45ʹ
# After HTML replacement: N 41°45'
# Extracted numbers: [41.0, 45.0]
# Processing: N 41°30ʹ
# After HTML replacement: N 41°30'
# Extracted numbers: [41.0, 30.0]
# Processing: W 88°30ʹ
# After HTML replacement: W 88°30'
# Extracted numbers: [88.0, 30.0]
# Processing: W 88°00ʹ
# After HTML replacement: W 88°00'
# Extracted numbers: [88.0, 0.0]
# Processing: N 37°45ʹ
# After HTML replacement: N 37°45'
# Extracted numbers: [37.0, 45.0]
# Processing: N 37°33ʹ
# After HTML replacement: N 37°33'
# Extracted numbers: [37.0, 33.0]
# Processing: W 88°30ʹ
# After HTML replacement: W 88°30'
# Extracted numbers: [88.0, 30.0]
# Processing: W 88°15ʹ
# After HTML replacement: W 88°15'
# Extracted numbers: [88.0, 15.0]
# Processing: N 41°30ʹ
# After HTML replacement: N 41°30'
# Extracted numbers: [41.0, 30.0]
# Processing: N 41°15ʹ
# After HTML replacement: N 41°15'
# Extracted numbers: [41.0, 15.0]
# Processing: W 88°30ʹ
# After HTML replacement: W 88°30'
# Extracted numbers: [88.0, 30.0]
# Processing: W 88°15ʹ
# After HTML replacement: W 88°15'
# Extracted numbers: [88.0, 15.0]
# Processing: N 41°30ʹ
# After HTML replacement: N 41°30'
# Extracted numbers: [41.0, 30.0]
# Processing: N 41°15ʹ
# After HTML replacement: N 41°15'
# Extracted numbers: [41.0, 15.0]
# Processing: W 89°15ʹ
# After HTML replacement: W 89°15'
# Extracted numbers: [89.0, 15.0]
# Processing: W 89°00ʹ
# After HTML replacement: W 89°00'
# Extracted numbers: [89.0, 0.0]
# Processing: N 42°15ʹ
# After HTML replacement: N 42°15'
# Extracted numbers: [42.0, 15.0]
# Processing: N 42°00ʹ
# After HTML replacement: N 42°00'
# Extracted numbers: [42.0, 0.0]
# Processing: W 8°00ʹ00ʺ
# After HTML replacement: W 8°00'00"
# Extracted numbers: [8.0, 0.0, 0.0]
# Processing: W 0°43ʹ00ʺ
# After HTML replacement: W 0°43'00"
# Extracted numbers: [0.0, 43.0, 0.0]
# Processing: N 60°51ʹ00ʺ
# After HTML replacement: N 60°51'00"
# Extracted numbers: [60.0, 51.0, 0.0]
# Processing: N 54°37ʹ00ʺ
# After HTML replacement: N 54°37'00"
# Extracted numbers: [54.0, 37.0, 0.0]
# Processing: W 8°06'00"
# After HTML replacement: W 8°06'00"
# Extracted numbers: [8.0, 6.0, 0.0]
# Processing: W 0°19'00"
# After HTML replacement: W 0°19'00"
# Extracted numbers: [0.0, 19.0, 0.0]
# Processing: N 59°21'00"
# After HTML replacement: N 59°21'00"
# Extracted numbers: [59.0, 21.0, 0.0]
# Processing: N 54°51'00"
# After HTML replacement: N 54°51'00"
# Extracted numbers: [54.0, 51.0, 0.0]
# Processing: W 90°
# After HTML replacement: W 90°
# Extracted numbers: [90.0]
# Processing: W 82°
# After HTML replacement: W 82°
# Extracted numbers: [82.0]
# Processing: N 38°
# After HTML replacement: N 38°
# Extracted numbers: [38.0]
# Processing: N 34°
# After HTML replacement: N 34°
# Extracted numbers: [34.0]
# Processing: W 90°15ʹ
# After HTML replacement: W 90°15'
# Extracted numbers: [90.0, 15.0]
# Processing: W 90°00ʹ
# After HTML replacement: W 90°00'
# Extracted numbers: [90.0, 0.0]
# Processing: N 42°30ʹ
# After HTML replacement: N 42°30'
# Extracted numbers: [42.0, 30.0]
# Processing: N 42°15ʹ
# After HTML replacement: N 42°15'
# Extracted numbers: [42.0, 15.0]
# Processing: W 90°30ʹ
# After HTML replacement: W 90°30'
# Extracted numbers: [90.0, 30.0]
# Processing: W 90°15ʹ
# After HTML replacement: W 90°15'
# Extracted numbers: [90.0, 15.0]
# Processing: N 42°30ʹ
# After HTML replacement: N 42°30'
# Extracted numbers: [42.0, 30.0]
# Processing: N 42°15ʹ
# After HTML replacement: N 42°15'
# Extracted numbers: [42.0, 15.0]
# Processing: W 91°00ʹ
# After HTML replacement: W 91°00'
# Extracted numbers: [91.0, 0.0]
# Processing: W 90°30ʹ
# After HTML replacement: W 90°30'
# Extracted numbers: [90.0, 30.0]
# Processing: N 40°45ʹ
# After HTML replacement: N 40°45'
# Extracted numbers: [40.0, 45.0]
# Processing: N 40°30ʹ
# After HTML replacement: N 40°30'
# Extracted numbers: [40.0, 30.0]
# Processing: W 93°00ʹ
# After HTML replacement: W 93°00'
# Extracted numbers: [93.0, 0.0]
# Processing: W 86°40ʹ
# After HTML replacement: W 86°40'
# Extracted numbers: [86.0, 40.0]
# Processing: N 47°10ʹ
# After HTML replacement: N 47°10'
# Extracted numbers: [47.0, 10.0]
# Processing: N 42°20ʹ
# After HTML replacement: N 42°20'
# Extracted numbers: [42.0, 20.0]
# Processing: W 95°
# After HTML replacement: W 95°
# Extracted numbers: [95.0]
# Processing: W 70°
# After HTML replacement: W 70°
# Extracted numbers: [70.0]
# Processing: N 45°
# After HTML replacement: N 45°
# Extracted numbers: [45.0]
# Processing: N 28°
# After HTML replacement: N 28°
# Extracted numbers: [28.0]
# Processing: W 95°
# After HTML replacement: W 95°
# Extracted numbers: [95.0]
# Processing: W 88°
# After HTML replacement: W 88°
# Extracted numbers: [88.0]
# Processing: N 33°
# After HTML replacement: N 33°
# Extracted numbers: [33.0]
# Processing: N 29°
# After HTML replacement: N 29°
# Extracted numbers: [29.0]
# Processing: W 97°
# After HTML replacement: W 97°
# Extracted numbers: [97.0]
# Processing: W 22°
# After HTML replacement: W 22°
# Extracted numbers: [22.0]
# Processing: N 13°
# After HTML replacement: N 13°
# Extracted numbers: [13.0]
# Processing: S 56°
# After HTML replacement: S 56°
# Extracted numbers: [56.0]
# Processing: W 97°
# After HTML replacement: W 97°
# Extracted numbers: [97.0]
# Processing: W 67°
# After HTML replacement: W 67°
# Extracted numbers: [67.0]
# Processing: N 50°
# After HTML replacement: N 50°
# Extracted numbers: [50.0]
# Processing: N 24°
# After HTML replacement: N 24°
# Extracted numbers: [24.0]
# Processing: W 97°10ʹ
# After HTML replacement: W 97°10'
# Extracted numbers: [97.0, 10.0]
# Processing: W 82°15ʹ
# After HTML replacement: W 82°15'
# Extracted numbers: [82.0, 15.0]
# Processing: N 49°20°
# After HTML replacement: N 49°20°
# Extracted numbers: [49.0, 20.0]
# Processing: N 41°36ʹ
# After HTML replacement: N 41°36'
# Extracted numbers: [41.0, 36.0]
# Processing: W 98°00ʹ
# After HTML replacement: W 98°00'
# Extracted numbers: [98.0, 0.0]
# Processing: W 58°00ʹ
# After HTML replacement: W 58°00'
# Extracted numbers: [58.0, 0.0]
# Processing: N 33°30ʹ
# After HTML replacement: N 33°30'
# Extracted numbers: [33.0, 30.0]
# Processing: N 7°00ʹ
# After HTML replacement: N 7°00'
# Extracted numbers: [7.0, 0.0]
# Processing: W 9°43'00"
# After HTML replacement: W 9°43'00"
# Extracted numbers: [9.0, 43.0, 0.0]
# Processing: W 5°52'00"
# After HTML replacement: W 5°52'00"
# Extracted numbers: [5.0, 52.0, 0.0]
# Processing: N 42°13'00"
# After HTML replacement: N 42°13'00"
# Extracted numbers: [42.0, 13.0, 0.0]
# Processing: N 36°43'00"
# After HTML replacement: N 36°43'00"
# Extracted numbers: [36.0, 43.0, 0.0]
# Processing: W 9°50'
# After HTML replacement: W 9°50'
# Extracted numbers: [9.0, 50.0]
# Processing: E 4°25'
# After HTML replacement: E 4°25'
# Extracted numbers: [4.0, 25.0]
# Processing: N 44°45'
# After HTML replacement: N 44°45'
# Extracted numbers: [44.0, 45.0]
# Processing: N 34°33'
# After HTML replacement: N 34°33'
# Extracted numbers: [34.0, 33.0]
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'
# Error while extracting bounding box: 'float' object has no attribute 'split'

# %%
cleaned_file_path = "bbox_" + csv_file_path


# Write the cleaned data to a CSV file
data.to_csv(cleaned_file_path, index=False)
