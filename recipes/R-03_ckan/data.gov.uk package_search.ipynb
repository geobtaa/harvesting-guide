# %%
# CKAN metadata harvester using package_search (data.gov.uk)

import requests
import pandas as pd
import os
import time

# --- Settings ---
BASE_URL = "https://data.gov.uk/api/3/action/package_search"
BATCH_SIZE = 100  # max = 1000, but start small
MAX_RECORDS = 55000  # estimated size of full catalog
OUTPUT_DIR = "harvested_data"
OUTPUT_FILE = "ckan_data_gov_uk_package_search.csv"
os.makedirs(OUTPUT_DIR, exist_ok=True)
output_path = os.path.join(OUTPUT_DIR, OUTPUT_FILE)

# --- Helper Function ---
def flatten_search_result(record):
    org = record.get("organization", {})
    resources = record.get("resources", [])
    resource = resources[0] if resources else {}

    return {
        "id": record.get("id", ""),
        "name": record.get("name", ""),
        "title": record.get("title", ""),
        "notes": record.get("notes", ""),
        "url": record.get("url", ""),
        "type": record.get("type", ""),
        "version": record.get("version", ""),
        "state": record.get("state", ""),
        "private": record.get("private", ""),
        "isopen": record.get("isopen", ""),
        "metadata_created": record.get("metadata_created", ""),
        "metadata_modified": record.get("metadata_modified", ""),
        "license_id": record.get("license_id", ""),
        "license_title": record.get("license_title", ""),
        "creator_user_id": record.get("creator_user_id", ""),
        "owner_org": record.get("owner_org", ""),
        "organization": org.get("title", ""),
        "num_resources": record.get("num_resources", 0),
        "num_tags": record.get("num_tags", 0),
        "tags": ", ".join([tag.get("name", "") for tag in record.get("tags", [])]),
        "resource_name": resource.get("name", ""),
        "resource_format": resource.get("format", ""),
        "resource_url": resource.get("url", ""),
    }
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
# --- Harvesting Loop ---
all_records = []

for start in range(0, MAX_RECORDS, BATCH_SIZE):
    print(f"Fetching records {start} to {start + BATCH_SIZE - 1}...")
    params = {"start": start, "rows": BATCH_SIZE}
    try:
        response = requests.get(BASE_URL, params=params)
        response.raise_for_status()
        results = response.json()["result"]["results"]

        for record in results:
            flat = flatten_search_result(record)
            all_records.append(flat)

        time.sleep(0.5)  # avoid rate limiting

    except Exception as e:
        print(f"Error fetching batch starting at {start}: {e}")
        break

# --- Save to CSV ---
df = pd.DataFrame(all_records)
df.to_csv(output_path, index=False)
print(f"Saved {len(df)} records to {output_path}")
# Out:
# Fetching records 0 to 99...
# Fetching records 100 to 199...
# Fetching records 200 to 299...
# Fetching records 300 to 399...
# Fetching records 400 to 499...
# Fetching records 500 to 599...
# Fetching records 600 to 699...
# Fetching records 700 to 799...
# Fetching records 800 to 899...
# Fetching records 900 to 999...
# Fetching records 1000 to 1099...
# Fetching records 1100 to 1199...
# Fetching records 1200 to 1299...
# Fetching records 1300 to 1399...
# Fetching records 1400 to 1499...
# Fetching records 1500 to 1599...
# Fetching records 1600 to 1699...
# Fetching records 1700 to 1799...
# Fetching records 1800 to 1899...
# Fetching records 1900 to 1999...
# Fetching records 2000 to 2099...
# Fetching records 2100 to 2199...
# Fetching records 2200 to 2299...
# Fetching records 2300 to 2399...
# Fetching records 2400 to 2499...
# Fetching records 2500 to 2599...
# Fetching records 2600 to 2699...
# Fetching records 2700 to 2799...
# Fetching records 2800 to 2899...
# Fetching records 2900 to 2999...
# Fetching records 3000 to 3099...
# Fetching records 3100 to 3199...
# Fetching records 3200 to 3299...
# Fetching records 3300 to 3399...
# Fetching records 3400 to 3499...
# Fetching records 3500 to 3599...
# Fetching records 3600 to 3699...
# Fetching records 3700 to 3799...
# Fetching records 3800 to 3899...
# Fetching records 3900 to 3999...
# Fetching records 4000 to 4099...
# Fetching records 4100 to 4199...
# Fetching records 4200 to 4299...
# Fetching records 4300 to 4399...
# Fetching records 4400 to 4499...
# Fetching records 4500 to 4599...
# Fetching records 4600 to 4699...
# Fetching records 4700 to 4799...
# Fetching records 4800 to 4899...
# Fetching records 4900 to 4999...
# Fetching records 5000 to 5099...
# Fetching records 5100 to 5199...
# Fetching records 5200 to 5299...
# Fetching records 5300 to 5399...
# Fetching records 5400 to 5499...
# Fetching records 5500 to 5599...
# Fetching records 5600 to 5699...
# Fetching records 5700 to 5799...
# Fetching records 5800 to 5899...
# Fetching records 5900 to 5999...
# Fetching records 6000 to 6099...
# Fetching records 6100 to 6199...
# Fetching records 6200 to 6299...
# Fetching records 6300 to 6399...
# Fetching records 6400 to 6499...
# Fetching records 6500 to 6599...
# Fetching records 6600 to 6699...
# Fetching records 6700 to 6799...
# Fetching records 6800 to 6899...
# Fetching records 6900 to 6999...
# Fetching records 7000 to 7099...
# Fetching records 7100 to 7199...
# Fetching records 7200 to 7299...
# Fetching records 7300 to 7399...
# Fetching records 7400 to 7499...
# Fetching records 7500 to 7599...
# Fetching records 7600 to 7699...
# Fetching records 7700 to 7799...
# Fetching records 7800 to 7899...
# Fetching records 7900 to 7999...
# Fetching records 8000 to 8099...
# Fetching records 8100 to 8199...
# Fetching records 8200 to 8299...
# Fetching records 8300 to 8399...
# Fetching records 8400 to 8499...
# Fetching records 8500 to 8599...
# Fetching records 8600 to 8699...
# Fetching records 8700 to 8799...
# Fetching records 8800 to 8899...
# Fetching records 8900 to 8999...
# Fetching records 9000 to 9099...
# Fetching records 9100 to 9199...
# Fetching records 9200 to 9299...
# Fetching records 9300 to 9399...
# Fetching records 9400 to 9499...
# Fetching records 9500 to 9599...
# Fetching records 9600 to 9699...
# Fetching records 9700 to 9799...
# Fetching records 9800 to 9899...
# Fetching records 9900 to 9999...
# Fetching records 10000 to 10099...
# Fetching records 10100 to 10199...
# Fetching records 10200 to 10299...
# Fetching records 10300 to 10399...
# Fetching records 10400 to 10499...
# Fetching records 10500 to 10599...
# Fetching records 10600 to 10699...
# Fetching records 10700 to 10799...
# Fetching records 10800 to 10899...
# Fetching records 10900 to 10999...
# Fetching records 11000 to 11099...
# Fetching records 11100 to 11199...
# Fetching records 11200 to 11299...
# Fetching records 11300 to 11399...
# Fetching records 11400 to 11499...
# Fetching records 11500 to 11599...
# Fetching records 11600 to 11699...
# Fetching records 11700 to 11799...
# Fetching records 11800 to 11899...
# Fetching records 11900 to 11999...
# Fetching records 12000 to 12099...
# Fetching records 12100 to 12199...
# Fetching records 12200 to 12299...
# Fetching records 12300 to 12399...
# Fetching records 12400 to 12499...
# Fetching records 12500 to 12599...
# Fetching records 12600 to 12699...
# Fetching records 12700 to 12799...
# Fetching records 12800 to 12899...
# Fetching records 12900 to 12999...
# Fetching records 13000 to 13099...
# Fetching records 13100 to 13199...
# Fetching records 13200 to 13299...
# Fetching records 13300 to 13399...
# Fetching records 13400 to 13499...
# Fetching records 13500 to 13599...
# Fetching records 13600 to 13699...
# Fetching records 13700 to 13799...
# Fetching records 13800 to 13899...
# Fetching records 13900 to 13999...
# Fetching records 14000 to 14099...
# Fetching records 14100 to 14199...
# Fetching records 14200 to 14299...
# Fetching records 14300 to 14399...
# Fetching records 14400 to 14499...
# Fetching records 14500 to 14599...
# Fetching records 14600 to 14699...
# Fetching records 14700 to 14799...
# Fetching records 14800 to 14899...
# Fetching records 14900 to 14999...
# Fetching records 15000 to 15099...
# Fetching records 15100 to 15199...
# Fetching records 15200 to 15299...
# Fetching records 15300 to 15399...
# Fetching records 15400 to 15499...
# Fetching records 15500 to 15599...
# Fetching records 15600 to 15699...
# Fetching records 15700 to 15799...
# Fetching records 15800 to 15899...
# Fetching records 15900 to 15999...
# Fetching records 16000 to 16099...
# Fetching records 16100 to 16199...
# Fetching records 16200 to 16299...
# Fetching records 16300 to 16399...
# Fetching records 16400 to 16499...
# Fetching records 16500 to 16599...
# Fetching records 16600 to 16699...
# Fetching records 16700 to 16799...
# Fetching records 16800 to 16899...
# Fetching records 16900 to 16999...
# Fetching records 17000 to 17099...
# Fetching records 17100 to 17199...
# Fetching records 17200 to 17299...
# Fetching records 17300 to 17399...
# Fetching records 17400 to 17499...
# Fetching records 17500 to 17599...
# Fetching records 17600 to 17699...
# Fetching records 17700 to 17799...
# Fetching records 17800 to 17899...
# Fetching records 17900 to 17999...
# Fetching records 18000 to 18099...
# Fetching records 18100 to 18199...
# Fetching records 18200 to 18299...
# Fetching records 18300 to 18399...
# Fetching records 18400 to 18499...
# Fetching records 18500 to 18599...
# Fetching records 18600 to 18699...
# Fetching records 18700 to 18799...
# Fetching records 18800 to 18899...
# Fetching records 18900 to 18999...
# Fetching records 19000 to 19099...
# Fetching records 19100 to 19199...
# Fetching records 19200 to 19299...
# Fetching records 19300 to 19399...
# Fetching records 19400 to 19499...
# Fetching records 19500 to 19599...
# Fetching records 19600 to 19699...
# Fetching records 19700 to 19799...
# Fetching records 19800 to 19899...
# Fetching records 19900 to 19999...
# Fetching records 20000 to 20099...
# Fetching records 20100 to 20199...
# Fetching records 20200 to 20299...
# Fetching records 20300 to 20399...
# Fetching records 20400 to 20499...
# Fetching records 20500 to 20599...
# Fetching records 20600 to 20699...
# Fetching records 20700 to 20799...
# Fetching records 20800 to 20899...
# Fetching records 20900 to 20999...
# Fetching records 21000 to 21099...
# Fetching records 21100 to 21199...
# Fetching records 21200 to 21299...
# Fetching records 21300 to 21399...
# Fetching records 21400 to 21499...
# Fetching records 21500 to 21599...
# Fetching records 21600 to 21699...
# Fetching records 21700 to 21799...
# Fetching records 21800 to 21899...
# Fetching records 21900 to 21999...
# Fetching records 22000 to 22099...
# Fetching records 22100 to 22199...
# Fetching records 22200 to 22299...
# Fetching records 22300 to 22399...
# Fetching records 22400 to 22499...
# Fetching records 22500 to 22599...
# Fetching records 22600 to 22699...
# Fetching records 22700 to 22799...
# Fetching records 22800 to 22899...
# Fetching records 22900 to 22999...
# Fetching records 23000 to 23099...
# Fetching records 23100 to 23199...
# Fetching records 23200 to 23299...
# Fetching records 23300 to 23399...
# Fetching records 23400 to 23499...
# Fetching records 23500 to 23599...
# Fetching records 23600 to 23699...
# Fetching records 23700 to 23799...
# Fetching records 23800 to 23899...
# Fetching records 23900 to 23999...
# Fetching records 24000 to 24099...
# Fetching records 24100 to 24199...
# Fetching records 24200 to 24299...
# Fetching records 24300 to 24399...
# Fetching records 24400 to 24499...
# Fetching records 24500 to 24599...
# Fetching records 24600 to 24699...
# Fetching records 24700 to 24799...
# Fetching records 24800 to 24899...
# Fetching records 24900 to 24999...
# Fetching records 25000 to 25099...
# Fetching records 25100 to 25199...
# Fetching records 25200 to 25299...
# Fetching records 25300 to 25399...
# Fetching records 25400 to 25499...
# Fetching records 25500 to 25599...
# Fetching records 25600 to 25699...
# Fetching records 25700 to 25799...
# Fetching records 25800 to 25899...
# Fetching records 25900 to 25999...
# Fetching records 26000 to 26099...
# Fetching records 26100 to 26199...
# Fetching records 26200 to 26299...
# Fetching records 26300 to 26399...
# Fetching records 26400 to 26499...
# Fetching records 26500 to 26599...
# Fetching records 26600 to 26699...
# Fetching records 26700 to 26799...
# Fetching records 26800 to 26899...
# Fetching records 26900 to 26999...
# Fetching records 27000 to 27099...
# Fetching records 27100 to 27199...
# Fetching records 27200 to 27299...
# Fetching records 27300 to 27399...
# Fetching records 27400 to 27499...
# Fetching records 27500 to 27599...
# Fetching records 27600 to 27699...
# Fetching records 27700 to 27799...
# Fetching records 27800 to 27899...
# Fetching records 27900 to 27999...
# Fetching records 28000 to 28099...
# Fetching records 28100 to 28199...
# Fetching records 28200 to 28299...
# Fetching records 28300 to 28399...
# Fetching records 28400 to 28499...
# Fetching records 28500 to 28599...
# Fetching records 28600 to 28699...
# Fetching records 28700 to 28799...
# Fetching records 28800 to 28899...
# Fetching records 28900 to 28999...
# Fetching records 29000 to 29099...
# Fetching records 29100 to 29199...
# Fetching records 29200 to 29299...
# Fetching records 29300 to 29399...
# Fetching records 29400 to 29499...
# Fetching records 29500 to 29599...
# Fetching records 29600 to 29699...
# Fetching records 29700 to 29799...
# Fetching records 29800 to 29899...
# Fetching records 29900 to 29999...
# Fetching records 30000 to 30099...
# Fetching records 30100 to 30199...
# Fetching records 30200 to 30299...
# Fetching records 30300 to 30399...
# Fetching records 30400 to 30499...
# Fetching records 30500 to 30599...
# Fetching records 30600 to 30699...
# Fetching records 30700 to 30799...
# Fetching records 30800 to 30899...
# Fetching records 30900 to 30999...
# Fetching records 31000 to 31099...
# Fetching records 31100 to 31199...
# Fetching records 31200 to 31299...
# Fetching records 31300 to 31399...
# Fetching records 31400 to 31499...
# Fetching records 31500 to 31599...
# Fetching records 31600 to 31699...
# Fetching records 31700 to 31799...
# Fetching records 31800 to 31899...
# Fetching records 31900 to 31999...
# Fetching records 32000 to 32099...
# Fetching records 32100 to 32199...
# Fetching records 32200 to 32299...
# Fetching records 32300 to 32399...
# Fetching records 32400 to 32499...
# Fetching records 32500 to 32599...
# Fetching records 32600 to 32699...
# Fetching records 32700 to 32799...
# Fetching records 32800 to 32899...
# Fetching records 32900 to 32999...
# Fetching records 33000 to 33099...
# Fetching records 33100 to 33199...
# Fetching records 33200 to 33299...
# Fetching records 33300 to 33399...
# Fetching records 33400 to 33499...
# Fetching records 33500 to 33599...
# Fetching records 33600 to 33699...
# Fetching records 33700 to 33799...
# Fetching records 33800 to 33899...
# Fetching records 33900 to 33999...
# Fetching records 34000 to 34099...
# Fetching records 34100 to 34199...
# Fetching records 34200 to 34299...
# Fetching records 34300 to 34399...
# Fetching records 34400 to 34499...
# Fetching records 34500 to 34599...
# Fetching records 34600 to 34699...
# Fetching records 34700 to 34799...
# Fetching records 34800 to 34899...
# Fetching records 34900 to 34999...
# Fetching records 35000 to 35099...
# Fetching records 35100 to 35199...
# Fetching records 35200 to 35299...
# Fetching records 35300 to 35399...
# Fetching records 35400 to 35499...
# Fetching records 35500 to 35599...
# Fetching records 35600 to 35699...
# Fetching records 35700 to 35799...
# Fetching records 35800 to 35899...
# Fetching records 35900 to 35999...
# Fetching records 36000 to 36099...
# Fetching records 36100 to 36199...
# Fetching records 36200 to 36299...
# Fetching records 36300 to 36399...
# Fetching records 36400 to 36499...
# Fetching records 36500 to 36599...
# Fetching records 36600 to 36699...
# Fetching records 36700 to 36799...
# Fetching records 36800 to 36899...
# Fetching records 36900 to 36999...
# Fetching records 37000 to 37099...
# Fetching records 37100 to 37199...
# Fetching records 37200 to 37299...
# Fetching records 37300 to 37399...
# Fetching records 37400 to 37499...
# Fetching records 37500 to 37599...
# Fetching records 37600 to 37699...
# Fetching records 37700 to 37799...
# Fetching records 37800 to 37899...
# Fetching records 37900 to 37999...
# Fetching records 38000 to 38099...
# Fetching records 38100 to 38199...
# Fetching records 38200 to 38299...
# Fetching records 38300 to 38399...
# Fetching records 38400 to 38499...
# Fetching records 38500 to 38599...
# Fetching records 38600 to 38699...
# Fetching records 38700 to 38799...
# Fetching records 38800 to 38899...
# Fetching records 38900 to 38999...
# Fetching records 39000 to 39099...
# Fetching records 39100 to 39199...
# Fetching records 39200 to 39299...
# Fetching records 39300 to 39399...
# Fetching records 39400 to 39499...
# Fetching records 39500 to 39599...
# Fetching records 39600 to 39699...
# Fetching records 39700 to 39799...
# Fetching records 39800 to 39899...
# Fetching records 39900 to 39999...
# Fetching records 40000 to 40099...
# Fetching records 40100 to 40199...
# Fetching records 40200 to 40299...
# Fetching records 40300 to 40399...
# Fetching records 40400 to 40499...
# Fetching records 40500 to 40599...
# Fetching records 40600 to 40699...
# Fetching records 40700 to 40799...
# Fetching records 40800 to 40899...
# Fetching records 40900 to 40999...
# Fetching records 41000 to 41099...
# Fetching records 41100 to 41199...
# Fetching records 41200 to 41299...
# Fetching records 41300 to 41399...
# Fetching records 41400 to 41499...
# Fetching records 41500 to 41599...
# Fetching records 41600 to 41699...
# Fetching records 41700 to 41799...
# Fetching records 41800 to 41899...
# Fetching records 41900 to 41999...
# Fetching records 42000 to 42099...
# Fetching records 42100 to 42199...
# Fetching records 42200 to 42299...
# Fetching records 42300 to 42399...
# Fetching records 42400 to 42499...
# Fetching records 42500 to 42599...
# Fetching records 42600 to 42699...
# Fetching records 42700 to 42799...
# Fetching records 42800 to 42899...
# Fetching records 42900 to 42999...
# Fetching records 43000 to 43099...
# Fetching records 43100 to 43199...
# Fetching records 43200 to 43299...
# Fetching records 43300 to 43399...
# Fetching records 43400 to 43499...
# Fetching records 43500 to 43599...
# Fetching records 43600 to 43699...
# Fetching records 43700 to 43799...
# Fetching records 43800 to 43899...
# Fetching records 43900 to 43999...
# Fetching records 44000 to 44099...
# Fetching records 44100 to 44199...
# Fetching records 44200 to 44299...
# Fetching records 44300 to 44399...
# Fetching records 44400 to 44499...
# Fetching records 44500 to 44599...
# Fetching records 44600 to 44699...
# Fetching records 44700 to 44799...
# Fetching records 44800 to 44899...
# Fetching records 44900 to 44999...
# Fetching records 45000 to 45099...
# Fetching records 45100 to 45199...
# Fetching records 45200 to 45299...
# Fetching records 45300 to 45399...
# Fetching records 45400 to 45499...
# Fetching records 45500 to 45599...
# Fetching records 45600 to 45699...
# Fetching records 45700 to 45799...
# Fetching records 45800 to 45899...
# Fetching records 45900 to 45999...
# Fetching records 46000 to 46099...
# Fetching records 46100 to 46199...
# Fetching records 46200 to 46299...
# Fetching records 46300 to 46399...
# Fetching records 46400 to 46499...
# Fetching records 46500 to 46599...
# Fetching records 46600 to 46699...
# Fetching records 46700 to 46799...
# Fetching records 46800 to 46899...
# Fetching records 46900 to 46999...
# Fetching records 47000 to 47099...
# Fetching records 47100 to 47199...
# Fetching records 47200 to 47299...
# Fetching records 47300 to 47399...
# Fetching records 47400 to 47499...
# Fetching records 47500 to 47599...
# Fetching records 47600 to 47699...
# Fetching records 47700 to 47799...
# Fetching records 47800 to 47899...
# Fetching records 47900 to 47999...
# Fetching records 48000 to 48099...
# Fetching records 48100 to 48199...
# Fetching records 48200 to 48299...
# Fetching records 48300 to 48399...
# Fetching records 48400 to 48499...
# Fetching records 48500 to 48599...
# Fetching records 48600 to 48699...
# Fetching records 48700 to 48799...
# Fetching records 48800 to 48899...
# Fetching records 48900 to 48999...
# Fetching records 49000 to 49099...
# Fetching records 49100 to 49199...
# Fetching records 49200 to 49299...
# Fetching records 49300 to 49399...
# Fetching records 49400 to 49499...
# Fetching records 49500 to 49599...
# Fetching records 49600 to 49699...
# Fetching records 49700 to 49799...
# Fetching records 49800 to 49899...
# Fetching records 49900 to 49999...
# Fetching records 50000 to 50099...
# Fetching records 50100 to 50199...
# Fetching records 50200 to 50299...
# Fetching records 50300 to 50399...
# Fetching records 50400 to 50499...
# Fetching records 50500 to 50599...
# Fetching records 50600 to 50699...
# Fetching records 50700 to 50799...
# Fetching records 50800 to 50899...
# Fetching records 50900 to 50999...
# Fetching records 51000 to 51099...
# Fetching records 51100 to 51199...
# Fetching records 51200 to 51299...
# Fetching records 51300 to 51399...
# Fetching records 51400 to 51499...
# Fetching records 51500 to 51599...
# Fetching records 51600 to 51699...
# Fetching records 51700 to 51799...
# Fetching records 51800 to 51899...
# Fetching records 51900 to 51999...
# Fetching records 52000 to 52099...
# Fetching records 52100 to 52199...
# Fetching records 52200 to 52299...
# Fetching records 52300 to 52399...
# Fetching records 52400 to 52499...
# Fetching records 52500 to 52599...
# Fetching records 52600 to 52699...
# Fetching records 52700 to 52799...
# Fetching records 52800 to 52899...
# Fetching records 52900 to 52999...
# Fetching records 53000 to 53099...
# Fetching records 53100 to 53199...
# Fetching records 53200 to 53299...
# Fetching records 53300 to 53399...
# Fetching records 53400 to 53499...
# Fetching records 53500 to 53599...
# Fetching records 53600 to 53699...
# Fetching records 53700 to 53799...
# Fetching records 53800 to 53899...
# Fetching records 53900 to 53999...
# Fetching records 54000 to 54099...
# Fetching records 54100 to 54199...
# Fetching records 54200 to 54299...
# Fetching records 54300 to 54399...
# Fetching records 54400 to 54499...
# Fetching records 54500 to 54599...
# Fetching records 54600 to 54699...
# Fetching records 54700 to 54799...
# Fetching records 54800 to 54899...
# Fetching records 54900 to 54999...
# Saved 55000 records to harvested_data/ckan_data_gov_uk_package_search.csv
