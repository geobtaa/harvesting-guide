# %%
import csv
import os
import re
import requests
from urllib.parse import urlparse
import mimetypes

# %%
def get_extension(response, url):
    """
    Determine the file extension.
    1. Try to extract the filename from the 'Content-Disposition' header.
    2. If not available, try to guess from the 'Content-Type' header.
    3. As a fallback, extract the extension from the URL.
    """
    # Option 1: Check Content-Disposition header
    cd = response.headers.get('Content-Disposition')
    if cd:
        fname = re.findall('filename="([^"]+)"', cd)
        if fname:
            return os.path.splitext(fname[0])[1]
    
    # Option 2: Guess from Content-Type header
    content_type = response.headers.get('Content-Type')
    if content_type:
        ext = mimetypes.guess_extension(content_type.split(';')[0])
        if ext:
            return ext
    
    # Option 3: Use the extension from the URL path
    parsed_url = urlparse(url)
    _, ext = os.path.splitext(parsed_url.path)
    return ext

def download_file(url, base_filename, output_dir):
    """
    Downloads the file from the provided URL and saves it using the given base_filename.
    """
    try:
        response = requests.get(url, stream=True)
        response.raise_for_status()
        
        # Determine the extension for the file
        extension = get_extension(response, url)
        full_filename = f"{base_filename}{extension}"
        file_path = os.path.join(output_dir, full_filename)
        
        # Download and save the file in chunks
        with open(file_path, 'wb') as f:
            for chunk in response.iter_content(chunk_size=8192):
                if chunk:
                    f.write(chunk)
        print(f"Downloaded {url} to {file_path}")
    except Exception as e:
        print(f"Error downloading {url}: {e}")

def main(csv_file, output_dir):
    # Create output directory if it does not exist
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    # Open the CSV file
    with open(csv_file, newline='', encoding='utf-8') as f:
        reader = csv.DictReader(f)
        for row in reader:
            # Adjust these keys if your CSV uses different headers
            file_id = row['ID']
            download_url = row['DownloadLink']
            download_file(download_url, file_id, output_dir)

# Set your CSV file path and output directory here:
csv_file = '1000-1011-downloads.csv'  # Replace with your CSV filename or path
output_dir = 'downloads'  # Replace with your desired output directory

# Run the main function to download the files
main(csv_file, output_dir)
# Out:
# Downloaded https://gis-fema.hub.arcgis.com/api/download/v1/items/2adcad8079ac4e8f879b68d6d8aab15b/shapefile?layers=0 to downloads/2adcad8079ac4e8f879b68d6d8aab15b_0.zip
# Downloaded https://gis-fema.hub.arcgis.com/api/download/v1/items/5e715669590a4e009519716d8fcd0a3c/shapefile?layers=0 to downloads/5e715669590a4e009519716d8fcd0a3c_0.zip
# Downloaded https://gis-fema.hub.arcgis.com/api/download/v1/items/0c6359b9e85645b9bed92e25b0edf763/shapefile?layers=0 to downloads/0c6359b9e85645b9bed92e25b0edf763_0.zip
# Error downloading https://gis-fema.hub.arcgis.com/api/download/v1/items/4b6238f3623547eebc614226f0356828/shapefile?layers=0: 500 Server Error: Internal Server Error for url: https://gis-fema.hub.arcgis.com/api/download/v1/items/4b6238f3623547eebc614226f0356828/shapefile?layers=0
# Downloaded https://gis-fema.hub.arcgis.com/api/download/v1/items/4b6238f3623547eebc614226f0356828/shapefile?layers=1 to downloads/4b6238f3623547eebc614226f0356828_1.zip
# Downloaded https://gis-fema.hub.arcgis.com/api/download/v1/items/4b6238f3623547eebc614226f0356828/shapefile?layers=2 to downloads/4b6238f3623547eebc614226f0356828_2.zip
# Downloaded https://gis-fema.hub.arcgis.com/api/download/v1/items/64d5eb131a374c7dbe8f821ae71d2215/shapefile?layers=0 to downloads/64d5eb131a374c7dbe8f821ae71d2215_0.zip
# Downloaded https://gis-fema.hub.arcgis.com/api/download/v1/items/4d028196e9f64c4888c57f6d53981dab/shapefile?layers=0 to downloads/4d028196e9f64c4888c57f6d53981dab_0.zip
# Downloaded https://gis-fema.hub.arcgis.com/api/download/v1/items/628ea97ce5774fa9bcbbf6206029c9ad/shapefile?layers=0 to downloads/628ea97ce5774fa9bcbbf6206029c9ad_0.zip
# Downloaded https://gis-fema.hub.arcgis.com/api/download/v1/items/910089de7b5c402cb915c519662887cd/shapefile?layers=0 to downloads/910089de7b5c402cb915c519662887cd_0.bin
# Downloaded https://gis-fema.hub.arcgis.com/api/download/v1/items/7add98e882ec4442931e63b29f2d3b94/shapefile?layers=0 to downloads/7add98e882ec4442931e63b29f2d3b94_0.zip
# Downloaded https://gis-fema.hub.arcgis.com/api/download/v1/items/dfd0253d12504eb09ab84613d7cb6c47/shapefile?layers=0 to downloads/dfd0253d12504eb09ab84613d7cb6c47_0.zip
# Downloaded https://gis-fema.hub.arcgis.com/api/download/v1/items/6e17446731b14c7b91f92beff65fff06/shapefile?layers=0 to downloads/6e17446731b14c7b91f92beff65fff06_0.zip
# Downloaded https://gis-fema.hub.arcgis.com/api/download/v1/items/d633d2b2a0a44e53ac7b5cd865dd15b4/shapefile?layers=0 to downloads/d633d2b2a0a44e53ac7b5cd865dd15b4_0.zip
# Downloaded https://gis-fema.hub.arcgis.com/api/download/v1/items
json
# Downloaded https://gis-fema.hub.arcgis.com/api/download/v1/items/98823d943a16441ca36709e3b2de9393/shapefile?layers=312 to downloads/98823d943a16441ca36709e3b2de9393_312.json
# Downloaded https://gis-fema.hub.arcgis.com/api/download/v1/items/98823d943a16441ca36709e3b2de9393/shapefile?layers=313 to downloads/98823d943a16441ca36709e3b2de9393_313.json
# Downloaded https://gis-fema.hub.arcgis.com/api/download/v1/items/57b5d74f27c94981804d52518ee4a5df/shapefile?layers=5 to downloads/57b5d74f27c94981804d52518ee4a5df_5.json
# Downloaded https://gis-fema.hub.arcgis.com/api/download/v1/items/68f971bc9bc14df8a817ef92aa930fda/shapefile?layers=0 to downloads/68f971bc9bc14df8a817ef92aa930fda_0.zip
# Downloaded https://gis-fema.hub.arcgis.com/api/download/v1/items/57b5d74f27c94981804d52518ee4a5df/shapefile?layers=6 to downloads/57b5d74f27c94981804d52518ee4a5df_6.json
# Downloaded https://gis-fema.hub.arcgis.com/api/download/v1/items/98823d943a16441ca36709e3b2de9393/shapefile?layers=314 to downloads/98823d943a16441ca36709e3b2de9393_314.json
# Error downloading https://gis-fema.hub.arcgis.com/api/download/v1/items/98823d943a16441ca36709e3b2de9393/shapefile?layers=0: 500 Server Error: Internal Server Error for url: https://gis-fema.hub.arcgis.com/api/download/v1/items/98823d943a16441ca36709e3b2de9393/shapefile?layers=0
# Downloaded https://gis-fema.hub.arcgis.com/api/download/v1/items/98823d943a16441ca36709e3b2de9393/shapefile?layers=1 to downloads/98823d943a16441ca36709e3b2de9393_1.json
# Downloaded https://gis-fema.hub.arcgis.com/api/download/v1/items/98823d943a16441ca36709e3b2de9393/shapefile?layers=10 to downloads/98823d943a16441ca36709e3b2de9393_10.json
# Downloaded https://gis-fema.hub.arcgis.com/api/download/v1/items/98823d943a16441ca36709e3b2de9393/shapefile?layers=100 to downloads/98823d943a16441ca36709e3b2de9393_100.json
# Downloaded https://gis-fema.hub.arcgis.com/api/download/v1/items/98823d943a16441ca36709e3b2de9393/shapefile?layers=101 to downloads/98823d943a16441ca36709e3b2de9393_101.json
# Downloaded https://gis-fema.hub.arcgis.com/api/download/v1/items/57b5d74f27c94981804d52518ee4a5df/shapefile?layers=7 to downloads/57b5d74f27c94981804d52518ee4a5df_7.json
# Downloaded https://gis-fema.hub.arcgis.com/api/download/v1/items/98823d943a16441ca36709e3b2de9393/shapefile?layers=315 to downloads/98823d943a16441ca36709e3b2de9393_315.json
# Downloaded https://gis-fema.hub.arcgis.com/api/download/v1/items/98823d943a16441ca36709e3b2de9393/shapefile?layers=102 to downloads/98823d943a16441ca36709e3b2de9393_102.json
# Downloaded https://gis-fema.hub.arcgis.com/api/download/v1/items/98823d943a16441ca36709e3b2de9393/shapefile?layers=103 to downloads/98823d943a16441ca36709e3b2de9393_103.json
# Downloaded https://gis-fema.hub.arcgis.com/api/download/v1/items/98823d943a16441ca36709e3b2de9393/shapefile?layers=104 to downloads/98823d943a16441ca36709e3b2de9393_104.json
# Downloaded https://gis-fema.hub.arcgis.com/api/download/v1/items/98823d943a16441ca36709e3b2de9393/shapefile?layers=105 to downloads/98823d943a16441ca36709e3b2de9393_105.json
# Downloaded https://gis-fema.hub.arcgis.com/api/download/v1/items/98823d943a16441ca36709e3b2de9393/shapefile?layers=106 to downloads/98823d943a16441ca36709e3b2de9393_106.json
# Downloaded https://gis-fema.hub.arcgis.com/api/download/v1/items/98823d943a16441ca36709e3b2de9393/shapefile?layers=107 to downloads/98823d943a16441ca36709e3b2de9393_107.json
# Downloaded https://gis-fema.hub.arcgis.com/api/download/v1/items/98823d943a16441ca36709e3b2de9393/shapefile?layers=108 to downloads/98823d943a16441ca36709e3b2de9393_108.json
# Downloaded https://gis-fema.hub.arcgis.com/api/download/v1/items/98823d943a16441ca36709e3b2de9393/shapefile?layers=109 to downloads/98823d943a16441ca36709e3b2de9393_109.json
# Downloaded https://gis-fema.hub.arcgis.com/api/download/v1/items/98823d943a16441ca36709e3b2de9393/shapefile?layers=11 to downloads/98823d943a16441ca36709e3b2de9393_11.json
# Downloaded https://gis-fema.hub.arcgis.com/api/download/v1/items/98823d943a16441ca36709e3b2de9393/shapefile?layers=110 to downloads/98823d943a16441ca36709e3b2de9393_110.json
# Downloaded https://gis-fema.hub.arcgis.com/api/download/v1/items/98823d943a16441ca36709e3b2de9393/shapefile?layers=111 to downloads/98823d943a16441ca36709e3b2de9393_111.json
# Downloaded https://gis-fema.hub.arcgis.com/api/download/v1/items/98823d943a16441ca36709e3b2de9393/shapefile?layers=112 to downloads/98823d943a16441ca36709e3b2de9393_112.json
# Downloaded https://gis-fema.hub.arcgis.com/api/download/v1/items/98823d943a16441ca36709e3b2de9393/shapefile?layers=113 to downloads/98823d943a16441ca36709e3b2de9393_113.json
# Downloaded https://gis-fema.hub.arcgis.com/api/download/v1/items/98823d943a16441ca36709e3b2de9393/shapefile?layers=114 to downloads/98823d943a16441ca36709e3b2de9393_114.json
# Downloaded https://gis-fema.hub.arcgis.com/api/download/v1/items/98823d943a16441ca36709e3b2de9393/shapefile?layers=115 to downloads/98823d943a16441ca36709e3b2de9393_115.json
# Downloaded https://gis-fema.hub.arcgis.com/api/download/v1/items/98823d943a16441ca36709e3b2de9393/shapefile?layers=116 to downloads/98823d943a16441ca36709e3b2de9393_116.json
# Downloaded https://gis-fema.hub.arcgis.com/api/download/v1/items/57b5d74f27c94981804d52518ee4a5df/shapefile?layers=8 to downloads/57b5d74f27c94981804d52518ee4a5df_8.json
# Downloaded https://gis-fema.hub.arcgis.com/api/download/v1/items/98823d943a16441ca36709e3b2de9393/shapefile?layers=316 to downloads/98823d943a16441ca36709e3b2de9393_316.json
# Downloaded https://gis-fema.hub.arcgis.com/api/download/v1/items/98823d943a16441ca36709e3b2de9393/shapefile?layers=117 to downloads/98823d943a16441ca36709e3b2de9393_117.json
# Downloaded https://gis-fema.hub.arcgis.com/api/download/v1/items/98823d943a16441ca36709e3b2de9393/shapefile?layers=118 to downloads/98823d943a16441ca36709e3b2de9393_118.json
# Error downloading https://gis-fema.hub.arcgis.com/api/download/v1/items/98823d943a16441ca36709e3b2de9393/shapefile?layers=119: 400 Client Error: Bad Request for url: https://gis-fema.hub.arcgis.com/api/download/v1/items/98823d943a16441ca36709e3b2de9393/shapefile?layers=119
# Downloaded https://gis-fema.hub.arcgis.com/api/download/v1/items/98823d943a16441ca36709e3b2de9393/shapefile?layers=12 to downloads/98823d943a16441ca36709e3b2de9393_12.json
# Error downloading https://gis-fema.hub.arcgis.com/api/download/v1/items/98823d943a16441ca36709e3b2de9393/shapefile?layers=120: 400 Client Error: Bad Request for url: https://gis-fema.hub.arcgis.com/api/download/v1/items/98823d943a16441ca36709e3b2de9393/shapefile?layers=120
# Downloaded https://gis-fema.hub.arcgis.com/api/download/v1/items/98823d943a16441ca36709e3b2de9393/shapefile?layers=121 to downloads/98823d943a16441ca36709e3b2de9393_121.json
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 68
#      65 output_dir = 'downloads'  # Replace with your desired output directory
#      67 # Run the main function to download the files
# ---> 68 main(csv_file, output_dir)
#
# Cell In[3], line 61, in main(csv_file, output_dir)
#      59 file_id = row['ID']
#      60 download_url = row['DownloadLink']
# ---> 61 download_file(download_url, file_id, output_dir)
#
# Cell In[3], line 32, in download_file(url, base_filename, output_dir)
#      28 """
#      29 Downloads the file from the provided URL and saves it using the given base_filename.
#      30 """
#      31 try:
# ---> 32     response = requests.get(url, stream=True)
#      33     response.raise_for_status()
#      35     # Determine the extension for the file
#
# File ~/opt/anaconda3/envs/notebooks/lib/python3.10/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/opt/anaconda3/envs/notebooks/lib/python3.10/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/opt/anaconda3/envs/notebooks/lib/python3.10/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/opt/anaconda3/envs/notebooks/lib/python3.10/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/opt/anaconda3/envs/notebooks/lib/python3.10/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~/opt/anaconda3/envs/notebooks/lib/python3.10/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File ~/opt/anaconda3/envs/notebooks/lib/python3.10/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/opt/anaconda3/envs/notebooks/lib/python3.10/site-packages/urllib3/connection.py:507, in HTTPConnection.getresponse(self)
#     504 from .response import HTTPResponse
#     506 # Get the response from http.client.HTTPConnection
# --> 507 httplib_response = super().getresponse()
#     509 try:
#     510     assert_header_parsing(httplib_response.msg)
#
# File ~/opt/anaconda3/envs/notebooks/lib/python3.10/http/client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File ~/opt/anaconda3/envs/notebooks/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~/opt/anaconda3/envs/notebooks/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~/opt/anaconda3/envs/notebooks/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File ~/opt/anaconda3/envs/notebooks/lib/python3.10/ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File ~/opt/anaconda3/envs/notebooks/lib/python3.10/ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:
