# %% [markdown]
# This script takes a plain text file in FGDC and extracts the Attribute labels, definitions, and sources. This is useful only for FGDC files that were shared as plain text. (Mostly common practice only in 1990s-early 2000s).

# %%
import re
import csv

# Path to your plain text file
text_file_path = 'Sand_Gravel_Pits_Abandoned_IN.txt'

# Output CSV file path
csv_file_path = 'output.csv'

# Read the text file
with open(text_file_path, 'r', encoding='utf-8') as file:
    text_data = file.read()

# Regular expression pattern to match each Attribute section with more flexible handling of whitespace
attribute_pattern = re.compile(
    r'Attribute:\s*'
    r'Attribute_Label:\s*(.*?)\s*'
    r'Attribute_Definition:\s*(.*?)\s*'
    r'Attribute_Definition_Source:\s*([^\n\r]*)',  # Capture everything up to the next newline
    re.DOTALL | re.MULTILINE
)

# Find all matches
matches = attribute_pattern.findall(text_data)

# Debugging: Print the number of matches found
print(f'\nTotal Attribute sections found: {len(matches)}')
# Out:
# Total Attribute sections found: 45

# %%
# List to store the extracted values
data = []

# Loop through each match and extract the needed values
for i, match in enumerate(matches):
    label, definition, source = match
    # Print debugging information about the source field
    print(f'\nMatch #{i+1}:')
    print(f'Label: {label.strip()}')
    print(f'Definition: {definition.strip()}')
    print(f'Source: {source.strip()} (Captured Source)')

    # Append the extracted values to the list
    data.append([label.strip(), definition.strip(), source.strip()])

# Write the extracted data to a CSV file
with open(csv_file_path, 'w', newline='', encoding='utf-8') as csvfile:
    csv_writer = csv.writer(csvfile)
    # Write the header
    csv_writer.writerow(['Attribute_Label', 'Attribute_Definition', 'Attribute_Definition_Source'])
    # Write the data rows
    csv_writer.writerows(data)

print(f'\nExtraction complete. Data saved to {csv_file_path}')
# Out:
# Match #1:
# Label: Count
# Definition: Auto number assigned by Access
# Source: IGS Memorandum Report 98 (Captured Source)
#
# Match #2:
# Label: Sgnum
# Definition: Database number
# Source: IGS Memorandum Report 98 (Captured Source)
#
# Match #3:
# Label: Qtr
# Definition: Quartering of section
# Source: IGS Memorandum Report 98 (Captured Source)
#
# Match #4:
# Label: Qtr3
# Definition: Smallest quarter of section
# Source: IGS, Paul Irwin (Captured Source)
#
# Match #5:
# Label: Qtr2
# Definition: Intermediate quarter of section
# Source: IGS, Paul Irwin (Captured Source)
#
# Match #6:
# Label: Qtr1
# Definition: Largest quarter of section
# Source: IGS, Paul Irwin (Captured Source)
#
# Match #7:
# Label: Cnty
# Definition: County
# Source: IGS Memorandum Report 98 (Captured Source)
#
# Match #8:
# Label: Quad
# Definition: Name of USGS 7.5-minute quadrangle
# Source: IGS Memorandum Report 98 (Captured Source)
#
# Match #9:
# Label: Date_
# Definition: Date data was recorded
# Source: IGS Memorandum Report 98 (Captured Source)
#
# Match #10:
# Label: Styp
# Definition: Survey type
# Source: IGS Memorandum Report 98 (Captured Source)
#
# Match #11:
# Label: Snum
# Definition: Survey number
# Source: IGS Memorandum Report 98 (Captured Source)
#
# Match #12:
# Label: Tnum
# Definition: Township number
# Source: IGS Memorandum Report 98 (Captured Source)
#
# Match #13:
# Label: Tdir
# Definition: Township direction
# Source: IGS Memorandum Report 98 (Captured Source)
#
# Match #14:
# Label: Rnum
# Definition: Range number
# Source: IGS Memorandum Report 98 (Captured Source)
#
# Match #15:
# Label: Rdir
# Definition: Range direction
# Source: IGS Memorandum Report 98 (Captured Source)
#
# Match #16:
# Label: Dpth
# Definition: Depth of pit (interpreted)
# Source: IGS Memorandum Report 98 (Captured Source)
#
# Match #17:
# Label: Dpthnt
# Definition: Depth note, observed depth of pit
# Source: IGS Memorandum Report 98 (Captured Source)
#
# Match #18:
# Label: Acres
# Definition: Area of pit in acres derived from "Size"
# Source: IGS Memorandum Report 98 (Captured Source)
#
# Match #19:
# Label: Sizent
# Definition: Size note, description of pit size
# Source: IGS Memorandum Report 98 (Captured Source)
#
# Match #20:
# Label: Size
# Definition: Size, observed size of pit
# Source: IGS Memorandum Report 98 (Captured Source)
#
# Match #21:
# Label: Obdn
# Definition: Overburden thickness derived from "Obdnnt"
# Source: IGS Memorandum Report 98 (Captured Source)
#
# Match #22:
# Label: Obdnnt
# Definition: Overburden note, observed overburden thickness
# Source: IGS Memorandum Report 98 (Captured Source)
#
# Match #23:
# Label: Sdgvthk
# Definition: Sand and gravel thickness, derived from "Sdgvthknt"
# Source: IGS Memorandum Report 98 (Captured Source)
#
# Match #24:
# Label: Sdgvthknt
# Definition: Sand and gravel note, observed sand and gravel thickness
# Source: IGS Memorandum Report 98 (Captured Source)
#
# Match #25:
# Label: Location
# Definition: Description of location
# Source: IGS Memorandum Report 98 (Captured Source)
#
# Match #26:
# Label: Company
# Definition: Company name
# Source: IGS Memorandum Report 98 (Captured Source)
#
# Match #27:
# Label: Pitnme
# Definition: Pit name
# Source: IGS Memorandum Report 98 (Captured Source)
#
# Match #28:
# Label: Address
# Definition: Address
# Source: IGS Memorandum Report 98 (Captured Source)
#
# Match #29:
# Label: Management
# Definition: Management
# Source: IGS Memorandum Report 98 (Captured Source)
#
# Match #30:
# Label: Coown
# Definition: Company owner
# Source: IGS Memorandum Report 98 (Captured Source)
#
# Match #31:
# Label: Lndown
# Definition: Land owner
# Source: IGS Memorandum Report 98 (Captured Source)
#
# Match #32:
# Label: Acreage
# Definition: Acreage, presumed to be land holdings not pit area
# Source: IGS Memorandum Report 98 (Captured Source)
#
# Match #33:
# Label: Products
# Definition: Products
# Source: IGS Memorandum Report 98 (Captured Source)
#
# Match #34:
# Label: Dayprod
# Definition: Daily production
# Source: IGS Memorandum Report 98 (Captured Source)
#
# Match #35:
# Label: Prod1948
# Definition: Production in 1948
# Source: IGS Memorandum Report 98 (Captured Source)
#
# Match #36:
# Label: Cumton
# Definition: Cumulative tons of production derived from "Cumyds"
# Source: IGS Memorandum Report 98 (Captured Source)
#
# Match #37:
# Label: Cumyds
# Definition: Cumulative yards produced
# Source: IGS Memorandum Report 98 (Captured Source)
#
# Match #38:
# Label: Cumulative
# Definition: Cumulative production stated in various units
# Source: IGS Memorandum Report 98 (Captured Source)
#
# Match #39:
# Label: Capacity
# Definition: Daily capacity
# Source: IGS Memorandum Report 98 (Captured Source)
#
# Match #40:
# Label: Geologist
# Definition: Geologist who made observations
# Source: IGS Memorandum Report 98 (Captured Source)
#
# Match #41:
# Label: Source
# Definition: Source of some or all of recorded data
# Source: IGS Memorandum Report 98 (Captured Source)
#
# Match #42:
# Label: Dateopn
# Definition: Date opened
# Source: IGS Memorandum Report 98 (Captured Source)
#
# Match #43:
# Label: Dateclo
# Definition: Date closed
# Source: IGS Memorandum Report 98 (Captured Source)
#
# Match #44:
# Label: Wet
# Definition: Pit condition (wet)
# Source: IGS Memorandum Report 98 (Captured Source)
#
# Match #45:
# Label: Dry
# Definition: Pit condition (dry)
# Source: IGS Memorandum Report 98 (Captured Source)
#
# Extraction complete. Data saved to output.csv
