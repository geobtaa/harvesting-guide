# %% [markdown]
# ## Purpose
#
# To parse an XML file of MODs metadata from Michigan State University Digital Repository (https://d.lib.msu.edu/maps) and convert it to a CSV

# %%
import time
import re
import pandas as pd
import xml.etree.ElementTree as ET

action_date = time.strftime('%Y%m%d')

# %% [markdown]
# ## Part 1: download the metadata

# %%
def fetch_records(base_url, metadata_prefix, set_spec):
    records = []
    payload = {
        'verb': 'ListRecords',
        'metadataPrefix': metadata_prefix,
        'set': set_spec
    }
    
    while True:
        response = requests.get(base_url, params=payload)

        if response.status_code == 200:
            root = ET.fromstring(response.content)

            for record in root.findall(".//{http://www.openarchives.org/OAI/2.0/}record"):
                records.append(record)
            # Check for a resumptionToken
            token = root.find(".//{http://www.openarchives.org/OAI/2.0/}resumptionToken")
            if token is not None and token.text is not None:
                payload = {
                    'verb': 'ListRecords',
                    'resumptionToken': token.text
                }
            else:
                break   # Break out of the loop if there are no more records to fetch

        else:
            print(f"Failed to fetch records: {response.content}")
            break

    print(f"Fetched {len(records)} records.")
    return records

base_url = "https://d.lib.msu.edu/oai"
metadata_prefix = "mods"
set_spec = "maps"

all_records = fetch_records(base_url, metadata_prefix, set_spec)
# Out:
# Fetched 1224 records.

# %%
from xml.etree.ElementTree import ElementTree, Element, SubElement, tostring, ElementTree
import xml.dom.minidom

# Create the root element
root = Element("AllRecords")

# Append each record to the root element
for record in all_records:
    root.append(record)

# Use ElementTree to convert it into a string and prettify the XML
rough_string = tostring(root, "utf-8")
reparsed = xml.dom.minidom.parseString(rough_string)
pretty_string = reparsed.toprettyxml(indent="\t")

# Write to XML file
with open("all_records.xml", "w") as f:
    f.write(pretty_string)

print("Successfully written to all_records.xml!")
# Out:
# Successfully written to all_records.xml!

# %% [markdown]
# ## Part 2: Process the XML file

# %%
# Add the namespace for OAI
namespaces = {
    'ns0': 'http://www.openarchives.org/OAI/2.0/',
    'ns1': 'http://www.loc.gov/mods/v3',  # Changed from 'mods' to 'ns1'
    'ns2': 'http://www.w3.org/1999/xlink'  # Changed from 'xlink' to 'ns2'
}

# %%
xml_file = "all_records.xml"
# csv_file = action_date + "_05d-01.csv"
csv_file = "20231011_06d-01.csv"

# %%
def parse_XML(xml_file):
    # Parse the XML file
    tree = ET.parse(xml_file)
    root = tree.getroot()

    # Adjust the search to navigate through the OAI namespace
#     records = root.findall(".//oai:record", namespaces)
    records = root.findall(".//ns0:record", namespaces)
    
    rows = []
    for record in records:
        
        setSpecs = record.findall(".//ns0:setSpec", namespaces)
        
        additional_setSpec = None  # Initialize to None for each record

        # Check for additional setSpec
        for spec in setSpecs:
            if spec.text != 'maps':
                additional_setSpec = spec.text
                break  # Exit loop once the additional setSpec is found
        
        
        header = record.find(".//ns0:header", namespaces)
        identifier = header.find(".//ns0:identifier", namespaces)
        
#         metadata = record.find(".//mods:mods", namespaces)
        metadata = record.find(".//ns1:mods", namespaces)
        title = metadata.find(".//ns1:title", namespaces)
        names = metadata.findall(".//ns1:namePart", namespaces)
        publishers = metadata.findall(".//ns1:publisher", namespaces)
        issued_dates = metadata.findall(".//ns1:dateIssued", namespaces)
        temporal_dates = metadata.findall(".//ns1:dateOther", namespaces)
        
        
        language_code = record.find(".//ns1:languageTerm[@type='code']", namespaces)
        rights = record.find(".//ns1:accessCondition", namespaces)
        spatial = record.find(".//ns1:coordinates", namespaces)
        
        
        # Find the URL with note attribute 'ark' under location
        url_element = record.find(".//ns1:location/ns1:url[@note='ark']", namespaces)
        
        # Extract the URL text if the element is found
        url_text = url_element.text if url_element is not None else None

    

        # find all unique place names
        geographics = record.findall(".//ns1:geographic", namespaces)
        place_names = list(set([geo.text for geo in geographics]))
        
        # find all unique topics
        topics = record.findall(".//ns1:topic", namespaces)
        keywords = list(set([topic.text for topic in topics]))
        
        # description fields
        extents = metadata.findall(".//ns1:extent", namespaces)
        abstracts = metadata.findall(".//ns1:abstract", namespaces)
        notes = metadata.findall(".//ns1:note", namespaces)
        scale = metadata.findall(".//ns1:scale", namespaces)
        
        
        
        # Extract individual elements, these will return lists of elements


            # Create an empty list to hold description parts
        description_parts = []

        # Add parts to the list only if they have some content
        if extents:
            extents_str = "|".join([extent.text for extent in extents])
            description_parts.append(f"Extent: {extents_str}")
        if abstracts:
            abstracts_str = "|".join([abstract.text for abstract in abstracts])
            description_parts.append(f"Abstract: {abstracts_str}")
        if notes:
            notes_str = "|".join([note.text for note in notes])
            description_parts.append(f"Notes: {notes_str}")
        if scale:
            scale_str = "|".join([sc.text for sc in scale])
            description_parts.append(f"{scale_str}")

        # Join the parts into the complete description string
        description = " | ".join(description_parts)

        row = {
            "Identifier": identifier.text,
            "Title": title.text,
            "Description": description,
            "Rights": rights.text,
            "Creator": "|".join([name.text for name in names]) if names else None,
            "Publisher": "|".join([publisher.text for publisher in publishers]) if publishers else None,
            "Date Issued": "|".join([issued_date.text for issued_date in issued_dates]) if issued_dates else None,
            "Temporal Coverage": "|".join([temporal_date.text for temporal_date in temporal_dates]) if temporal_dates else None,
            "Language": language_code.text if language_code is not None else None,
            "Spatial Coverage": "|".join(place_names),
            "Subject": "|".join(keywords),
            "Coordinates": spatial.text if spatial is not None else None,
            "Ark": url_text,
            "additional_setSpec": additional_setSpec  # Add additional setSpec here

     
        }
        
        rows.append(row)
        
    out_df = pd.DataFrame(rows)
        
    return out_df

# Continue with the rest of the code to load the XML file and print the result
df = parse_XML(xml_file)

# %%
print(df.additional_setSpec.to_string(index=False))
# Out:
#           None
#           None
#   maps:maps_96
#           None
#           None
#           None
#           None
#           None
#           None
#           None
#           None
#           None
#           None
#   maps:maps_96
#           None
#           None
#           None
#           None
#           None
#           None
#           None
#           None
#           None
#   maps:maps_96
#           None
#           None
#           None
#   maps:maps_96
#           None
#           None
#           None
#           None
#           None
#   maps:maps_96
#           None
#           None
#           None
#   maps:maps_96
#           None
#           None
#           None
#           None
#   maps:maps_96
#           None
#           None
#           None
#           None
#           None
#           None
#   maps:maps_96
#           None
#           None
#           None
#   maps:maps_96
#           None
#           None
#           None
#   maps:maps_96
#           None
#           None
#           None
#           None
#           None
#   maps:maps_96
#           None
#           None
#           None
#           None
#   maps:maps_96
#           None
#           None
#           None
#           None
#           None
#   maps:maps_96
#           None
#           None
#           None
#           None
#           None
#           None
#           None
#           None
#           None
#           None
#  maps:maps_113
#           None
#           None
#           None
#           None
#  maps:maps_113
#           None
#           None
#           None
#           None
#           None
#  maps:maps_113
#           None
#           None
#           None
#           None
#  maps:maps_113
#           None
#           None
#           None
#           None
#  maps:maps_113
#           None
#           None
#           None
#           None
#           None
#  maps:maps_113
#           None
#           None
#           None
#           None
#           None
#  maps:maps_113
#           None
#           None
#           None
#           None
#  maps:maps_113
#           None
#           None
#           None
#           None
#  maps:maps_113
# maps:maps_1219
# maps:maps_1219
# maps:maps_1219
# maps:maps_1219
# maps:maps_1219
# maps:maps_1219
# maps:maps_1219
# maps:maps_1219
# maps:maps_1219
# maps:maps_1219
#  maps:maps_113
# maps:maps_1219
# maps:maps_1219
# maps:maps_1219
# maps:maps_1219
# maps:maps_1219
# maps:maps_1219
# maps:maps_1219
# maps:maps_1219
# maps:maps_1219
# maps:maps_1219
#  maps:maps_113
# maps:maps_1219
# maps:maps_1219
# maps:maps_1219
# maps:maps_1219
#           None
# maps:maps_1244
# maps:maps_1244
# maps:maps_1244
# maps:maps_1244
# maps:maps_1244
#  maps:maps_113
# maps:maps_1244
# maps:maps_1244
# maps:maps_1244
# maps:maps_1244
# maps:maps_1244
# maps:maps_1244
# maps:maps_1244
# maps:maps_1244
# maps:maps_1244
# maps:maps_1244
#  maps:maps_113
# maps:maps_1244
# maps:maps_1244
#           None
# maps:maps_1262
# maps:maps_1262
# maps:maps_1262
# maps:maps_1262
# maps:maps_1262
# maps:maps_1262
# maps:maps_1262
#  maps:maps_113
# maps:maps_1262
# maps:maps_1262
# maps:maps_1262
# maps:maps_1262
# maps:maps_1262
# maps:maps_1262
# maps:maps_1262
# maps:maps_1262
# maps:maps_1262
# maps:maps_1262
#  maps:maps_113
# maps:maps_1262
# maps:maps_1262
#           None
# maps:maps_1282
# maps:maps_1282
# maps:maps_1282
# maps:maps_1282
# maps:maps_1282
# maps:maps_1282
# maps:maps_1282
#           None
# maps:maps_1282
# maps:maps_1282
# maps:maps_1282
# maps:maps_1282
# maps:maps_1282
# maps:maps_1282
# maps:maps_1282
# maps:maps_1282
# maps:maps_1282
# maps:maps_1282
#           None
#  maps:maps_129
# maps:maps_1282
# maps:maps_1282
# maps:maps_1282
# maps:maps_1282
#           None
# maps:maps_1304
# maps:maps_1304
# maps:maps_1304
# maps:maps_1304
# maps:maps_1304
#  maps:maps_129
# maps:maps_1304
# maps:maps_1304
# maps:maps_1304
# maps:maps_1304
# maps:maps_1304
# maps:maps_1304
# maps:maps_1304
# maps:maps_1304
# maps:maps_1304
# maps:maps_1304
#  maps:maps_129
# maps:maps_1304
# maps:maps_1304
# maps:maps_1304
# maps:maps_1304
# maps:maps_1304
# maps:maps_1304
#  maps:maps_129
#  maps:maps_129
#           None
# maps:maps_1343
# maps:maps_1343
# maps:maps_1343
# maps:maps_1343
# maps:maps_1343
# maps:maps_1343
#  maps:maps_129
# maps:maps_1343
# maps:maps_1343
# maps:maps_1343
# maps:maps_1343
# maps:maps_1343
# maps:maps_1343
# maps:maps_1343
# maps:maps_1343
# maps:maps_1343
# maps:maps_1343
#  maps:maps_129
#  maps:maps_129
#  maps:maps_129
#  maps:maps_129
#           None
#  maps:maps_129
#  maps:maps_129
#  maps:maps_129
#  maps:maps_129
#  maps:maps_129
#  maps:maps_129
#  maps:maps_129
#  maps:maps_129
#  maps:maps_129
#           None
#           None
#  maps:maps_149
#  maps:maps_149
#  maps:maps_149
#  maps:maps_149
#  maps:maps_149
#  maps:maps_149
#  maps:maps_149
#  maps:maps_149
#  maps:maps_149
#  maps:maps_149
#           None
#  maps:maps_149
#  maps:maps_149
#  maps:maps_149
#  maps:maps_149
#  maps:maps_149
#  maps:maps_149
#  maps:maps_149
#  maps:maps_149
#   maps:maps_96
#  maps:maps_113
#           None
#           None
#  maps:maps_170
#  maps:maps_170
#  maps:maps_170
#  maps:maps_170
#  maps:maps_170
#  maps:maps_170
#  maps:maps_170
#  maps:maps_170
#  maps:maps_170
#           None
#  maps:maps_170
#  maps:maps_170
#  maps:maps_170
#  maps:maps_170
#  maps:maps_170
#  maps:maps_170
#  maps:maps_170
#  maps:maps_170
#  maps:maps_170
#  maps:maps_170
#           None
#  maps:maps_170
#  maps:maps_170
#  maps:maps_170
#  maps:maps_170
#  maps:maps_170
#           None
#  maps:maps_195
#  maps:maps_195
#  maps:maps_195
#  maps:maps_195
#           None
#           None
#  maps:maps_195
#  maps:maps_195
#  maps:maps_195
#  maps:maps_195
#  maps:maps_195
#  maps:maps_195
#  maps:maps_195
#  maps:maps_195
#  maps:maps_195
#  maps:maps_195
#           None
#  maps:maps_195
#  maps:maps_195
#           None
#  maps:maps_212
#  maps:maps_212
#  maps:maps_212
#  maps:maps_212
#  maps:maps_212
#  maps:maps_212
#  maps:maps_212
#           None
#  maps:maps_212
#  maps:maps_212
#  maps:maps_212
#  maps:maps_212
#  maps:maps_212
#  maps:maps_212
#  maps:maps_212
#  maps:maps_212
#  maps:maps_212
#  maps:maps_212
#           None
#  maps:maps_212
#  maps:maps_212
#  maps:maps_212
#  maps:maps_212
#  maps:maps_212
#  maps:maps_212
#  maps:maps_212
#  maps:maps_212
#  maps:maps_212
#  maps:maps_212
#           None
#           None
#  maps:maps_240
#  maps:maps_240
#  maps:maps_240
#  maps:maps_240
#  maps:maps_240
#  maps:maps_240
#  maps:maps_240
#  maps:maps_240
#  maps:maps_240
#           None
#  maps:maps_240
#  maps:maps_240
#  maps:maps_240
#  maps:maps_240
#  maps:maps_240
#  maps:maps_240
#  maps:maps_240
#  maps:maps_240
#  maps:maps_240
#  maps:maps_240
#           None
#  maps:maps_240
#           None
#  maps:maps_261
#  maps:maps_261
#  maps:maps_261
#  maps:maps_261
#  maps:maps_261
#  maps:maps_261
#  maps:maps_261
#  maps:maps_261
#           None
#  maps:maps_261
#  maps:maps_261
#  maps:maps_261
#  maps:maps_261
#  maps:maps_261
#           None
#  maps:maps_275
#  maps:maps_275
#  maps:maps_275
#  maps:maps_275
#           None
#  maps:maps_275
#  maps:maps_275
#  maps:maps_275
#  maps:maps_275
#  maps:maps_275
#  maps:maps_275
#  maps:maps_275
#  maps:maps_275
#  maps:maps_275
#  maps:maps_275
#           None
#  maps:maps_275
#           None
#  maps:maps_291
#  maps:maps_291
#  maps:maps_291
#  maps:maps_291
#  maps:maps_291
#  maps:maps_291
#  maps:maps_291
#  maps:maps_291
#           None
#           None
#  maps:maps_291
#  maps:maps_291
#  maps:maps_291
#  maps:maps_291
#  maps:maps_291
#  maps:maps_291
#  maps:maps_291
#  maps:maps_291
#           None
#  maps:maps_308
#           None
#  maps:maps_308
#  maps:maps_308
#  maps:maps_308
#  maps:maps_308
#  maps:maps_308
#  maps:maps_308
#  maps:maps_308
#  maps:maps_308
#  maps:maps_308
#  maps:maps_308
#           None
#  maps:maps_308
#           None
#  maps:maps_321
#  maps:maps_321
#  maps:maps_321
#  maps:maps_321
#  maps:maps_321
#  maps:maps_321
#  maps:maps_321
#  maps:maps_321
#           None
#  maps:maps_321
#  maps:maps_321
#  maps:maps_321
#  maps:maps_321
#  maps:maps_321
#  maps:maps_321
#  maps:maps_321
#  maps:maps_321
#  maps:maps_321
#  maps:maps_321
#           None
#           None
#  maps:maps_340
#  maps:maps_340
#  maps:maps_340
#  maps:maps_340
#  maps:maps_340
#  maps:maps_340
#  maps:maps_340
#  maps:maps_340
#  maps:maps_340
#           None
#  maps:maps_340
#  maps:maps_340
#  maps:maps_340
#  maps:maps_340
#  maps:maps_340
#  maps:maps_340
#  maps:maps_340
#  maps:maps_340
#  maps:maps_340
#  maps:maps_340
#           None
#  maps:maps_340
#           None
#  maps:maps_361
#  maps:maps_361
#  maps:maps_361
#  maps:maps_361
#  maps:maps_361
#  maps:maps_361
#  maps:maps_361
#  maps:maps_361
#           None
#  maps:maps_361
#  maps:maps_361
#  maps:maps_361
#  maps:maps_361
#  maps:maps_361
#  maps:maps_361
#  maps:maps_361
#  maps:maps_361
#  maps:maps_361
#  maps:maps_361
#           None
#  maps:maps_361
#  maps:maps_361
#  maps:maps_361
#  maps:maps_361
#  maps:maps_361
#  maps:maps_361
#           None
#  maps:maps_386
#  maps:maps_386
#  maps:maps_386
#           None
#  maps:maps_386
#  maps:maps_386
#  maps:maps_386
#  maps:maps_386
#  maps:maps_386
#  maps:maps_386
#  maps:maps_386
#  maps:maps_386
#  maps:maps_386
#  maps:maps_386
#           None
#           None
#  maps:maps_386
#  maps:maps_386
#  maps:maps_386
#  maps:maps_386
#  maps:maps_386
#  maps:maps_386
#  maps:maps_386
#           None
#  maps:maps_407
#  maps:maps_407
#           None
#  maps:maps_407
#  maps:maps_407
#  maps:maps_407
#  maps:maps_407
#  maps:maps_407
#  maps:maps_407
#  maps:maps_407
#  maps:maps_407
#  maps:maps_407
#  maps:maps_407
#           None
#  maps:maps_407
#  maps:maps_407
#  maps:maps_407
#  maps:maps_407
#  maps:maps_407
#  maps:maps_407
#  maps:maps_407
#  maps:maps_407
#  maps:maps_407
#  maps:maps_407
#           None
#  maps:maps_407
#  maps:maps_407
#  maps:maps_407
#  maps:maps_407
#  maps:maps_407
#  maps:maps_407
#  maps:maps_407
#  maps:maps_407
#  maps:maps_407
#  maps:maps_407
#           None
#  maps:maps_407
#  maps:maps_407
#  maps:maps_407
#  maps:maps_407
#  maps:maps_407
#  maps:maps_407
#  maps:maps_407
#  maps:maps_407
#  maps:maps_407
#           None
#           None
#  maps:maps_449
#  maps:maps_449
#  maps:maps_449
#  maps:maps_449
#  maps:maps_449
#  maps:maps_449
#  maps:maps_449
#  maps:maps_449
#  maps:maps_449
#  maps:maps_449
#           None
#  maps:maps_449
#  maps:maps_449
#  maps:maps_449
#  maps:maps_449
#  maps:maps_449
#  maps:maps_449
#  maps:maps_449
#  maps:maps_449
#  maps:maps_449
#  maps:maps_449
#           None
#  maps:maps_449
#  maps:maps_449
#  maps:maps_449
#  maps:maps_449
#  maps:maps_449
#  maps:maps_449
#           None
#  maps:maps_476
#  maps:maps_476
#  maps:maps_476
#           None
#  maps:maps_476
#  maps:maps_476
#  maps:maps_476
#  maps:maps_476
#  maps:maps_476
#  maps:maps_476
#  maps:maps_476
#  maps:maps_476
#  maps:maps_476
#  maps:maps_476
#           None
#  maps:maps_476
#  maps:maps_476
#  maps:maps_476
#  maps:maps_476
#  maps:maps_476
#           None
#  maps:maps_495
#  maps:maps_495
#  maps:maps_495
#  maps:maps_495
#           None
#           None
#  maps:maps_495
#  maps:maps_495
#  maps:maps_495
#  maps:maps_495
#  maps:maps_495
#  maps:maps_495
#  maps:maps_495
#  maps:maps_495
#  maps:maps_495
#  maps:maps_495
#           None
#  maps:maps_495
#  maps:maps_495
#  maps:maps_495
#           None
#  maps:maps_513
#  maps:maps_513
#  maps:maps_513
#  maps:maps_513
#  maps:maps_513
#  maps:maps_513
#           None
#  maps:maps_513
#  maps:maps_513
#  maps:maps_513
#  maps:maps_513
#  maps:maps_513
#  maps:maps_513
#  maps:maps_513
#  maps:maps_513
#  maps:maps_513
#  maps:maps_513
#           None
#  maps:maps_513
#  maps:maps_513
#  maps:maps_513
#  maps:maps_513
#  maps:maps_513
#  maps:maps_513
#  maps:maps_513
#  maps:maps_513
#  maps:maps_513
#  maps:maps_513
#           None
#           None
#  maps:maps_540
#  maps:maps_540
#  maps:maps_540
#  maps:maps_540
#  maps:maps_540
#  maps:maps_540
#  maps:maps_540
#  maps:maps_540
#  maps:maps_540
#           None
#  maps:maps_540
#  maps:maps_540
#  maps:maps_540
#  maps:maps_540
#  maps:maps_540
#  maps:maps_540
#           None
#  maps:maps_556
#  maps:maps_556
#  maps:maps_556
#           None
#  maps:maps_556
#  maps:maps_556
#  maps:maps_556
#  maps:maps_556
#  maps:maps_556
#  maps:maps_556
#  maps:maps_556
#  maps:maps_556
#  maps:maps_556
#  maps:maps_556
#           None
#  maps:maps_556
#  maps:maps_556
#  maps:maps_556
#           None
#  maps:maps_573
#  maps:maps_573
#  maps:maps_573
#  maps:maps_573
#  maps:maps_573
#  maps:maps_573
#           None
#  maps:maps_573
#  maps:maps_573
#  maps:maps_573
#  maps:maps_573
#  maps:maps_573
#  maps:maps_573
#  maps:maps_573
#  maps:maps_573
#  maps:maps_573
#  maps:maps_573
#           None
#  maps:maps_573
#  maps:maps_573
#  maps:maps_573
#  maps:maps_573
#  maps:maps_573
#  maps:maps_573
#  maps:maps_573
#  maps:maps_573
#           None
#  maps:maps_598
#           None
#           None
#  maps:maps_598
#  maps:maps_598
#  maps:maps_598
#  maps:maps_598
#  maps:maps_598
#  maps:maps_598
#  maps:maps_598
#  maps:maps_598
#  maps:maps_598
#  maps:maps_598
#           None
#  maps:maps_598
#  maps:maps_598
#  maps:maps_598
#  maps:maps_598
#  maps:maps_598
#  maps:maps_598
#           None
#  maps:maps_616
#  maps:maps_616
#  maps:maps_616
#           None
#  maps:maps_616
#  maps:maps_616
#  maps:maps_616
#  maps:maps_616
#  maps:maps_616
#  maps:maps_616
#  maps:maps_616
#  maps:maps_616
#  maps:maps_616
#  maps:maps_616
#           None
#  maps:maps_616
#  maps:maps_616
#  maps:maps_616
#  maps:maps_616
#  maps:maps_616
#  maps:maps_616
#           None
#  maps:maps_636
#  maps:maps_636
#  maps:maps_636
#           None
#  maps:maps_636
#  maps:maps_636
#  maps:maps_636
#  maps:maps_636
#  maps:maps_636
#  maps:maps_636
#  maps:maps_636
#  maps:maps_636
#  maps:maps_636
#  maps:maps_636
#           None
#  maps:maps_636
#  maps:maps_636
#  maps:maps_636
#  maps:maps_636
#  maps:maps_636
#  maps:maps_636
#  maps:maps_636
#           None
#  maps:maps_657
#  maps:maps_657
#           None
#  maps:maps_657
#  maps:maps_657
#  maps:maps_657
#  maps:maps_657
#  maps:maps_657
#  maps:maps_657
#  maps:maps_657
#  maps:maps_657
#  maps:maps_657
#  maps:maps_657
#           None
#  maps:maps_657
#  maps:maps_657
#  maps:maps_657
#  maps:maps_657
#  maps:maps_657
#  maps:maps_657
#  maps:maps_657
#  maps:maps_657
#           None
#  maps:maps_678
#           None
#  maps:maps_678
#  maps:maps_678
#  maps:maps_678
#  maps:maps_678
#  maps:maps_678
#  maps:maps_678
#  maps:maps_678
#  maps:maps_678
#  maps:maps_678
#  maps:maps_678
#           None
#  maps:maps_678
#  maps:maps_678
#  maps:maps_678
#  maps:maps_678
#           None
#  maps:maps_694
#  maps:maps_694
#  maps:maps_694
#  maps:maps_694
#  maps:maps_694
#           None
#           None
#  maps:maps_694
#  maps:maps_694
#  maps:maps_694
#  maps:maps_694
#  maps:maps_694
#  maps:maps_694
#  maps:maps_694
#  maps:maps_694
#  maps:maps_694
#  maps:maps_694
#           None
#  maps:maps_694
#  maps:maps_694
#  maps:maps_694
#           None
#  maps:maps_713
#  maps:maps_713
#  maps:maps_713
#  maps:maps_713
#  maps:maps_713
#  maps:maps_713
#           None
#  maps:maps_713
#  maps:maps_713
#  maps:maps_713
#  maps:maps_713
#  maps:maps_713
#  maps:maps_713
#  maps:maps_713
#  maps:maps_713
#  maps:maps_713
#  maps:maps_713
#           None
#           None
#  maps:maps_730
#  maps:maps_730
#  maps:maps_730
#  maps:maps_730
#  maps:maps_730
#  maps:maps_730
#  maps:maps_730
#  maps:maps_730
#  maps:maps_730
#           None
#  maps:maps_730
#  maps:maps_730
#  maps:maps_730
#  maps:maps_730
#  maps:maps_730
#  maps:maps_730
#  maps:maps_730
#  maps:maps_730
#  maps:maps_730
#  maps:maps_730
#           None
#  maps:maps_730
#  maps:maps_730
#  maps:maps_730
#  maps:maps_730
#  maps:maps_730
#           None
#  maps:maps_755
#  maps:maps_755
#  maps:maps_755
#  maps:maps_755
#           None
#  maps:maps_755
#  maps:maps_755
#  maps:maps_755
#  maps:maps_755
#  maps:maps_755
#  maps:maps_755
#  maps:maps_755
#  maps:maps_755
#  maps:maps_755
#  maps:maps_755
#           None
#  maps:maps_755
#  maps:maps_755
#  maps:maps_755
#  maps:maps_755
#  maps:maps_755
#  maps:maps_755
#  maps:maps_755
#  maps:maps_755
#  maps:maps_755
#  maps:maps_755
#           None
#  maps:maps_755
#  maps:maps_755
#  maps:maps_755
#  maps:maps_755
#  maps:maps_755
#  maps:maps_755
#  maps:maps_755
#  maps:maps_755
#  maps:maps_755
#  maps:maps_755
#           None
#  maps:maps_755
#  maps:maps_755
#  maps:maps_755
#  maps:maps_755
#  maps:maps_755
#  maps:maps_755
#           None
#  maps:maps_796
#  maps:maps_796
#  maps:maps_796
#           None
#           None
#  maps:maps_796
#  maps:maps_796
#  maps:maps_796
#  maps:maps_796
#  maps:maps_796
#  maps:maps_796
#  maps:maps_796
#  maps:maps_796
#  maps:maps_796
#  maps:maps_796
#           None
#  maps:maps_796
#  maps:maps_796
#  maps:maps_796
#           None
#  maps:maps_813
#  maps:maps_813
#  maps:maps_813
#  maps:maps_813
#  maps:maps_813
#  maps:maps_813
#           None
#  maps:maps_813
#  maps:maps_813
#  maps:maps_813
#  maps:maps_813
#  maps:maps_813
#  maps:maps_813
#  maps:maps_813
#  maps:maps_813
#  maps:maps_813
#  maps:maps_813
#           None
#  maps:maps_813
#  maps:maps_813
#  maps:maps_813
#  maps:maps_813
#  maps:maps_813
#  maps:maps_813
#  maps:maps_813
#  maps:maps_813
#  maps:maps_813
#  maps:maps_813
#           None
#  maps:maps_813
#  maps:maps_813
#  maps:maps_813
#  maps:maps_813
#  maps:maps_813
#  maps:maps_813
#  maps:maps_813
#  maps:maps_813
#  maps:maps_813
#  maps:maps_813
#           None
#  maps:maps_813
#           None
#  maps:maps_851
#  maps:maps_851
#  maps:maps_851
#  maps:maps_851
#  maps:maps_851
#  maps:maps_851
#  maps:maps_851
#  maps:maps_851
#           None
#  maps:maps_851
#  maps:maps_851
#  maps:maps_851
#  maps:maps_851
#  maps:maps_851
#  maps:maps_851
#  maps:maps_851
#  maps:maps_851
#  maps:maps_851
#  maps:maps_851
#           None
#  maps:maps_851
#  maps:maps_851
#  maps:maps_851
#  maps:maps_851
#  maps:maps_851
#  maps:maps_851
#  maps:maps_851
#  maps:maps_851
#  maps:maps_851
#  maps:maps_851
#           None
#  maps:maps_851
#  maps:maps_851
#  maps:maps_851
#  maps:maps_851
#  maps:maps_851
#  maps:maps_851
#  maps:maps_851
#  maps:maps_851
#  maps:maps_851
#  maps:maps_851
#           None
#  maps:maps_851
#  maps:maps_851
#  maps:maps_851
#           None
#  maps:maps_893
#  maps:maps_893
#  maps:maps_893
#  maps:maps_893
#  maps:maps_893
#  maps:maps_893
#           None
#           None
#  maps:maps_893
#  maps:maps_893
#  maps:maps_893
#  maps:maps_893
#  maps:maps_893
#  maps:maps_893
#  maps:maps_893
#  maps:maps_893
#  maps:maps_893
#  maps:maps_893
#           None
#  maps:maps_893
#  maps:maps_893
#  maps:maps_893
#  maps:maps_893
#  maps:maps_893
#  maps:maps_893
#  maps:maps_893
#  maps:maps_893
#           None
#  maps:maps_918
#           None
#  maps:maps_918
#  maps:maps_918
#  maps:maps_918
#  maps:maps_918
#  maps:maps_918
#  maps:maps_918
#  maps:maps_918
#  maps:maps_918
#  maps:maps_918
#  maps:maps_918
#           None
#  maps:maps_918
#  maps:maps_918
#  maps:maps_918
#  maps:maps_918
#  maps:maps_918
#  maps:maps_918
#  maps:maps_918
#  maps:maps_918
#  maps:maps_918
#  maps:maps_918
#           None
#  maps:maps_918
#  maps:maps_918
#  maps:maps_918
#  maps:maps_918
#  maps:maps_918
#  maps:maps_918
#           None
#  maps:maps_946
#  maps:maps_946
#  maps:maps_946
#           None
#  maps:maps_946
#  maps:maps_946
#  maps:maps_946
#  maps:maps_946
#  maps:maps_946
#  maps:maps_946
#  maps:maps_946
#  maps:maps_946
#  maps:maps_946
#  maps:maps_946
#           None
#  maps:maps_946
#  maps:maps_946
#  maps:maps_946
#           None
#  maps:maps_963
#  maps:maps_963
#  maps:maps_963
#  maps:maps_963
#  maps:maps_963
#  maps:maps_963
#   maps:maps_96
#  maps:maps_963
#  maps:maps_963
#  maps:maps_963
#  maps:maps_963
#  maps:maps_963
#  maps:maps_963
#  maps:maps_963
#  maps:maps_963
#  maps:maps_963
#  maps:maps_963
#   maps:maps_96
#           None
#           None
#           None
#           None
#           None
#           None
#           None
#           None
#           None
#           None
#   maps:maps_96
#           None
#           None
#           None
#           None
#           None
#           None
#           None
#           None
#           None
#           None

# %%
def create_date_range(temporal_coverage):
    # Remove any white spaces
    temporal_coverage = temporal_coverage.strip()
    
    # Single year condition
    if temporal_coverage.isdigit():
        year = int(temporal_coverage)
        return f"{year}-{year}"

    # Century condition (e.g., 19xx)
    elif "xx" in temporal_coverage:
        century_start = int(temporal_coverage.replace("xx", "00"))
        century_end = int(temporal_coverage.replace("xx", "99"))
        return f"{century_start}-{century_end}"
    
    # Decade condition (e.g., 193x)
    elif "x" in temporal_coverage:
        decade_start = int(temporal_coverage.replace("x", "0"))
        decade_end = int(temporal_coverage.replace("x", "9"))
        return f"{decade_start}-{decade_end}"
    
    # Default date range if no condition is met
    else:
        return "1900-1955"

# Apply the function to create the new 'Date Range' column
df['Date Range'] = df['Temporal Coverage'].apply(create_date_range)

# %%
def clean_spatial_coverage(spatial_coverage):
    # Split the string by the pipe '|' symbol into a list
    locations = spatial_coverage.split("|")
    
    # Check if the record is related to Michigan
    if "Michigan" in locations:
        # Initialize sets to hold unique type B and type C locations
        type_b = set()
        type_c = set()
        
        # Categorize locations
        for loc in locations:
            if "(Mich.)" in loc:
                type_b.add(loc.replace(" (Mich.)", ""))
            elif loc == "Michigan":
                type_c.add("Michigan")
        
        # Create the cleaned locations list based on the rules
        cleaned_locations = ["Michigan--" + b for b in type_b]
        
        if "Michigan" not in cleaned_locations:
            cleaned_locations.append("Michigan")
        
        # Rejoin the list into a string separated by the pipe '|' symbol
        return "|".join(cleaned_locations)
    else:
        # If the record is not related to Michigan, return the original string
        return spatial_coverage

# Apply the function to clean up the 'Spatial Coverage' column
df['Spatial Coverage'] = df['Spatial Coverage'].apply(clean_spatial_coverage)

# %%
def convert_to_decimal(coordinate_str):
    try:
        print(f"Processing: {coordinate_str}")  # Debug print
        
        # Decode HTML entities
        coordinate_str = coordinate_str.replace("&#176;", "°").replace("&#697;", "'").replace("&#698;", '"').replace("ʹ", "'").replace("ʺ", '"')
        
        print(f"After HTML replacement: {coordinate_str}")  # Debug print
        
        # Check if already in decimal format
        if "." in coordinate_str:
            decimal_degrees = float(re.search(r"-?\d+\.\d+", coordinate_str).group())
        
        else:
            # Extract numerical values
            num_values = [float(x) for x in re.findall(r"\d+", coordinate_str)]
            
            print(f"Extracted numbers: {num_values}")  # Debug print
            
            # DMS to decimal with or without special characters
            if len(num_values) == 3:
                degrees, minutes, seconds = num_values
                decimal_degrees = degrees + (minutes / 60.0) + (seconds / 3600.0)
            
            # DM to decimal
            elif len(num_values) == 2:
                degrees, minutes = num_values
                decimal_degrees = degrees + (minutes / 60.0)
                
            # Only degrees
            elif len(num_values) == 1:
                degrees = num_values[0]
                decimal_degrees = degrees

            else:
                return None  # Unrecognized format

        if "S" in coordinate_str or "W" in coordinate_str:
            decimal_degrees *= -1

        return round(decimal_degrees, 4)

    except Exception as e:
        print(f"Error while converting coordinate: {e}")
        return None

def extract_bounding_box(coordinate_field):
    try:
        # Split latitude and longitude pairs
        lon_str, lat_str = coordinate_field.split("/")
        
        # Extract individual coordinates and convert to decimal
        west, east = map(convert_to_decimal, lon_str.split("--"))
        north, south = map(convert_to_decimal, lat_str.split("--"))
        
        # Check if any conversion failed
        if None in [west, east, north, south]:
            print("Conversion failed for one or more coordinates.")
            return None
        
        return f"{west},{south},{east},{north}"
    except Exception as e:
        print(f"Error while extracting bounding box: {e}")
        return None

df['Extracted Bounding Box'] = df['Coordinates'].apply(extract_bounding_box)
# Out:
# Processing: W 11°28ʹ00ʺ
# After HTML replacement: W 11°28'00"
# Extracted numbers: [11.0, 28.0, 0.0]
# Processing: W 7°22ʹ00ʺ
# After HTML replacement: W 7°22'00"
# Extracted numbers: [7.0, 22.0, 0.0]
# Processing: N 8°33ʹ00ʺ
# After HTML replacement: N 8°33'00"
# Extracted numbers: [8.0, 33.0, 0.0]
# Processing: N 4°18ʹ00ʺ
# After HTML replacement: N 4°18'00"
# Extracted numbers: [4.0, 18.0, 0.0]
# Processing: W 90°25ʹ00ʺ
# After HTML replacement: W 90°25'00"
# Extracted numbers: [90.0, 25.0, 0.0]
# Processing: W 81°51ʹ00ʺ
# After HTML replacement: W 81°51'00"
# Extracted numbers: [81.0, 51.0, 0.0]
# Processing: N 47°33ʹ00ʺ
# After HTML replacement: N 47°33'00"
# Extracted numbers: [47.0, 33.0, 0.0]
# Processing: N 41°27ʹ00ʺ
# After HTML replacement: N 41°27'00"
# Extracted numbers: [41.0, 27.0, 0.0]
# Processing: W 085.876188
# After HTML replacement: W 085.876188
# Processing: W 085.760122
# After HTML replacement: W 085.760122
# Processing: N 041.983774
# After HTML replacement: N 041.983774
# Processing: N 041.896623
# After HTML replacement: N 041.896623
# Processing: W 83°55ʹ55ʺ
# After HTML replacement: W 83°55'55"
# Extracted numbers: [83.0, 55.0, 55.0]
# Processing: W 83°27ʹ11ʺ
# After HTML replacement: W 83°27'11"
# Extracted numbers: [83.0, 27.0, 11.0]
# Processing: N 43°13ʹ23ʺ
# After HTML replacement: N 43°13'23"
# Extracted numbers: [43.0, 13.0, 23.0]
# Processing: N 42°46ʹ50ʺ
# After HTML replacement: N 42°46'50"
# Extracted numbers: [42.0, 46.0, 50.0]
# Processing: W 85°49ʹ13ʺ
# After HTML replacement: W 85°49'13"
# Extracted numbers: [85.0, 49.0, 13.0]
# Processing: W 85°19ʹ54ʺ
# After HTML replacement: W 85°19'54"
# Extracted numbers: [85.0, 19.0, 54.0]
# Processing: N 45°00ʹ01ʺ
# After HTML replacement: N 45°00'01"
# Extracted numbers: [45.0, 0.0, 1.0]
# Processing: N 44°30ʹ41ʺ
# After HTML replacement: N 44°30'41"
# Extracted numbers: [44.0, 30.0, 41.0]
# Processing: W 83°29ʹ46ʺ
# After HTML replacement: W 83°29'46"
# Extracted numbers: [83.0, 29.0, 46.0]
# Processing: W 82°36ʹ16ʺ
# After HTML replacement: W 82°36'16"
# Extracted numbers: [82.0, 36.0, 16.0]
# Processing: N 44°04ʹ12ʺ
# After HTML replacement: N 44°04'12"
# Extracted numbers: [44.0, 4.0, 12.0]
# Processing: N 43°40ʹ03ʺ
# After HTML replacement: N 43°40'03"
# Extracted numbers: [43.0, 40.0, 3.0]
# Processing: W 86°09ʹ23ʺ
# After HTML replacement: W 86°09'23"
# Extracted numbers: [86.0, 9.0, 23.0]
# Processing: W 85°31ʹ36ʺ
# After HTML replacement: W 85°31'36"
# Extracted numbers: [85.0, 31.0, 36.0]
# Processing: N 45°29ʹ29ʺ
# After HTML replacement: N 45°29'29"
# Extracted numbers: [45.0, 29.0, 29.0]
# Processing: N 44°46ʹ27ʺ
# After HTML replacement: N 44°46'27"
# Extracted numbers: [44.0, 46.0, 27.0]
# Processing: W 84°21ʹ48ʺ
# After HTML replacement: W 84°21'48"
# Extracted numbers: [84.0, 21.0, 48.0]
# Processing: W 83°45ʹ47ʺ
# After HTML replacement: W 83°45'47"
# Extracted numbers: [83.0, 45.0, 47.0]
# Processing: N 42°04ʹ56ʺ
# After HTML replacement: N 42°04'56"
# Extracted numbers: [42.0, 4.0, 56.0]
# Processing: N 41°42ʹ23ʺ
# After HTML replacement: N 41°42'23"
# Extracted numbers: [41.0, 42.0, 23.0]
# Processing: W 84°09ʹ29ʺ
# After HTML replacement: W 84°09'29"
# Extracted numbers: [84.0, 9.0, 29.0]
# Processing: W 83°39ʹ53ʺ
# After HTML replacement: W 83°39'53"
# Extracted numbers: [83.0, 39.0, 53.0]
# Processing: N 42°46ʹ59ʺ
# After HTML replacement: N 42°46'59"
# Extracted numbers: [42.0, 46.0, 59.0]
# Processing: N 42°25ʹ26ʺ
# After HTML replacement: N 42°25'26"
# Extracted numbers: [42.0, 25.0, 26.0]
# Processing: W 84°08ʹ02ʺ
# After HTML replacement: W 84°08'02"
# Extracted numbers: [84.0, 8.0, 2.0]
# Processing: W 83°32ʹ21ʺ
# After HTML replacement: W 83°32'21"
# Extracted numbers: [83.0, 32.0, 21.0]
# Processing: N 42°26ʹ06ʺ
# After HTML replacement: N 42°26'06"
# Extracted numbers: [42.0, 26.0, 6.0]
# Processing: N 42°04ʹ17ʺ
# After HTML replacement: N 42°04'17"
# Extracted numbers: [42.0, 4.0, 17.0]
# Processing: W 85°33ʹ51ʺ
# After HTML replacement: W 85°33'51"
# Extracted numbers: [85.0, 33.0, 51.0]
# Processing: W 84°50ʹ13ʺ
# After HTML replacement: W 84°50'13"
# Extracted numbers: [84.0, 50.0, 13.0]
# Processing: N 43°28ʹ02ʺ
# After HTML replacement: N 43°28'02"
# Extracted numbers: [43.0, 28.0, 2.0]
# Processing: N 43°07ʹ05ʺ
# After HTML replacement: N 43°07'05"
# Extracted numbers: [43.0, 7.0, 5.0]
# Processing: W 85°33ʹ51ʺ
# After HTML replacement: W 85°33'51"
# Extracted numbers: [85.0, 33.0, 51.0]
# Processing: W 85°05ʹ12ʺ
# After HTML replacement: W 85°05'12"
# Extracted numbers: [85.0, 5.0, 12.0]
# Processing: N 44°09ʹ55ʺ
# After HTML replacement: N 44°09'55"
# Extracted numbers: [44.0, 9.0, 55.0]
# Processing: N 43°48ʹ44ʺ
# After HTML replacement: N 43°48'44"
# Extracted numbers: [43.0, 48.0, 44.0]
# Processing: W 86°16ʹ18ʺ
# After HTML replacement: W 86°16'18"
# Extracted numbers: [86.0, 16.0, 18.0]
# Processing: W 85°46ʹ55ʺ
# After HTML replacement: W 85°46'55"
# Extracted numbers: [85.0, 46.0, 55.0]
# Processing: N 43°12ʹ21ʺ
# After HTML replacement: N 43°12'21"
# Extracted numbers: [43.0, 12.0, 21.0]
# Processing: N 42°46ʹ03ʺ
# After HTML replacement: N 42°46'03"
# Extracted numbers: [42.0, 46.0, 3.0]
# Processing: W 085.877122
# After HTML replacement: W 085.877122
# Processing: W 085.76122
# After HTML replacement: W 085.76122
# Processing: N 042.069453
# After HTML replacement: N 042.069453
# Processing: N 041.983503
# After HTML replacement: N 041.983503
# Processing: W 82°59ʹ46ʺ
# After HTML replacement: W 82°59'46"
# Extracted numbers: [82.0, 59.0, 46.0]
# Processing: W 82°24ʹ43ʺ
# After HTML replacement: W 82°24'43"
# Extracted numbers: [82.0, 24.0, 43.0]
# Processing: N 43°10ʹ08ʺ
# After HTML replacement: N 43°10'08"
# Extracted numbers: [43.0, 10.0, 8.0]
# Processing: N 42°28ʹ40ʺ
# After HTML replacement: N 42°28'40"
# Extracted numbers: [42.0, 28.0, 40.0]
# Processing: W 83°07ʹ13ʺ
# After HTML replacement: W 83°07'13"
# Extracted numbers: [83.0, 7.0, 13.0]
# Processing: W 82°30ʹ11ʺ
# After HTML replacement: W 82°30'11"
# Extracted numbers: [82.0, 30.0, 11.0]
# Processing: N 43°41ʹ25ʺ
# After HTML replacement: N 43°41'25"
# Extracted numbers: [43.0, 41.0, 25.0]
# Processing: N 43°09ʹ14ʺ
# After HTML replacement: N 43°09'14"
# Extracted numbers: [43.0, 9.0, 14.0]
# Processing: W 83°46ʹ26ʺ
# After HTML replacement: W 83°46'26"
# Extracted numbers: [83.0, 46.0, 26.0]
# Processing: W 83°11ʹ20ʺ
# After HTML replacement: W 83°11'20"
# Extracted numbers: [83.0, 11.0, 20.0]
# Processing: N 42°05ʹ39ʺ
# After HTML replacement: N 42°05'39"
# Extracted numbers: [42.0, 5.0, 39.0]
# Processing: N 41°43ʹ24ʺ
# After HTML replacement: N 41°43'24"
# Extracted numbers: [41.0, 43.0, 24.0]
# Processing: W 85°47ʹ18ʺ
# After HTML replacement: W 85°47'18"
# Extracted numbers: [85.0, 47.0, 18.0]
# Processing: W 85°17ʹ28ʺ
# After HTML replacement: W 85°17'28"
# Extracted numbers: [85.0, 17.0, 28.0]
# Processing: N 42°04ʹ18ʺ
# After HTML replacement: N 42°04'18"
# Extracted numbers: [42.0, 4.0, 18.0]
# Processing: N 41°45ʹ32ʺ
# After HTML replacement: N 41°45'32"
# Extracted numbers: [41.0, 45.0, 32.0]
# Processing: W 83°06ʹ10ʺ
# After HTML replacement: W 83°06'10"
# Extracted numbers: [83.0, 6.0, 10.0]
# Processing: W 82°42ʹ21ʺ
# After HTML replacement: W 82°42'21"
# Extracted numbers: [82.0, 42.0, 21.0]
# Processing: N 42°53ʹ51ʺ
# After HTML replacement: N 42°53'51"
# Extracted numbers: [42.0, 53.0, 51.0]
# Processing: N 42°26ʹ49ʺ
# After HTML replacement: N 42°26'49"
# Extracted numbers: [42.0, 26.0, 49.0]
# Processing: W 83°27ʹ38ʺ
# After HTML replacement: W 83°27'38"
# Extracted numbers: [83.0, 27.0, 38.0]
# Processing: W 82°59ʹ01ʺ
# After HTML replacement: W 82°59'01"
# Extracted numbers: [82.0, 59.0, 1.0]
# Processing: N 43°19ʹ37ʺ
# After HTML replacement: N 43°19'37"
# Extracted numbers: [43.0, 19.0, 37.0]
# Processing: N 42°52ʹ49ʺ
# After HTML replacement: N 42°52'49"
# Extracted numbers: [42.0, 52.0, 49.0]
# Processing: W 88 59
# After HTML replacement: W 88 59
# Extracted numbers: [88.0, 59.0]
# Processing: W 88 13
# After HTML replacement: W 88 13
# Extracted numbers: [88.0, 13.0]
# Processing: N 47 17
# After HTML replacement: N 47 17
# Extracted numbers: [47.0, 17.0]
# Processing: N 46 25
# After HTML replacement: N 46 25
# Extracted numbers: [46.0, 25.0]
# Processing: W 83 29 46
# After HTML replacement: W 83 29 46
# Extracted numbers: [83.0, 29.0, 46.0]
# Processing: W 82 36 16
# After HTML replacement: W 82 36 16
# Extracted numbers: [82.0, 36.0, 16.0]
# Processing: N 44 04 12
# After HTML replacement: N 44 04 12
# Extracted numbers: [44.0, 4.0, 12.0]
# Processing: N 43 40 03
# After HTML replacement: N 43 40 03
# Extracted numbers: [43.0, 40.0, 3.0]
# Processing: W 83 53 11
# After HTML replacement: W 83 53 11
# Extracted numbers: [83.0, 53.0, 11.0]
# Processing: W 83 18 57
# After HTML replacement: W 83 18 57
# Extracted numbers: [83.0, 18.0, 57.0]
# Processing: N 44 30 42
# After HTML replacement: N 44 30 42
# Extracted numbers: [44.0, 30.0, 42.0]
# Processing: N 44 09 42
# After HTML replacement: N 44 09 42
# Extracted numbers: [44.0, 9.0, 42.0]
# Processing: W 085.991704
# After HTML replacement: W 085.991704
# Processing: W 085.876917
# After HTML replacement: W 085.876917
# Processing: N 041.8107
# After HTML replacement: N 041.8107
# Processing: N 041.759341
# After HTML replacement: N 041.759341
# Processing: W 84 43 14
# After HTML replacement: W 84 43 14
# Extracted numbers: [84.0, 43.0, 14.0]
# Processing: W 84 07 50
# After HTML replacement: W 84 07 50
# Extracted numbers: [84.0, 7.0, 50.0]
# Processing: N 42 25 28
# After HTML replacement: N 42 25 28
# Extracted numbers: [42.0, 25.0, 28.0]
# Processing: N 42 04 13
# After HTML replacement: N 42 04 13
# Extracted numbers: [42.0, 4.0, 13.0]
# Processing: W 85 45 57
# After HTML replacement: W 85 45 57
# Extracted numbers: [85.0, 45.0, 57.0]
# Processing: W 85 17 33
# After HTML replacement: W 85 17 33
# Extracted numbers: [85.0, 17.0, 33.0]
# Processing: N 42 25 17
# After HTML replacement: N 42 25 17
# Extracted numbers: [42.0, 25.0, 17.0]
# Processing: N 42 04 11
# After HTML replacement: N 42 04 11
# Extracted numbers: [42.0, 4.0, 11.0]
# Processing: W 85 18 48
# After HTML replacement: W 85 18 48
# Extracted numbers: [85.0, 18.0, 48.0]
# Processing: W 84 50 15
# After HTML replacement: W 84 50 15
# Extracted numbers: [84.0, 50.0, 15.0]
# Processing: N 43 07 14
# After HTML replacement: N 43 07 14
# Extracted numbers: [43.0, 7.0, 14.0]
# Processing: N 42 46 09
# After HTML replacement: N 42 46 09
# Extracted numbers: [42.0, 46.0, 9.0]
# Processing: W 085.991348
# After HTML replacement: W 085.991348
# Processing: W 085.875346
# After HTML replacement: W 085.875346
# Processing: N 041.897223
# After HTML replacement: N 041.897223
# Processing: N 041.809447
# After HTML replacement: N 041.809447
# Processing: W 85 50'
# After HTML replacement: W 85 50'
# Extracted numbers: [85.0, 50.0]
# Processing: W 84 43
# After HTML replacement: W 84 43
# Extracted numbers: [84.0, 43.0]
# Processing: N 45 50
# After HTML replacement: N 45 50
# Extracted numbers: [45.0, 50.0]
# Processing: N 45 06
# After HTML replacement: N 45 06
# Extracted numbers: [45.0, 6.0]
# Processing: W 85 07 13
# After HTML replacement: W 85 07 13
# Extracted numbers: [85.0, 7.0, 13.0]
# Processing: W 84 43 53
# After HTML replacement: W 84 43 53
# Extracted numbers: [84.0, 43.0, 53.0]
# Processing: N 45 47 22
# After HTML replacement: N 45 47 22
# Extracted numbers: [45.0, 47.0, 22.0]
# Processing: N 45 16 12
# After HTML replacement: N 45 16 12
# Extracted numbers: [45.0, 16.0, 12.0]
# Processing: W 88 40 55
# After HTML replacement: W 88 40 55
# Extracted numbers: [88.0, 40.0, 55.0]
# Processing: W 87 59 30
# After HTML replacement: W 87 59 30
# Extracted numbers: [87.0, 59.0, 30.0]
# Processing: N 46 58 01
# After HTML replacement: N 46 58 01
# Extracted numbers: [46.0, 58.0, 1.0]
# Processing: N 46 25 08
# After HTML replacement: N 46 25 08
# Extracted numbers: [46.0, 25.0, 8.0]
# Processing: W 83 52
# After HTML replacement: W 83 52
# Extracted numbers: [83.0, 52.0]
# Processing: W 083 15
# After HTML replacement: W 083 15
# Extracted numbers: [83.0, 15.0]
# Processing: N 44 51
# After HTML replacement: N 44 51
# Extracted numbers: [44.0, 51.0]
# Processing: N 44 30
# After HTML replacement: N 44 30
# Extracted numbers: [44.0, 30.0]
# Processing: W 83 53 18
# After HTML replacement: W 83 53 18
# Extracted numbers: [83.0, 53.0, 18.0]
# Processing: W 83 11 25
# After HTML replacement: W 83 11 25
# Extracted numbers: [83.0, 11.0, 25.0]
# Processing: N 45 12 25
# After HTML replacement: N 45 12 25
# Extracted numbers: [45.0, 12.0, 25.0]
# Processing: N 44 51 23
# After HTML replacement: N 44 51 23
# Extracted numbers: [44.0, 51.0, 23.0]
# Processing: W 085.991226
# After HTML replacement: W 085.991226
# Processing: W 085.875346
# After HTML replacement: W 085.875346
# Processing: N 041.983774
# After HTML replacement: N 041.983774
# Processing: N 041.897044
# After HTML replacement: N 041.897044
# Processing: W 85 26 39
# After HTML replacement: W 85 26 39
# Extracted numbers: [85.0, 26.0, 39.0]
# Processing: W 84 50 53
# After HTML replacement: W 84 50 53
# Extracted numbers: [84.0, 50.0, 53.0]
# Processing: N 45 12 28
# After HTML replacement: N 45 12 28
# Extracted numbers: [45.0, 12.0, 28.0]
# Processing: N 44 48 51
# After HTML replacement: N 44 48 51
# Extracted numbers: [44.0, 48.0, 51.0]
# Processing: W 86 13 31
# After HTML replacement: W 86 13 31
# Extracted numbers: [86.0, 13.0, 31.0]
# Processing: W 85 45 33
# After HTML replacement: W 85 45 33
# Extracted numbers: [85.0, 45.0, 33.0]
# Processing: N 42 04 17
# After HTML replacement: N 42 04 17
# Extracted numbers: [42.0, 4.0, 17.0]
# Processing: N 41 45 32
# After HTML replacement: N 41 45 32
# Extracted numbers: [41.0, 45.0, 32.0]
# Processing: W 84 51 12
# After HTML replacement: W 84 51 12
# Extracted numbers: [84.0, 51.0, 12.0]
# Processing: W 84 22 22
# After HTML replacement: W 84 22 22
# Extracted numbers: [84.0, 22.0, 22.0]
# Processing: N 44 51 28
# After HTML replacement: N 44 51 28
# Extracted numbers: [44.0, 51.0, 28.0]
# Processing: N 44 30 26
# After HTML replacement: N 44 30 26
# Extracted numbers: [44.0, 30.0, 26.0]
# Processing: W 085.991977
# After HTML replacement: W 085.991977
# Processing: W 085.876188
# After HTML replacement: W 085.876188
# Processing: N 042.070079
# After HTML replacement: N 042.070079
# Processing: N 041.983611
# After HTML replacement: N 041.983611
# Processing: W 90 25 06
# After HTML replacement: W 90 25 06
# Extracted numbers: [90.0, 25.0, 6.0]
# Processing: W 88 59 24
# After HTML replacement: W 88 59 24
# Extracted numbers: [88.0, 59.0, 24.0]
# Processing: N 46 46 04
# After HTML replacement: N 46 46 04
# Extracted numbers: [46.0, 46.0, 4.0]
# Processing: N 46 05 50
# After HTML replacement: N 46 05 50
# Extracted numbers: [46.0, 5.0, 50.0]
# Processing: W 87 22 15
# After HTML replacement: W 87 22 15
# Extracted numbers: [87.0, 22.0, 15.0]
# Processing: W 86 27 41
# After HTML replacement: W 86 27 41
# Extracted numbers: [86.0, 27.0, 41.0]
# Processing: N 46 09 32
# After HTML replacement: N 46 09 32
# Extracted numbers: [46.0, 9.0, 32.0]
# Processing: N 45 28 38
# After HTML replacement: N 45 28 38
# Extracted numbers: [45.0, 28.0, 38.0]
# Processing: W 86 49 32
# After HTML replacement: W 86 49 32
# Extracted numbers: [86.0, 49.0, 32.0]
# Processing: W 86 13 22
# After HTML replacement: W 86 13 22
# Extracted numbers: [86.0, 13.0, 22.0]
# Processing: N 42 14 43
# After HTML replacement: N 42 14 43
# Extracted numbers: [42.0, 14.0, 43.0]
# Processing: N 41 45 34
# After HTML replacement: N 41 45 34
# Extracted numbers: [41.0, 45.0, 34.0]
# Processing: W 84⁰36
# After HTML replacement: W 84⁰36
# Extracted numbers: [84.0, 36.0]
# Processing: W 84⁰08
# After HTML replacement: W 84⁰08
# Extracted numbers: [84.0, 8.0]
# Processing: N 42⁰46
# After HTML replacement: N 42⁰46
# Extracted numbers: [42.0, 46.0]
# Processing: N 42⁰25
# After HTML replacement: N 42⁰25
# Extracted numbers: [42.0, 25.0]
# Processing: W 086.108454
# After HTML replacement: W 086.108454
# Processing: W 085.991294
# After HTML replacement: W 085.991294
# Processing: N 041.811133
# After HTML replacement: N 041.811133
# Processing: N 041.760152
# After HTML replacement: N 041.760152
# Processing: W 88 08 10
# After HTML replacement: W 88 08 10
# Extracted numbers: [88.0, 8.0, 10.0]
# Processing: W 87 37 07
# After HTML replacement: W 87 37 07
# Extracted numbers: [87.0, 37.0, 7.0]
# Processing: N 46 14 51
# After HTML replacement: N 46 14 51
# Extracted numbers: [46.0, 14.0, 51.0]
# Processing: N 45 43 18
# After HTML replacement: N 45 43 18
# Extracted numbers: [45.0, 43.0, 18.0]
# Processing: W85 15
# After HTML replacement: W85 15
# Extracted numbers: [85.0, 15.0]
# Processing: W83 28
# After HTML replacement: W83 28
# Extracted numbers: [83.0, 28.0]
# Processing: N46 46
# After HTML replacement: N46 46
# Extracted numbers: [46.0, 46.0]
# Processing: N45 54
# After HTML replacement: N45 54
# Extracted numbers: [45.0, 54.0]
# Processing: W 85 17 37"
# After HTML replacement: W 85 17 37"
# Extracted numbers: [85.0, 17.0, 37.0]
# Processing: W 84 49 27"
# After HTML replacement: W 84 49 27"
# Extracted numbers: [84.0, 49.0, 27.0]
# Processing: N 42 04 24"
# After HTML replacement: N 42 04 24"
# Extracted numbers: [42.0, 4.0, 24.0]
# Processing: N 41 45 33"
# After HTML replacement: N 41 45 33"
# Extracted numbers: [41.0, 45.0, 33.0]
# Processing: W 85 17 58
# After HTML replacement: W 85 17 58
# Extracted numbers: [85.0, 17.0, 58.0]
# Processing: W 84 42 34
# After HTML replacement: W 84 42 34
# Extracted numbers: [84.0, 42.0, 34.0]
# Processing: N 42 25 19
# After HTML replacement: N 42 25 19
# Extracted numbers: [42.0, 25.0, 19.0]
# Processing: N 42 04 13
# After HTML replacement: N 42 04 13
# Extracted numbers: [42.0, 4.0, 13.0]
# Processing: W 84 50 00
# After HTML replacement: W 84 50 00
# Extracted numbers: [84.0, 50.0, 0.0]
# Processing: W 84 23 00
# After HTML replacement: W 84 23 00
# Extracted numbers: [84.0, 23.0, 0.0]
# Processing: N 43 07 00
# After HTML replacement: N 43 07 00
# Extracted numbers: [43.0, 7.0, 0.0]
# Processing: N 42 46 30
# After HTML replacement: N 42 46 30
# Extracted numbers: [42.0, 46.0, 30.0]
# Processing: W 85 05 20
# After HTML replacement: W 85 05 20
# Extracted numbers: [85.0, 5.0, 20.0]
# Processing: W 84 36 22
# After HTML replacement: W 84 36 22
# Extracted numbers: [84.0, 36.0, 22.0]
# Processing: N 44 09 47
# After HTML replacement: N 44 09 47
# Extracted numbers: [44.0, 9.0, 47.0]
# Processing: N 43 48 44
# After HTML replacement: N 43 48 44
# Extracted numbers: [43.0, 48.0, 44.0]
# Processing: W 086.108208
# After HTML replacement: W 086.108208
# Processing: W 085.990677
# After HTML replacement: W 085.990677
# Processing: N 041.897736
# After HTML replacement: N 041.897736
# Processing: N 041.810662
# After HTML replacement: N 041.810662
# Processing: W 84⁰10
# After HTML replacement: W 84⁰10
# Extracted numbers: [84.0, 10.0]
# Processing: W 83⁰34
# After HTML replacement: W 83⁰34
# Extracted numbers: [83.0, 34.0]
# Processing: N 44⁰10
# After HTML replacement: N 44⁰10
# Extracted numbers: [44.0, 10.0]
# Processing: N43⁰54
# After HTML replacement: N43⁰54
# Extracted numbers: [43.0, 54.0]
# Processing: W 85 49 13
# After HTML replacement: W 85 49 13
# Extracted numbers: [85.0, 49.0, 13.0]
# Processing: W 85 19 54
# After HTML replacement: W 85 19 54
# Extracted numbers: [85.0, 19.0, 54.0]
# Processing: N 45 00 01
# After HTML replacement: N 45 00 01
# Extracted numbers: [45.0, 0.0, 1.0]
# Processing: N 44 30 41
# After HTML replacement: N 44 30 41
# Extracted numbers: [44.0, 30.0, 41.0]
# Processing: W 84 10 05
# After HTML replacement: W 84 10 05
# Extracted numbers: [84.0, 10.0, 5.0]
# Processing: W 83 41 54
# After HTML replacement: W 83 41 54
# Extracted numbers: [83.0, 41.0, 54.0]
# Processing: N 43 59 49
# After HTML replacement: N 43 59 49
# Extracted numbers: [43.0, 59.0, 49.0]
# Processing: N 43 28 43
# After HTML replacement: N 43 28 43
# Extracted numbers: [43.0, 28.0, 43.0]
# Processing: W 086.10755
# After HTML replacement: W 086.10755
# Processing: W 085.985422
# After HTML replacement: W 085.985422
# Processing: N 041.983721
# After HTML replacement: N 041.983721
# Processing: N 041.897103
# After HTML replacement: N 041.897103
# Processing: W 84 44 02
# After HTML replacement: W 84 44 02
# Extracted numbers: [84.0, 44.0, 2.0]
# Processing: W 84 14 51
# After HTML replacement: W 84 14 51
# Extracted numbers: [84.0, 14.0, 51.0]
# Processing: N 45 47 19
# After HTML replacement: N 45 47 19
# Extracted numbers: [45.0, 47.0, 19.0]
# Processing: N 45 11 54
# After HTML replacement: N 45 11 54
# Extracted numbers: [45.0, 11.0, 54.0]
# Processing: W 83 55 00
# After HTML replacement: W 83 55 00
# Extracted numbers: [83.0, 55.0, 0.0]
# Processing: W 83 27 00
# After HTML replacement: W 83 27 00
# Extracted numbers: [83.0, 27.0, 0.0]
# Processing: N 43 13 00
# After HTML replacement: N 43 13 00
# Extracted numbers: [43.0, 13.0, 0.0]
# Processing: N 42 46 00
# After HTML replacement: N 42 46 00
# Extracted numbers: [42.0, 46.0, 0.0]
# Processing: W 85 32 44
# After HTML replacement: W 85 32 44
# Extracted numbers: [85.0, 32.0, 44.0]
# Processing: W 85 04 24
# After HTML replacement: W 85 04 24
# Extracted numbers: [85.0, 4.0, 24.0]
# Processing: N 42 46 14
# After HTML replacement: N 42 46 14
# Extracted numbers: [42.0, 46.0, 14.0]
# Processing: N 42 25 10
# After HTML replacement: N 42 25 10
# Extracted numbers: [42.0, 25.0, 10.0]
# Processing: W 086.10789
# After HTML replacement: W 086.10789
# Processing: W 085.991215
# After HTML replacement: W 085.991215
# Processing: N 042.07081
# After HTML replacement: N 042.07081
# Processing: N 041.983493
# After HTML replacement: N 041.983493
# Processing: W 86 15 33
# After HTML replacement: W 86 15 33
# Extracted numbers: [86.0, 15.0, 33.0]
# Processing: W 85 48 57
# After HTML replacement: W 85 48 57
# Extracted numbers: [85.0, 48.0, 57.0]
# Processing: N 44 46 39
# After HTML replacement: N 44 46 39
# Extracted numbers: [44.0, 46.0, 39.0]
# Processing: N 44 30 42
# After HTML replacement: N 44 30 42
# Extracted numbers: [44.0, 30.0, 42.0]
# Processing: W 87 06'00"
# After HTML replacement: W 87 06'00"
# Extracted numbers: [87.0, 6.0, 0.0]
# Processing: W 85 51'00"
# After HTML replacement: W 85 51'00"
# Extracted numbers: [85.0, 51.0, 0.0]
# Processing: N 46 41'00"
# After HTML replacement: N 46 41'00"
# Extracted numbers: [46.0, 41.0, 0.0]
# Processing: N 46 09'00"
# After HTML replacement: N 46 09'00"
# Extracted numbers: [46.0, 9.0, 0.0]
# Processing: W 84 08
# After HTML replacement: W 84 08
# Extracted numbers: [84.0, 8.0]
# Processing: W 82 18
# After HTML replacement: W 82 18
# Extracted numbers: [82.0, 18.0]
# Processing: N 44 07
# After HTML replacement: N 44 07
# Extracted numbers: [44.0, 7.0]
# Processing: N 41 38
# After HTML replacement: N 41 38
# Extracted numbers: [41.0, 38.0]
# Processing: W 86 16 25
# After HTML replacement: W 86 16 25
# Extracted numbers: [86.0, 16.0, 25.0]
# Processing: W 85 32 34
# After HTML replacement: W 85 32 34
# Extracted numbers: [85.0, 32.0, 34.0]
# Processing: N 42 46 08
# After HTML replacement: N 42 46 08
# Extracted numbers: [42.0, 46.0, 8.0]
# Processing: N 42 25 07
# After HTML replacement: N 42 25 07
# Extracted numbers: [42.0, 25.0, 7.0]
# Processing: W 88°
# After HTML replacement: W 88°
# Extracted numbers: [88.0]
# Processing: W 82°
# After HTML replacement: W 82°
# Extracted numbers: [82.0]
# Processing: N 47°
# After HTML replacement: N 47°
# Extracted numbers: [47.0]
# Processing: N 41°30ʹ
# After HTML replacement: N 41°30'
# Extracted numbers: [41.0, 30.0]
# Processing: W 086.226101
# After HTML replacement: W 086.226101
# Processing: W 086.108208
# After HTML replacement: W 086.108208
# Processing: N 041.812112
# After HTML replacement: N 041.812112
# Processing: N 041.760414
# After HTML replacement: N 041.760414
# Processing: W 85 04 32
# After HTML replacement: W 85 04 32
# Extracted numbers: [85.0, 4.0, 32.0]
# Processing: W 84 36 01
# After HTML replacement: W 84 36 01
# Extracted numbers: [84.0, 36.0, 1.0]
# Processing: N 42 46 14
# After HTML replacement: N 42 46 14
# Extracted numbers: [42.0, 46.0, 14.0]
# Processing: N 42 25 17
# After HTML replacement: N 42 25 17
# Extracted numbers: [42.0, 25.0, 17.0]
# Processing: W 84 36 29
# After HTML replacement: W 84 36 29
# Extracted numbers: [84.0, 36.0, 29.0]
# Processing: W 84 09 57
# After HTML replacement: W 84 09 57
# Extracted numbers: [84.0, 9.0, 57.0]
# Processing: N 44 09 42
# After HTML replacement: N 44 09 42
# Extracted numbers: [44.0, 9.0, 42.0]
# Processing: N 43 48 48
# After HTML replacement: N 43 48 48
# Extracted numbers: [43.0, 48.0, 48.0]
# Processing: W 86°02ʹ28ʺ
# After HTML replacement: W 86°02'28"
# Extracted numbers: [86.0, 2.0, 28.0]
# Processing: W 85°33ʹ43ʺ
# After HTML replacement: W 85°33'43"
# Extracted numbers: [85.0, 33.0, 43.0]
# Processing: N 44°09ʹ58ʺ
# After HTML replacement: N 44°09'58"
# Extracted numbers: [44.0, 9.0, 58.0]
# Processing: N 43°48ʹ49ʺ
# After HTML replacement: N 43°48'49"
# Extracted numbers: [43.0, 48.0, 49.0]
# Processing: W 86°09ʹ23ʺ
# After HTML replacement: W 86°09'23"
# Extracted numbers: [86.0, 9.0, 23.0]
# Processing: W 85°31ʹ36ʺ
# After HTML replacement: W 85°31'36"
# Extracted numbers: [85.0, 31.0, 36.0]
# Processing: N 45°29ʹ29ʺ
# After HTML replacement: N 45°29'29"
# Extracted numbers: [45.0, 29.0, 29.0]
# Processing: N 44°46ʹ27ʺ
# After HTML replacement: N 44°46'27"
# Extracted numbers: [44.0, 46.0, 27.0]
# Processing: W 086.225189
# After HTML replacement: W 086.225189
# Processing: W 086.10753
# After HTML replacement: W 086.10753
# Processing: N 041.898729
# After HTML replacement: N 041.898729
# Processing: N 041.811133
# After HTML replacement: N 041.811133
# Processing: W 83°06ʹ10ʺ
# After HTML replacement: W 83°06'10"
# Extracted numbers: [83.0, 6.0, 10.0]
# Processing: W 82°42ʹ21ʺ
# After HTML replacement: W 82°42'21"
# Extracted numbers: [82.0, 42.0, 21.0]
# Processing: N 42°53ʹ51ʺ
# After HTML replacement: N 42°53'51"
# Extracted numbers: [42.0, 53.0, 51.0]
# Processing: N 42°26ʹ49ʺ
# After HTML replacement: N 42°26'49"
# Extracted numbers: [42.0, 26.0, 49.0]
# Processing: W 83°06ʹ10ʺ
# After HTML replacement: W 83°06'10"
# Extracted numbers: [83.0, 6.0, 10.0]
# Processing: W 82°42ʹ21ʺ
# After HTML replacement: W 82°42'21"
# Extracted numbers: [82.0, 42.0, 21.0]
# Processing: N 42°53ʹ51ʺ
# After HTML replacement: N 42°53'51"
# Extracted numbers: [42.0, 53.0, 51.0]
# Processing: N 42°26ʹ49ʺ
# After HTML replacement: N 42°26'49"
# Extracted numbers: [42.0, 26.0, 49.0]
# Processing: W 86°30ʹ55ʺ
# After HTML replacement: W 86°30'55"
# Extracted numbers: [86.0, 30.0, 55.0]
# Processing: W 86°02ʹ16ʺ
# After HTML replacement: W 86°02'16"
# Extracted numbers: [86.0, 2.0, 16.0]
# Processing: N 44°10ʹ46ʺ
# After HTML replacement: N 44°10'46"
# Extracted numbers: [44.0, 10.0, 46.0]
# Processing: N 43°48ʹ50ʺ
# After HTML replacement: N 43°48'50"
# Extracted numbers: [43.0, 48.0, 50.0]
# Processing: W 85°33ʹ51ʺ
# After HTML replacement: W 85°33'51"
# Extracted numbers: [85.0, 33.0, 51.0]
# Processing: W 85°05ʹ04ʺ
# After HTML replacement: W 85°05'04"
# Extracted numbers: [85.0, 5.0, 4.0]
# Processing: N 43°48ʹ51ʺ
# After HTML replacement: N 43°48'51"
# Extracted numbers: [43.0, 48.0, 51.0]
# Processing: N 43°27ʹ57ʺ
# After HTML replacement: N 43°27'57"
# Extracted numbers: [43.0, 27.0, 57.0]
# Processing: W 84°36ʹ30ʺ
# After HTML replacement: W 84°36'30"
# Extracted numbers: [84.0, 36.0, 30.0]
# Processing: W 84°09ʹ19ʺ
# After HTML replacement: W 84°09'19"
# Extracted numbers: [84.0, 9.0, 19.0]
# Processing: N 43°49ʹ42ʺ
# After HTML replacement: N 43°49'42"
# Extracted numbers: [43.0, 49.0, 42.0]
# Processing: N 43°27ʹ56ʺ
# After HTML replacement: N 43°27'56"
# Extracted numbers: [43.0, 27.0, 56.0]
# Processing: W 086.223456
# After HTML replacement: W 086.223456
# Processing: W 086.107263
# After HTML replacement: W 086.107263
# Processing: N 041.984601
# After HTML replacement: N 041.984601
# Processing: N 041.897726
# After HTML replacement: N 041.897726
# Processing: W 85°20ʹ16ʺ
# After HTML replacement: W 85°20'16"
# Extracted numbers: [85.0, 20.0, 16.0]
# Processing: W 84°51ʹ12ʺ
# After HTML replacement: W 84°51'12"
# Extracted numbers: [84.0, 51.0, 12.0]
# Processing: N 44°30ʹ43ʺ
# After HTML replacement: N 44°30'43"
# Extracted numbers: [44.0, 30.0, 43.0]
# Processing: N 44°09ʹ37ʺ
# After HTML replacement: N 44°09'37"
# Extracted numbers: [44.0, 9.0, 37.0]
# Processing: W 83°46ʹ26ʺ
# After HTML replacement: W 83°46'26"
# Extracted numbers: [83.0, 46.0, 26.0]
# Processing: W 83°11ʹ20ʺ
# After HTML replacement: W 83°11'20"
# Extracted numbers: [83.0, 11.0, 20.0]
# Processing: N 42°05ʹ39ʺ
# After HTML replacement: N 42°05'39"
# Extracted numbers: [42.0, 5.0, 39.0]
# Processing: N 41°43ʹ24ʺ
# After HTML replacement: N 41°43'24"
# Extracted numbers: [41.0, 43.0, 24.0]
# Processing: W 84°22ʹ22ʺ
# After HTML replacement: W 84°22'22"
# Extracted numbers: [84.0, 22.0, 22.0]
# Processing: W 83°52ʹ50ʺ
# After HTML replacement: W 83°52'50"
# Extracted numbers: [83.0, 52.0, 50.0]
# Processing: N 45°12ʹ07ʺ
# After HTML replacement: N 45°12'07"
# Extracted numbers: [45.0, 12.0, 7.0]
# Processing: N 44°51ʹ18ʺ
# After HTML replacement: N 44°51'18"
# Extracted numbers: [44.0, 51.0, 18.0]
# Processing: W 85°50ʹ46ʺ
# After HTML replacement: W 85°50'46"
# Extracted numbers: [85.0, 50.0, 46.0]
# Processing: W 84°43ʹ54ʺ
# After HTML replacement: W 84°43'54"
# Extracted numbers: [84.0, 43.0, 54.0]
# Processing: N 45°50ʹ29ʺ
# After HTML replacement: N 45°50'29"
# Extracted numbers: [45.0, 50.0, 29.0]
# Processing: N 45°06ʹ56ʺ
# After HTML replacement: N 45°06'56"
# Extracted numbers: [45.0, 6.0, 56.0]
# Processing: W 86°02ʹ27ʺ
# After HTML replacement: W 86°02'27"
# Extracted numbers: [86.0, 2.0, 27.0]
# Processing: W 85°33ʹ46ʺ
# After HTML replacement: W 85°33'46"
# Extracted numbers: [85.0, 33.0, 46.0]
# Processing: N 43°48ʹ51ʺ
# After HTML replacement: N 43°48'51"
# Extracted numbers: [43.0, 48.0, 51.0]
# Processing: N 43°17ʹ27ʺ
# After HTML replacement: N 43°17'27"
# Extracted numbers: [43.0, 17.0, 27.0]
# Processing: W 86°32ʹ29ʺ
# After HTML replacement: W 86°32'29"
# Extracted numbers: [86.0, 32.0, 29.0]
# Processing: W 86°02ʹ18ʺ
# After HTML replacement: W 86°02'18"
# Extracted numbers: [86.0, 2.0, 18.0]
# Processing: N 43°49ʹ08ʺ
# After HTML replacement: N 43°49'08"
# Extracted numbers: [43.0, 49.0, 8.0]
# Processing: N 43°28ʹ02ʺ
# After HTML replacement: N 43°28'02"
# Extracted numbers: [43.0, 28.0, 2.0]
# Processing: W 89°53ʹ07ʺ
# After HTML replacement: W 89°53'07"
# Extracted numbers: [89.0, 53.0, 7.0]
# Processing: W 88°51ʹ49ʺ
# After HTML replacement: W 88°51'49"
# Extracted numbers: [88.0, 51.0, 49.0]
# Processing: N 47°01ʹ44ʺ
# After HTML replacement: N 47°01'44"
# Extracted numbers: [47.0, 1.0, 44.0]
# Processing: N 46°19ʹ49ʺ
# After HTML replacement: N 46°19'49"
# Extracted numbers: [46.0, 19.0, 49.0]
# Processing: W 84°51ʹ38ʺ
# After HTML replacement: W 84°51'38"
# Extracted numbers: [84.0, 51.0, 38.0]
# Processing: W 84°22ʹ11ʺ
# After HTML replacement: W 84°22'11"
# Extracted numbers: [84.0, 22.0, 11.0]
# Processing: N 45°12ʹ07ʺ
# After HTML replacement: N 45°12'07"
# Extracted numbers: [45.0, 12.0, 7.0]
# Processing: N 44°51ʹ21ʺ
# After HTML replacement: N 44°51'21"
# Extracted numbers: [44.0, 51.0, 21.0]
# Processing: W 84°22ʹ11ʺ
# After HTML replacement: W 84°22'11"
# Extracted numbers: [84.0, 22.0, 11.0]
# Processing: W 83°41ʹ42ʺ
# After HTML replacement: W 83°41'42"
# Extracted numbers: [83.0, 41.0, 42.0]
# Processing: N 43°34ʹ08ʺ
# After HTML replacement: N 43°34'08"
# Extracted numbers: [43.0, 34.0, 8.0]
# Processing: N 43°07ʹ43ʺ
# After HTML replacement: N 43°07'43"
# Extracted numbers: [43.0, 7.0, 43.0]
# Processing: W 83°07ʹ13ʺ
# After HTML replacement: W 83°07'13"
# Extracted numbers: [83.0, 7.0, 13.0]
# Processing: W 82°30ʹ11ʺ
# After HTML replacement: W 82°30'11"
# Extracted numbers: [82.0, 30.0, 11.0]
# Processing: N 43°41ʹ25ʺ
# After HTML replacement: N 43°41'25"
# Extracted numbers: [43.0, 41.0, 25.0]
# Processing: N 43°09ʹ14ʺ
# After HTML replacement: N 43°09'14"
# Extracted numbers: [43.0, 9.0, 14.0]
# Processing: W 085.107341
# After HTML replacement: W 085.107341
# Processing: W 084.998117
# After HTML replacement: W 084.998117
# Processing: N 045.356013
# After HTML replacement: N 045.356013
# Processing: N 045.262308
# After HTML replacement: N 045.262308
# Processing: W 83°07ʹ13ʺ
# After HTML replacement: W 83°07'13"
# Extracted numbers: [83.0, 7.0, 13.0]
# Processing: W 82°30ʹ11ʺ
# After HTML replacement: W 82°30'11"
# Extracted numbers: [82.0, 30.0, 11.0]
# Processing: N 43°41ʹ25ʺ
# After HTML replacement: N 43°41'25"
# Extracted numbers: [43.0, 41.0, 25.0]
# Processing: N 43°09ʹ14ʺ
# After HTML replacement: N 43°09'14"
# Extracted numbers: [43.0, 9.0, 14.0]
# Processing: W 85°47ʹ26ʺ
# After HTML replacement: W 85°47'26"
# Extracted numbers: [85.0, 47.0, 26.0]
# Processing: W 85°18ʹ39ʺ
# After HTML replacement: W 85°18'39"
# Extracted numbers: [85.0, 18.0, 39.0]
# Processing: N 43°17ʹ39ʺ
# After HTML replacement: N 43°17'39"
# Extracted numbers: [43.0, 17.0, 39.0]
# Processing: N 42°46ʹ05ʺ
# After HTML replacement: N 42°46'05"
# Extracted numbers: [42.0, 46.0, 5.0]
# Processing: W 89°19ʹ
# After HTML replacement: W 89°19'
# Extracted numbers: [89.0, 19.0]
# Processing: W 87°35ʹ
# After HTML replacement: W 87°35'
# Extracted numbers: [87.0, 35.0]
# Processing: N 48°15ʹ
# After HTML replacement: N 48°15'
# Extracted numbers: [48.0, 15.0]
# Processing: N 47°11ʹ
# After HTML replacement: N 47°11'
# Extracted numbers: [47.0, 11.0]
# Processing: W 84°54ʹ
# After HTML replacement: W 84°54'
# Extracted numbers: [84.0, 54.0]
# Processing: W 84°20ʹ
# After HTML replacement: W 84°20'
# Extracted numbers: [84.0, 20.0]
# Processing: N 44°31ʹ
# After HTML replacement: N 44°31'
# Extracted numbers: [44.0, 31.0]
# Processing: N 44°09ʹ
# After HTML replacement: N 44°09'
# Extracted numbers: [44.0, 9.0]
# Processing: W 084.9787
# After HTML replacement: W 084.9787
# Processing: W 084.855106
# After HTML replacement: W 084.855106
# Processing: N 045.204809
# After HTML replacement: N 045.204809
# Processing: N 045.116637
# After HTML replacement: N 045.116637
# Processing: W 88°07ʹ03ʺ
# After HTML replacement: W 88°07'03"
# Extracted numbers: [88.0, 7.0, 3.0]
# Processing: W 87°06ʹ57ʺ
# After HTML replacement: W 87°06'57"
# Extracted numbers: [87.0, 6.0, 57.0]
# Processing: N 46°57ʹ59ʺ
# After HTML replacement: N 46°57'59"
# Extracted numbers: [46.0, 57.0, 59.0]
# Processing: N 45°59ʹ06ʺ
# After HTML replacement: N 45°59'06"
# Extracted numbers: [45.0, 59.0, 6.0]
# Processing: W 86°16ʹ00ʺ
# After HTML replacement: W 86°16'00"
# Extracted numbers: [86.0, 16.0, 0.0]
# Processing: W 85°46ʹ00ʺ
# After HTML replacement: W 85°46'00"
# Extracted numbers: [85.0, 46.0, 0.0]
# Processing: N 43°12ʹ00ʺ
# After HTML replacement: N 43°12'00"
# Extracted numbers: [43.0, 12.0, 0.0]
# Processing: N 42°46ʹ00ʺ
# After HTML replacement: N 42°46'00"
# Extracted numbers: [42.0, 46.0, 0.0]
# Processing: W 83°41ʹ57ʺ
# After HTML replacement: W 83°41'57"
# Extracted numbers: [83.0, 41.0, 57.0]
# Processing: W 83°06ʹ13ʺ
# After HTML replacement: W 83°06'13"
# Extracted numbers: [83.0, 6.0, 13.0]
# Processing: N 43°44ʹ02ʺ
# After HTML replacement: N 43°44'02"
# Extracted numbers: [43.0, 44.0, 2.0]
# Processing: N 43°13ʹ17ʺ
# After HTML replacement: N 43°13'17"
# Extracted numbers: [43.0, 13.0, 17.0]
# Processing: W 84°15ʹ07ʺ
# After HTML replacement: W 84°15'07"
# Extracted numbers: [84.0, 15.0, 7.0]
# Processing: W 83°22ʹ50ʺ
# After HTML replacement: W 83°22'50"
# Extracted numbers: [83.0, 22.0, 50.0]
# Processing: N 45°37ʹ34ʺ
# After HTML replacement: N 45°37'34"
# Extracted numbers: [45.0, 37.0, 34.0]
# Processing: N 45°11ʹ54ʺ
# After HTML replacement: N 45°11'54"
# Extracted numbers: [45.0, 11.0, 54.0]
# Processing: W 84°08ʹ02ʺ
# After HTML replacement: W 84°08'02"
# Extracted numbers: [84.0, 8.0, 2.0]
# Processing: W 83°32ʹ21ʺ
# After HTML replacement: W 83°32'21"
# Extracted numbers: [83.0, 32.0, 21.0]
# Processing: N 42°26ʹ06ʺ
# After HTML replacement: N 42°26'06"
# Extracted numbers: [42.0, 26.0, 6.0]
# Processing: N 42°04ʹ17ʺ
# After HTML replacement: N 42°04'17"
# Extracted numbers: [42.0, 4.0, 17.0]
# Processing: W 084.855488
# After HTML replacement: W 084.855488
# Processing: W 084.732693
# After HTML replacement: W 084.732693
# Processing: N 045.290649
# After HTML replacement: N 045.290649
# Processing: N 045.201943
# After HTML replacement: N 045.201943
# Processing: W 85°49ʹ16ʺ
# After HTML replacement: W 85°49'16"
# Extracted numbers: [85.0, 49.0, 16.0]
# Processing: W 85°20ʹ02ʺ
# After HTML replacement: W 85°20'02"
# Extracted numbers: [85.0, 20.0, 2.0]
# Processing: N 44°30ʹ46ʺ
# After HTML replacement: N 44°30'46"
# Extracted numbers: [44.0, 30.0, 46.0]
# Processing: N 44°09ʹ51ʺ
# After HTML replacement: N 44°09'51"
# Extracted numbers: [44.0, 9.0, 51.0]
# Processing: W 84°22ʹ04ʺ
# After HTML replacement: W 84°22'04"
# Extracted numbers: [84.0, 22.0, 4.0]
# Processing: W 83°55ʹ20ʺ
# After HTML replacement: W 83°55'20"
# Extracted numbers: [83.0, 55.0, 20.0]
# Processing: N 43°07ʹ57ʺ
# After HTML replacement: N 43°07'57"
# Extracted numbers: [43.0, 7.0, 57.0]
# Processing: N 42°46ʹ32ʺ
# After HTML replacement: N 42°46'32"
# Extracted numbers: [42.0, 46.0, 32.0]
# Processing: W 85°33ʹ52ʺ
# After HTML replacement: W 85°33'52"
# Extracted numbers: [85.0, 33.0, 52.0]
# Processing: W 85°05ʹ14ʺ
# After HTML replacement: W 85°05'14"
# Extracted numbers: [85.0, 5.0, 14.0]
# Processing: N 44°09ʹ54ʺ
# After HTML replacement: N 44°09'54"
# Extracted numbers: [44.0, 9.0, 54.0]
# Processing: N 43°48ʹ48ʺ
# After HTML replacement: N 43°48'48"
# Extracted numbers: [43.0, 48.0, 48.0]
# Processing: W 84°22ʹ14ʺ
# After HTML replacement: W 84°22'14"
# Extracted numbers: [84.0, 22.0, 14.0]
# Processing: W 83°52ʹ59ʺ
# After HTML replacement: W 83°52'59"
# Extracted numbers: [83.0, 52.0, 59.0]
# Processing: N 44°30ʹ31ʺ
# After HTML replacement: N 44°30'31"
# Extracted numbers: [44.0, 30.0, 31.0]
# Processing: N 44°09ʹ37ʺ
# After HTML replacement: N 44°09'37"
# Extracted numbers: [44.0, 9.0, 37.0]
# Processing: W 085.335594
# After HTML replacement: W 085.335594
# Processing: W 085.219321
# After HTML replacement: W 085.219321
# Processing: N 045.349603
# After HTML replacement: N 045.349603
# Processing: N 045.293011
# After HTML replacement: N 045.293011
# Processing: W 83°06ʹ10ʺ
# After HTML replacement: W 83°06'10"
# Extracted numbers: [83.0, 6.0, 10.0]
# Processing: W 82°42ʹ21ʺ
# After HTML replacement: W 82°42'21"
# Extracted numbers: [82.0, 42.0, 21.0]
# Processing: N 42°53ʹ51ʺ
# After HTML replacement: N 42°53'51"
# Extracted numbers: [42.0, 53.0, 51.0]
# Processing: N 42°26ʹ49ʺ
# After HTML replacement: N 42°26'49"
# Extracted numbers: [42.0, 26.0, 49.0]
# Processing: W 83°06ʹ10ʺ
# After HTML replacement: W 83°06'10"
# Extracted numbers: [83.0, 6.0, 10.0]
# Processing: W 82°42ʹ21ʺ
# After HTML replacement: W 82°42'21"
# Extracted numbers: [82.0, 42.0, 21.0]
# Processing: N 42°53ʹ51ʺ
# After HTML replacement: N 42°53'51"
# Extracted numbers: [42.0, 53.0, 51.0]
# Processing: N 42°26ʹ49ʺ
# After HTML replacement: N 42°26'49"
# Extracted numbers: [42.0, 26.0, 49.0]
# Processing: W 83°41ʹ21ʺ
# After HTML replacement: W 83°41'21"
# Extracted numbers: [83.0, 41.0, 21.0]
# Processing: W 83°05ʹ00ʺ
# After HTML replacement: W 83°05'00"
# Extracted numbers: [83.0, 5.0, 0.0]
# Processing: N 42°53ʹ19ʺ
# After HTML replacement: N 42°53'19"
# Extracted numbers: [42.0, 53.0, 19.0]
# Processing: N 42°25ʹ52ʺ
# After HTML replacement: N 42°25'52"
# Extracted numbers: [42.0, 25.0, 52.0]
# Processing: W86⁰37ʹ
# After HTML replacement: W86⁰37'
# Extracted numbers: [86.0, 37.0]
# Processing: W85⁰51ʹ
# After HTML replacement: W85⁰51'
# Extracted numbers: [85.0, 51.0]
# Processing: N46⁰31ʹ
# After HTML replacement: N46⁰31'
# Extracted numbers: [46.0, 31.0]
# Processing: N45⁰45ʹ
# After HTML replacement: N45⁰45'
# Extracted numbers: [45.0, 45.0]
# Processing: W 085.222849
# After HTML replacement: W 085.222849
# Processing: W 085.03936
# After HTML replacement: W 085.03936
# Processing: N 045.295417
# After HTML replacement: N 045.295417
# Processing: N 045.204633
# After HTML replacement: N 045.204633
# Processing: W 83°41ʹ21ʺ
# After HTML replacement: W 83°41'21"
# Extracted numbers: [83.0, 41.0, 21.0]
# Processing: W 83°05ʹ00ʺ
# After HTML replacement: W 83°05'00"
# Extracted numbers: [83.0, 5.0, 0.0]
# Processing: N 42°53ʹ19ʺ
# After HTML replacement: N 42°53'19"
# Extracted numbers: [42.0, 53.0, 19.0]
# Processing: N 42°25ʹ52ʺ
# After HTML replacement: N 42°25'52"
# Extracted numbers: [42.0, 25.0, 52.0]
# Processing: W 85°20ʹ02ʺ
# After HTML replacement: W 85°20'02"
# Extracted numbers: [85.0, 20.0, 2.0]
# Processing: W 84°50ʹ50ʺ
# After HTML replacement: W 84°50'50"
# Extracted numbers: [84.0, 50.0, 50.0]
# Processing: N 44°51ʹ34ʺ
# After HTML replacement: N 44°51'34"
# Extracted numbers: [44.0, 51.0, 34.0]
# Processing: N 44°30ʹ37ʺ
# After HTML replacement: N 44°30'37"
# Extracted numbers: [44.0, 30.0, 37.0]
# Processing: W 86°23ʹ19ʺ
# After HTML replacement: W 86°23'19"
# Extracted numbers: [86.0, 23.0, 19.0]
# Processing: W 85°49ʹ03ʺ
# After HTML replacement: W 85°49'03"
# Extracted numbers: [85.0, 49.0, 3.0]
# Processing: N 44°31ʹ05ʺ
# After HTML replacement: N 44°31'05"
# Extracted numbers: [44.0, 31.0, 5.0]
# Processing: N 44°09ʹ51ʺ
# After HTML replacement: N 44°09'51"
# Extracted numbers: [44.0, 9.0, 51.0]
# Processing: W 84°22ʹ18ʺ
# After HTML replacement: W 84°22'18"
# Extracted numbers: [84.0, 22.0, 18.0]
# Processing: W 83°53ʹ11ʺ
# After HTML replacement: W 83°53'11"
# Extracted numbers: [83.0, 53.0, 11.0]
# Processing: N 44°51ʹ23ʺ
# After HTML replacement: N 44°51'23"
# Extracted numbers: [44.0, 51.0, 23.0]
# Processing: N 44°30ʹ25ʺ
# After HTML replacement: N 44°30'25"
# Extracted numbers: [44.0, 30.0, 25.0]
# Processing: W 85°51ʹ55ʺ
# After HTML replacement: W 85°51'55"
# Extracted numbers: [85.0, 51.0, 55.0]
# Processing: W 84°06ʹ50ʺ
# After HTML replacement: W 84°06'50"
# Extracted numbers: [84.0, 6.0, 50.0]
# Processing: N 46°14ʹ44ʺ
# After HTML replacement: N 46°14'44"
# Extracted numbers: [46.0, 14.0, 44.0]
# Processing: N 45°43ʹ05ʺ
# After HTML replacement: N 45°43'05"
# Extracted numbers: [45.0, 43.0, 5.0]
# Processing: W 085.098563
# After HTML replacement: W 085.098563
# Processing: W 084.974646
# After HTML replacement: W 084.974646
# Processing: N 045.274732
# After HTML replacement: N 045.274732
# Processing: N 045.208016
# After HTML replacement: N 045.208016
# Processing: W 85°33ʹ45ʺ
# After HTML replacement: W 85°33'45"
# Extracted numbers: [85.0, 33.0, 45.0]
# Processing: W 84°50ʹ06ʺ
# After HTML replacement: W 84°50'06"
# Extracted numbers: [84.0, 50.0, 6.0]
# Processing: N 43°28ʹ05ʺ
# After HTML replacement: N 43°28'05"
# Extracted numbers: [43.0, 28.0, 5.0]
# Processing: N 43°07ʹ07ʺ
# After HTML replacement: N 43°07'07"
# Extracted numbers: [43.0, 7.0, 7.0]
# Processing: W 83°27ʹ38"
# After HTML replacement: W 83°27'38"
# Extracted numbers: [83.0, 27.0, 38.0]
# Processing: W 82°59ʹ01"
# After HTML replacement: W 82°59'01"
# Extracted numbers: [82.0, 59.0, 1.0]
# Processing: N 43°19ʹ37"
# After HTML replacement: N 43°19'37"
# Extracted numbers: [43.0, 19.0, 37.0]
# Processing: N 42°52ʹ49"
# After HTML replacement: N 42°52'49"
# Extracted numbers: [42.0, 52.0, 49.0]
# Processing: W 85°51ʹ54ʺ
# After HTML replacement: W 85°51'54"
# Extracted numbers: [85.0, 51.0, 54.0]
# Processing: W 85°14ʹ15ʺ
# After HTML replacement: W 85°14'15"
# Extracted numbers: [85.0, 14.0, 15.0]
# Processing: N 46°45ʹ18ʺ
# After HTML replacement: N 46°45'18"
# Extracted numbers: [46.0, 45.0, 18.0]
# Processing: N 46°14ʹ41ʺ
# After HTML replacement: N 46°14'41"
# Extracted numbers: [46.0, 14.0, 41.0]
# Processing: W 84°09ʹ29"
# After HTML replacement: W 84°09'29"
# Extracted numbers: [84.0, 9.0, 29.0]
# Processing: W 83°39ʹ53"
# After HTML replacement: W 83°39'53"
# Extracted numbers: [83.0, 39.0, 53.0]
# Processing: N 42°46ʹ59"
# After HTML replacement: N 42°46'59"
# Extracted numbers: [42.0, 46.0, 59.0]
# Processing: N 42°25ʹ26"
# After HTML replacement: N 42°25'26"
# Extracted numbers: [42.0, 25.0, 26.0]
# Processing: W 87°00ʹ
# After HTML replacement: W 87°00'
# Extracted numbers: [87.0, 0.0]
# Processing: W 82°30ʹ
# After HTML replacement: W 82°30'
# Extracted numbers: [82.0, 30.0]
# Processing: N 43°30ʹ
# After HTML replacement: N 43°30'
# Extracted numbers: [43.0, 30.0]
# Processing: N 41°30ʹ
# After HTML replacement: N 41°30'
# Extracted numbers: [41.0, 30.0]
# Processing: W 084.857457
# After HTML replacement: W 084.857457
# Processing: W 084.734308
# After HTML replacement: W 084.734308
# Processing: N 045.203942
# After HTML replacement: N 045.203942
# Processing: N 045.114912
# After HTML replacement: N 045.114912
# Processing: W 86°27ʹ42ʺ
# After HTML replacement: W 86°27'42"
# Extracted numbers: [86.0, 27.0, 42.0]
# Processing: W 85°47ʹ25ʺ
# After HTML replacement: W 85°47'25"
# Extracted numbers: [85.0, 47.0, 25.0]
# Processing: N 43°28ʹ21ʺ
# After HTML replacement: N 43°28'21"
# Extracted numbers: [43.0, 28.0, 21.0]
# Processing: N 43°07ʹ02ʺ
# After HTML replacement: N 43°07'02"
# Extracted numbers: [43.0, 7.0, 2.0]
# Processing: W 87°53ʹ17ʺ
# After HTML replacement: W 87°53'17"
# Extracted numbers: [87.0, 53.0, 17.0]
# Processing: W 87°15ʹ48ʺ
# After HTML replacement: W 87°15'48"
# Extracted numbers: [87.0, 15.0, 48.0]
# Processing: N 45°59ʹ09ʺ
# After HTML replacement: N 45°59'09"
# Extracted numbers: [45.0, 59.0, 9.0]
# Processing: N 45°05ʹ41ʺ
# After HTML replacement: N 45°05'41"
# Extracted numbers: [45.0, 5.0, 41.0]
# Processing: W 83°33ʹ06ʺ
# After HTML replacement: W 83°33'06"
# Extracted numbers: [83.0, 33.0, 6.0]
# Processing: W 82°45ʹ01ʺ
# After HTML replacement: W 82°45'01"
# Extracted numbers: [82.0, 45.0, 1.0]
# Processing: N 42°27ʹ05ʺ
# After HTML replacement: N 42°27'05"
# Extracted numbers: [42.0, 27.0, 5.0]
# Processing: N 42°01ʹ40ʺ
# After HTML replacement: N 42°01'40"
# Extracted numbers: [42.0, 1.0, 40.0]
# Error while extracting bounding box: 'NoneType' object has no attribute 'split'
# Processing: W 085.324064
# After HTML replacement: W 085.324064
# Processing: W 085.221584
# After HTML replacement: W 085.221584
# Processing: N 045.293558
# After HTML replacement: N 045.293558
# Processing: N 045.20556
# After HTML replacement: N 045.20556
# Processing: W 86°21ʹ47ʺ
# After HTML replacement: W 86°21'47"
# Extracted numbers: [86.0, 21.0, 47.0]
# Processing: W 85°45ʹ49ʺ
# After HTML replacement: W 85°45'49"
# Extracted numbers: [85.0, 45.0, 49.0]
# Processing: N 42°25ʹ14ʺ
# After HTML replacement: N 42°25'14"
# Extracted numbers: [42.0, 25.0, 14.0]
# Processing: N 42°04ʹ07ʺ
# After HTML replacement: N 42°04'07"
# Extracted numbers: [42.0, 4.0, 7.0]
# Processing: W 82°59ʹ46ʺ
# After HTML replacement: W 82°59'46"
# Extracted numbers: [82.0, 59.0, 46.0]
# Processing: W 82°20ʹ07ʺ
# After HTML replacement: W 82°20'07"
# Extracted numbers: [82.0, 20.0, 7.0]
# Processing: N 43°10ʹ08ʺ
# After HTML replacement: N 43°10'08"
# Extracted numbers: [43.0, 10.0, 8.0]
# Processing: N 42°28ʹ44ʺ
# After HTML replacement: N 42°28'44"
# Extracted numbers: [42.0, 28.0, 44.0]
# Processing: W 85°47ʹ30ʺ
# After HTML replacement: W 85°47'30"
# Extracted numbers: [85.0, 47.0, 30.0]
# Processing: W 85°17ʹ31ʺ
# After HTML replacement: W 85°17'31"
# Extracted numbers: [85.0, 17.0, 31.0]
# Processing: N 42°04ʹ17ʺ
# After HTML replacement: N 42°04'17"
# Extracted numbers: [42.0, 4.0, 17.0]
# Processing: N 41°45ʹ32ʺ
# After HTML replacement: N 41°45'32"
# Extracted numbers: [41.0, 45.0, 32.0]
# Processing: W 84°15ʹ02ʺ
# After HTML replacement: W 84°15'02"
# Extracted numbers: [84.0, 15.0, 2.0]
# Processing: W 83°22ʹ50ʺ
# After HTML replacement: W 83°22'50"
# Extracted numbers: [83.0, 22.0, 50.0]
# Processing: N 45°38ʹ26ʺ
# After HTML replacement: N 45°38'26"
# Extracted numbers: [45.0, 38.0, 26.0]
# Processing: N 45°11ʹ54ʺ
# After HTML replacement: N 45°11'54"
# Extracted numbers: [45.0, 11.0, 54.0]
# Processing: W 085.391118
# After HTML replacement: W 085.391118
# Processing: W 085.301208
# After HTML replacement: W 085.301208
# Processing: N 045.29341
# After HTML replacement: N 045.29341
# Processing: N 045.206907
# After HTML replacement: N 045.206907
# Processing: W 084.2520
# After HTML replacement: W 084.2520
# Processing: W 083.3808
# After HTML replacement: W 083.3808
# Processing: N 045.6263
# After HTML replacement: N 045.6263
# Processing: N 045.1986
# After HTML replacement: N 045.1986
# Processing: W 83.52
# After HTML replacement: W 83.52
# Processing: W 83.3805
# After HTML replacement: W 83.3805
# Processing: N 45.3605
# After HTML replacement: N 45.3605
# Processing: N 45.2067
# After HTML replacement: N 45.2067
# Processing: W 83.52138
# After HTML replacement: W 83.52138
# Processing: W 83.42
# After HTML replacement: W 83.42
# Processing: N 45.36833
# After HTML replacement: N 45.36833
# Processing: N 45.29388
# After HTML replacement: N 45.29388
# Processing: W 83.63972
# After HTML replacement: W 83.63972
# Processing: W 83.51361
# After HTML replacement: W 83.51361
# Processing: N 45.37083
# After HTML replacement: N 45.37083
# Processing: N 45.2044
# After HTML replacement: N 45.2044
# Processing: W 83.66694
# After HTML replacement: W 83.66694
# Processing: W 83.48722
# After HTML replacement: W 83.48722
# Processing: N 45.3778
# After HTML replacement: N 45.3778
# Processing: N 45.25833
# After HTML replacement: N 45.25833
# Processing: W 83.76083
# After HTML replacement: W 83.76083
# Processing: W 83.63667
# After HTML replacement: W 83.63667
# Processing: N 45.29194
# After HTML replacement: N 45.29194
# Processing: N 45.2044
# After HTML replacement: N 45.2044
# Processing: W 83.76212534
# After HTML replacement: W 83.76212534
# Processing: W 83.63796958
# After HTML replacement: W 83.63796958
# Processing: N 45.29077334
# After HTML replacement: N 45.29077334
# Processing: N 45.37730666
# After HTML replacement: N 45.37730666
# Processing: W 83.76244994
# After HTML replacement: W 83.76244994
# Processing: W 83.63958347
# After HTML replacement: W 83.63958347
# Processing: N 45.37601559
# ...
# Processing: W 085.335594
# After HTML replacement: W 085.335594
# Processing: W 085.219321
# After HTML replacement: W 085.219321
# Processing: N 045.349603
# After HTML replacement: N 045.349603
# Processing: N 045.293011
# After HTML replacement: N 045.293011
# Processing: W 084.857457
# After HTML replacement: W 084.857457
# Processing: W 084.734308
# After HTML replacement: W 084.734308
# Processing: N 045.203942
# After HTML replacement: N 045.203942
# Processing: N 045.114912
# After HTML replacement: N 045.114912
# Processing: W 085.324064
# After HTML replacement: W 085.324064
# Processing: W 085.221584
# After HTML replacement: W 085.221584
# Processing: N 045.293558
# After HTML replacement: N 045.293558
# Processing: N 045.20556
# After HTML replacement: N 045.20556
# Processing: W 084.97775
# After HTML replacement: W 084.97775
# Processing: W 084.853202
# After HTML replacement: W 084.853202
# Processing: N 045.291643
# After HTML replacement: N 045.291643
# Processing: N 045.203657
# After HTML replacement: N 045.203657
# Processing: W 085.391118
# After HTML replacement: W 085.391118
# Processing: W 085.301208
# After HTML replacement: W 085.301208
# Processing: N 045.29341
# After HTML replacement: N 045.29341
# Processing: N 045.206907
# After HTML replacement: N 045.206907
# Processing: W 085.223687
# After HTML replacement: W 085.223687
# Processing: W 085.098477
# After HTML replacement: W 085.098477
# Processing: N 045.205848
# After HTML replacement: N 045.205848
# Processing: N 045.117779
# After HTML replacement: N 045.117779
# Processing: W 085.099315
# After HTML replacement: W 085.099315
# Processing: W 084.977782
# After HTML replacement: W 084.977782
# Processing: N 045.204927
# After HTML replacement: N 045.204927
# Processing: N 045.117923
# After HTML replacement: N 045.117923
# Processing: W 085.599704
# After HTML replacement: W 085.599704
# Processing: W 085.48667
# After HTML replacement: W 085.48667
# Processing: N 045.571551
# After HTML replacement: N 045.571551
# Processing: N 045.63063
# After HTML replacement: N 045.63063
# Processing: W 085.599068
# After HTML replacement: W 085.599068
# Processing: W 085.598814
# After HTML replacement: W 085.598814
# Processing: N 045.690523
# After HTML replacement: N 045.690523
# Processing: N 045.690643
# After HTML replacement: N 045.690643
# Processing: W 86°13ʹ31ʺ
# After HTML replacement: W 86°13'31"
# Extracted numbers: [86.0, 13.0, 31.0]
# Processing: W 85°45ʹ33ʺ
# After HTML replacement: W 85°45'33"
# Extracted numbers: [85.0, 45.0, 33.0]
# Processing: N 42°04ʹ17ʺ
# After HTML replacement: N 42°04'17"
# Extracted numbers: [42.0, 4.0, 17.0]
# Processing: N 41°45ʹ32ʺ
# After HTML replacement: N 41°45'32"
# Extracted numbers: [41.0, 45.0, 32.0]
# Processing: W 085.695609
# After HTML replacement: W 085.695609
# Processing: W 085.683931
# After HTML replacement: W 085.683931
# Processing: N 045.769894
# After HTML replacement: N 045.769894
# Processing: N 045.775891
# After HTML replacement: N 045.775891
# Processing: W 085.473604
# After HTML replacement: W 085.473604
# Processing: W 085.473393
# After HTML replacement: W 085.473393
# Processing: N 045.777728
# After HTML replacement: N 045.777728
# Processing: N 045.778969
# After HTML replacement: N 045.778969
# Processing: W 085.23792
# After HTML replacement: W 085.23792
# Processing: W 085.096007
# After HTML replacement: W 085.096007
# Processing: N 045.373532
# After HTML replacement: N 045.373532
# Processing: N 045.261653
# After HTML replacement: N 045.261653
# Processing: W 86°03ʹ
# After HTML replacement: W 86°03'
# Extracted numbers: [86.0, 3.0]
# Processing: W 85°40ʹ
# After HTML replacement: W 85°40'
# Extracted numbers: [85.0, 40.0]
# Processing: N 41°46ʹ
# After HTML replacement: N 41°46'
# Extracted numbers: [41.0, 46.0]
# Processing: N 41°26ʹ
# After HTML replacement: N 41°26'
# Extracted numbers: [41.0, 26.0]
# Processing: W 085.8245
# After HTML replacement: W 085.8245
# Processing: W 086.0023
# After HTML replacement: W 086.0023
# Processing: N 041.6874
# After HTML replacement: N 041.6874
# Processing: N 041.6081
# After HTML replacement: N 041.6081
# Processing: W 085.6939
# After HTML replacement: W 085.6939
# Processing: W 085.6526
# After HTML replacement: W 085.6526
# Processing: N 041.6091
# After HTML replacement: N 041.6091
# Processing: N 041.5224
# After HTML replacement: N 041.5224
# Processing: W 086.06245
# After HTML replacement: W 086.06245
# Processing: W 085.9022
# After HTML replacement: W 085.9022
# Processing: N 041.5224
# After HTML replacement: N 041.5224
# Processing: N 041.4362
# After HTML replacement: N 041.4362
# Processing: W 085.7703
# After HTML replacement: W 085.7703
# Processing: W 085.6651
# After HTML replacement: W 085.6651
# Processing: N 041.6091
# After HTML replacement: N 041.6091
# Processing: N 041.5224
# After HTML replacement: N 041.5224
# Processing: W 086.0041
# After HTML replacement: W 086.0041
# Processing: W 085.8685
# After HTML replacement: W 085.8685
# Processing: N 041.7056
# After HTML replacement: N 041.7056
# Processing: N 041.6085
# After HTML replacement: N 041.6085
# Processing: W 085.8856
# After HTML replacement: W 085.8856
# Processing: W 085.7706
# After HTML replacement: W 085.7706
# Processing: N 041.6083
# After HTML replacement: N 041.6083
# Processing: N 041.5220
# After HTML replacement: N 041.5220
# Processing: W 085.791753
# After HTML replacement: W 085.791753
# Processing: W 085.790597
# After HTML replacement: W 085.790597
# Processing: N 041.759483
# After HTML replacement: N 041.759483
# Processing: N 041.761236
# After HTML replacement: N 041.761236
# Processing: W 086.0012
# After HTML replacement: W 086.0012
# Processing: W 085.8858
# After HTML replacement: W 085.8858
# Processing: N 041.6081
# After HTML replacement: N 041.6081
# Processing: N 041.5218
# After HTML replacement: N 041.5218
# Processing: W 085.8856
# After HTML replacement: W 085.8856
# Processing: W 085.7686
# After HTML replacement: W 085.7686
# Processing: N 041.5220
# After HTML replacement: N 041.5220
# Processing: N 041.4342
# After HTML replacement: N 041.4342
# Processing: W 085.8876
# After HTML replacement: W 085.8876
# Processing: W 085.7722
# After HTML replacement: W 085.7722
# Processing: N 041.6955
# After HTML replacement: N 041.6955
# Processing: N 041.6082
# After HTML replacement: N 041.6082
# Processing: W 085.8083
# After HTML replacement: W 085.8083
# Processing: W 085.0003
# After HTML replacement: W 085.0003
# Processing: N 041.5220
# After HTML replacement: N 041.5220
# Processing: N 041.4342
# After HTML replacement: N 041.4342
# Processing: W 085.7718
# After HTML replacement: W 085.7718
# Processing: W 085.6571
# After HTML replacement: W 085.6571
# Processing: N 041.6951
# After HTML replacement: N 041.6951
# Processing: N 041.6078
# After HTML replacement: N 041.6078
# Processing: W 086.0588
# After HTML replacement: W 086.0588
# Processing: W 086.0016
# After HTML replacement: W 086.0016
# Processing: N 041.6083
# After HTML replacement: N 041.6083
# Processing: N 041.5211
# After HTML replacement: N 041.5211
# Processing: W 086.0041
# After HTML replacement: W 086.0041
# Processing: W 085.8885
# After HTML replacement: W 085.8885
# Processing: N 041.7025
# After HTML replacement: N 041.7025
# Processing: N 041.6943
# After HTML replacement: N 041.6943
# Processing: W 086.0010
# After HTML replacement: W 086.0010
# Processing: W 085.8846
# After HTML replacement: W 085.8846
# Processing: N 041.5220
# After HTML replacement: N 041.5220
# Processing: N 041.4342
# After HTML replacement: N 041.4342
# Processing: W 085.8883
# After HTML replacement: W 085.8883
# Processing: W 085.8847
# After HTML replacement: W 085.8847
# Processing: N 041.7585
# After HTML replacement: N 041.7585
# Processing: N 041.6950
# After HTML replacement: N 041.6950
# Processing: W 085.7735
# After HTML replacement: W 085.7735
# Processing: W 085.6582
# After HTML replacement: W 085.6582
# Processing: N 041.7586
# After HTML replacement: N 041.7586
# Processing: N 041.6959
# After HTML replacement: N 041.6959
# Processing: W 085.791753
# After HTML replacement: W 085.791753
# Processing: W 085.790597
# After HTML replacement: W 085.790597
# Processing: N 041.759483
# After HTML replacement: N 041.759483
# Processing: N 041.761236
# After HTML replacement: N 041.761236
# Processing: W 84°50ʹ49ʺ
# After HTML replacement: W 84°50'49"
# Extracted numbers: [84.0, 50.0, 49.0]
# Processing: W 84°22ʹ05ʺ
# After HTML replacement: W 84°22'05"
# Extracted numbers: [84.0, 22.0, 5.0]
# Processing: N 43°27ʹ57ʺ
# After HTML replacement: N 43°27'57"
# Extracted numbers: [43.0, 27.0, 57.0]
# Processing: N 43°07ʹ01ʺ
# After HTML replacement: N 43°07'01"
# Extracted numbers: [43.0, 7.0, 1.0]
# Processing: W 85°26ʹ39ʺ
# After HTML replacement: W 85°26'39"
# Extracted numbers: [85.0, 26.0, 39.0]
# Processing: W 84°50ʹ53ʺ
# After HTML replacement: W 84°50'53"
# Extracted numbers: [84.0, 50.0, 53.0]
# Processing: N 45°12ʹ28ʺ
# After HTML replacement: N 45°12'28"
# Extracted numbers: [45.0, 12.0, 28.0]
# Processing: N 44°48ʹ51ʺ
# After HTML replacement: N 44°48'51"
# Extracted numbers: [44.0, 48.0, 51.0]
# Processing: W 84°10ʹ00ʺ
# After HTML replacement: W 84°10'00"
# Extracted numbers: [84.0, 10.0, 0.0]
# Processing: W 83°25ʹ36ʺ
# After HTML replacement: W 83°25'36"
# Extracted numbers: [83.0, 25.0, 36.0]
# Processing: N 44°09ʹ48ʺ
# After HTML replacement: N 44°09'48"
# Extracted numbers: [44.0, 9.0, 48.0]
# Processing: N 43°54ʹ37ʺ
# After HTML replacement: N 43°54'37"
# Extracted numbers: [43.0, 54.0, 37.0]
# Processing: W 85°07ʹ13ʺ
# After HTML replacement: W 85°07'13"
# Extracted numbers: [85.0, 7.0, 13.0]
# Processing: W 84°43ʹ53ʺ
# After HTML replacement: W 84°43'53"
# Extracted numbers: [84.0, 43.0, 53.0]
# Processing: N 45°47ʹ22ʺ
# After HTML replacement: N 45°47'22"
# Extracted numbers: [45.0, 47.0, 22.0]
# Processing: N 45°16ʹ12ʺ
# After HTML replacement: N 45°16'12"
# Extracted numbers: [45.0, 16.0, 12.0]
# Processing: W 86°49ʹ32ʺ
# After HTML replacement: W 86°49'32"
# Extracted numbers: [86.0, 49.0, 32.0]
# Processing: W 86°13ʹ22ʺ
# After HTML replacement: W 86°13'22"
# Extracted numbers: [86.0, 13.0, 22.0]
# Processing: N 42°14ʹ43ʺ
# After HTML replacement: N 42°14'43"
# Extracted numbers: [42.0, 14.0, 43.0]
# Processing: N 41°45ʹ34ʺ
# After HTML replacement: N 41°45'34"
# Extracted numbers: [41.0, 45.0, 34.0]
# Processing: W 84°43ʹ14ʺ
# After HTML replacement: W 84°43'14"
# Extracted numbers: [84.0, 43.0, 14.0]
# Processing: W 84°07ʹ50ʺ
# After HTML replacement: W 84°07'50"
# Extracted numbers: [84.0, 7.0, 50.0]
# Processing: N 42°25ʹ28ʺ
# After HTML replacement: N 42°25'28"
# Extracted numbers: [42.0, 25.0, 28.0]
# Processing: N 42°04ʹ13ʺ
# After HTML replacement: N 42°04'13"
# Extracted numbers: [42.0, 4.0, 13.0]
# Processing: W 85°45ʹ57ʺ
# After HTML replacement: W 85°45'57"
# Extracted numbers: [85.0, 45.0, 57.0]
# Processing: W 85°17ʹ33ʺ
# After HTML replacement: W 85°17'33"
# Extracted numbers: [85.0, 17.0, 33.0]
# Processing: N 42°25ʹ17ʺ
# After HTML replacement: N 42°25'17"
# Extracted numbers: [42.0, 25.0, 17.0]
# Processing: N 42°04ʹ11ʺ
# After HTML replacement: N 42°04'11"
# Extracted numbers: [42.0, 4.0, 11.0]
# Processing: W 85°50ʹ46ʺ
# After HTML replacement: W 85°50'46"
# Extracted numbers: [85.0, 50.0, 46.0]
# Processing: W 84°43ʹ54ʺ
# After HTML replacement: W 84°43'54"
# Extracted numbers: [84.0, 43.0, 54.0]
# Processing: N 45°50ʹ29ʺ
# After HTML replacement: N 45°50'29"
# Extracted numbers: [45.0, 50.0, 29.0]
# Processing: N 45°06ʹ56ʺ
# After HTML replacement: N 45°06'56"
# Extracted numbers: [45.0, 6.0, 56.0]
# Processing: W 84°10ʹ05ʺ
# After HTML replacement: W 84°10'05"
# Extracted numbers: [84.0, 10.0, 5.0]
# Processing: W 83°41ʹ54ʺ
# After HTML replacement: W 83°41'54"
# Extracted numbers: [83.0, 41.0, 54.0]
# Processing: N 43°59ʹ49ʺ
# After HTML replacement: N 43°59'49"
# Extracted numbers: [43.0, 59.0, 49.0]
# Processing: N 43°28ʹ43ʺ
# After HTML replacement: N 43°28'43"
# Extracted numbers: [43.0, 28.0, 43.0]
# Processing: W 84°36ʹ30ʺ
# After HTML replacement: W 84°36'30"
# Extracted numbers: [84.0, 36.0, 30.0]
# Processing: W 84°09ʹ19ʺ
# After HTML replacement: W 84°09'19"
# Extracted numbers: [84.0, 9.0, 19.0]
# Processing: N 43°49ʹ42ʺ
# After HTML replacement: N 43°49'42"
# Extracted numbers: [43.0, 49.0, 42.0]
# Processing: N 43°27ʹ56ʺ
# After HTML replacement: N 43°27'56"
# Extracted numbers: [43.0, 27.0, 56.0]
# Processing: W 085.876886
# After HTML replacement: W 085.876886
# Processing: W 085.760146
# After HTML replacement: W 085.760146
# Processing: N 041.809238
# After HTML replacement: N 041.809238
# Processing: N 041.897166
# After HTML replacement: N 041.897166
# Processing: W 84°22ʹ07ʺ
# After HTML replacement: W 84°22'07"
# Extracted numbers: [84.0, 22.0, 7.0]
# Processing: W 83°55ʹ21ʺ
# After HTML replacement: W 83°55'21"
# Extracted numbers: [83.0, 55.0, 21.0]
# Processing: N 43°07ʹ58ʺ
# After HTML replacement: N 43°07'58"
# Extracted numbers: [43.0, 7.0, 58.0]
# Processing: N 42°46ʹ20ʺ
# After HTML replacement: N 42°46'20"
# Extracted numbers: [42.0, 46.0, 20.0]
# Processing: W 83°33ʹ06ʺ
# After HTML replacement: W 83°33'06"
# Extracted numbers: [83.0, 33.0, 6.0]
# Processing: W 82°51ʹ05ʺ
# After HTML replacement: W 82°51'05"
# Extracted numbers: [82.0, 51.0, 5.0]
# Processing: N 42°27ʹ05ʺ
# After HTML replacement: N 42°27'05"
# Extracted numbers: [42.0, 27.0, 5.0]
# Processing: N 42°01ʹ40ʺ
# After HTML replacement: N 42°01'40"
# Extracted numbers: [42.0, 1.0, 40.0]
# Processing: W 84°36ʹ36ʺ
# After HTML replacement: W 84°36'36"
# Extracted numbers: [84.0, 36.0, 36.0]
# Processing: W 84°09ʹ57ʺ
# After HTML replacement: W 84°09'57"
# Extracted numbers: [84.0, 9.0, 57.0]
# Processing: N 44°09ʹ42ʺ
# After HTML replacement: N 44°09'42"
# Extracted numbers: [44.0, 9.0, 42.0]
# Processing: N 43°48ʹ48ʺ
# After HTML replacement: N 43°48'48"
# Extracted numbers: [43.0, 48.0, 48.0]
# Processing: W 83°41ʹ21ʺ
# After HTML replacement: W 83°41'21"
# Extracted numbers: [83.0, 41.0, 21.0]
# Processing: W 83°05ʹ00ʺ
# After HTML replacement: W 83°05'00"
# Extracted numbers: [83.0, 5.0, 0.0]
# Processing: N 42°53ʹ19ʺ
# After HTML replacement: N 42°53'19"
# Extracted numbers: [42.0, 53.0, 19.0]
# Processing: N 42°25ʹ52ʺ
# After HTML replacement: N 42°25'52"
# Extracted numbers: [42.0, 25.0, 52.0]
# Processing: W 84°36ʹ13ʺ
# After HTML replacement: W 84°36'13"
# Extracted numbers: [84.0, 36.0, 13.0]
# Processing: W 84°08ʹ26ʺ
# After HTML replacement: W 84°08'26"
# Extracted numbers: [84.0, 8.0, 26.0]
# Processing: N 42°46ʹ35ʺ
# After HTML replacement: N 42°46'35"
# Extracted numbers: [42.0, 46.0, 35.0]
# Processing: N 42°25ʹ17ʺ
# After HTML replacement: N 42°25'17"
# Extracted numbers: [42.0, 25.0, 17.0]
# Processing: W 85°05ʹ20ʺ
# After HTML replacement: W 85°05'20"
# Extracted numbers: [85.0, 5.0, 20.0]
# Processing: W 84°36ʹ22ʺ
# After HTML replacement: W 84°36'22"
# Extracted numbers: [84.0, 36.0, 22.0]
# Processing: N 44°09ʹ47ʺ
# After HTML replacement: N 44°09'47"
# Extracted numbers: [44.0, 9.0, 47.0]
# Processing: N 43°48ʹ44ʺ
# After HTML replacement: N 43°48'44"
# Extracted numbers: [43.0, 48.0, 44.0]
# Processing: W 85°04ʹ28ʺ
# After HTML replacement: W 85°04'28"
# Extracted numbers: [85.0, 4.0, 28.0]
# Processing: W 84°36ʹ09ʺ
# After HTML replacement: W 84°36'09"
# Extracted numbers: [84.0, 36.0, 9.0]
# Processing: N 42°46ʹ16ʺ
# After HTML replacement: N 42°46'16"
# Extracted numbers: [42.0, 46.0, 16.0]
# Processing: N 42°25ʹ15ʺ
# After HTML replacement: N 42°25'15"
# Extracted numbers: [42.0, 25.0, 15.0]
# Processing: W 85°18ʹ45ʺ
# After HTML replacement: W 85°18'45"
# Extracted numbers: [85.0, 18.0, 45.0]
# Processing: W 84°50ʹ15ʺ
# After HTML replacement: W 84°50'15"
# Extracted numbers: [84.0, 50.0, 15.0]
# Processing: N 43°07ʹ14ʺ
# After HTML replacement: N 43°07'14"
# Extracted numbers: [43.0, 7.0, 14.0]
# Processing: N 42°46ʹ09ʺ
# After HTML replacement: N 42°46'09"
# Extracted numbers: [42.0, 46.0, 9.0]
# Processing: W 84°50ʹ21ʺ
# After HTML replacement: W 84°50'21"
# Extracted numbers: [84.0, 50.0, 21.0]
# Processing: W 84°21ʹ44ʺ
# After HTML replacement: W 84°21'44"
# Extracted numbers: [84.0, 21.0, 44.0]
# Processing: N 43°07ʹ11ʺ
# After HTML replacement: N 43°07'11"
# Extracted numbers: [43.0, 7.0, 11.0]
# Processing: N 42°46ʹ10ʺ
# After HTML replacement: N 42°46'10"
# Extracted numbers: [42.0, 46.0, 10.0]
# Processing: W 87°22ʹ15ʺ
# After HTML replacement: W 87°22'15"
# Extracted numbers: [87.0, 22.0, 15.0]
# Processing: W 86°27ʹ41ʺ
# After HTML replacement: W 86°27'41"
# Extracted numbers: [86.0, 27.0, 41.0]
# Processing: N 46°09ʹ32ʺ
# After HTML replacement: N 46°09'32"
# Extracted numbers: [46.0, 9.0, 32.0]
# Processing: N 45°28ʹ38ʺ
# After HTML replacement: N 45°28'38"
# Extracted numbers: [45.0, 28.0, 38.0]

# %%
# check and correct the order of the coordinates

def correct_bounding_box(bounding_box_str):
    try:
        west, south, east, north = map(float, bounding_box_str.split(","))
        
        # Correct latitude: ensure north >= south
        if north < south:
            print(f"Swapping latitudes {south} and {north}")
            north, south = south, north
        
        # Correct longitude: ensure east >= west
        if east < west:
            print(f"Swapping longitudes {west} and {east}")
            east, west = west, east

        return f"{west},{south},{east},{north}"
    
    except Exception as e:
        print(f"Error while correcting bounding box: {e}")
        return None

# Apply the function to the "Bounding Box" column
df['Bounding Box'] = df['Extracted Bounding Box'].apply(correct_bounding_box)
# Out:
# Error while correcting bounding box: 'NoneType' object has no attribute 'split'
# Swapping latitudes 45.3773 and 45.2908
# Swapping latitudes 45.4192 and 45.376
# Swapping latitudes 45.2908 and 45.2021
# Swapping latitudes 45.2877 and 45.1988
# Swapping latitudes 45.3729 and 45.2847
# Swapping latitudes 45.4559 and 45.3675
# Swapping latitudes 45.499 and 45.4519
# Swapping latitudes 45.2847 and 45.1984
# Swapping latitudes 45.3675 and 45.2824
# Swapping latitudes 45.4519 and 45.3656
# Swapping latitudes 45.5374 and 45.4505
# Swapping latitudes 45.2825 and 45.1986
# Swapping latitudes 45.3683 and 45.2821
# Swapping latitudes 45.4518 and 45.3656
# Swapping latitudes 45.5392 and 45.4508
# Swapping latitudes 45.6263 and 45.5374
# Swapping latitudes 44.1671 and 44.0748
# Swapping latitudes 44.5988 and 44.5122
# Swapping latitudes 44.6856 and 44.5983
# Swapping latitudes 45.6306 and 45.5716
# Swapping latitudes 44.5992 and 44.5121
# Swapping latitudes 44.9506 and 44.8616
# Swapping latitudes 44.9946 and 44.9502
# Swapping latitudes 44.5995 and 44.5122
# Swapping latitudes 44.687 and 44.5992
# Swapping latitudes 44.7754 and 44.6862
# Swapping latitudes 44.6001 and 44.5127
# Swapping latitudes 45.8046 and 45.7729
# Swapping latitudes 44.6891 and 44.5995
# Swapping latitudes 44.7754 and 44.687
# Swapping latitudes 42.9824 and 42.8887
# Swapping latitudes 43.0686 and 42.976
# Swapping latitudes 43.1541 and 43.0644
# Swapping latitudes 43.2417 and 43.1519
# Swapping latitudes 43.3295 and 43.2401
# Swapping latitudes 42.976 and 42.8855
# Swapping latitudes 43.0644 and 42.9728
# Swapping latitudes 45.8044 and 45.774
# Swapping latitudes 43.1519 and 43.0608
# Swapping latitudes 43.2401 and 43.1487
# Swapping latitudes 43.3271 and 43.2376
# Swapping latitudes 42.9727 and 42.8829
# Swapping latitudes 43.0608 and 42.9705
# Swapping latitudes 43.1487 and 43.0574
# Swapping latitudes 43.2376 and 43.1453
# Swapping latitudes 43.3245 and 43.2352
# Swapping latitudes 42.9704 and 42.8804
# Swapping latitudes 43.0574 and 42.9688
# Swapping latitudes 45.7604 and 45.7172
# Swapping latitudes 43.1453 and 43.0539
# Swapping latitudes 43.2352 and 43.1434
# Swapping latitudes 41.8997 and 41.8121
# Swapping latitudes 41.9856 and 41.8987
# Swapping latitudes 42.0723 and 41.9846
# Swapping latitudes 42.1574 and 42.0715
# Swapping latitudes 42.2436 and 42.1571
# Swapping latitudes 41.8136 and 41.7601
# Swapping latitudes 41.8997 and 41.8125
# Swapping latitudes 41.9858 and 41.8993
# Swapping latitudes 42.0726 and 41.9856
# Swapping latitudes 45.6719 and 45.6261
# Swapping latitudes 42.2432 and 42.1574
# Swapping latitudes 41.813 and 41.7595
# Swapping latitudes 41.8995 and 41.8125
# Swapping latitudes 45.4651 and 45.3765
# Swapping latitudes 42.0727 and 41.9854
# Swapping latitudes 45.4651 and 45.3765
# Swapping latitudes 41.8137 and 41.7595
# Swapping latitudes 41.8997 and 41.813
# Swapping latitudes 41.8137 and 41.7597
# Error while correcting bounding box: 'NoneType' object has no attribute 'split'
# Error while correcting bounding box: 'NoneType' object has no attribute 'split'
# Error while correcting bounding box: 'NoneType' object has no attribute 'split'
# Error while correcting bounding box: 'NoneType' object has no attribute 'split'
# Error while correcting bounding box: 'NoneType' object has no attribute 'split'
# Swapping latitudes 42.5186 and 22.4284
# Swapping latitudes 42.6063 and 42.5146
# Swapping latitudes 42.6956 and 42.6022
# Swapping latitudes 42.7833 and 42.6921
# Swapping latitudes 42.5146 and 42.4252
# Swapping latitudes 42.6022 and 42.5107
# Swapping latitudes 42.6921 and 42.6003
# Swapping latitudes 42.7817 and 42.6878
# Swapping latitudes 42.5107 and 42.4239
# Swapping latitudes 42.6878 and 42.5994
# Swapping latitudes 42.7808 and 42.6854
# Swapping latitudes 42.5103 and 42.4239
# Swapping latitudes 42.5996 and 42.5098
# Swapping latitudes 42.6854 and 42.5992
# Swapping latitudes 42.7785 and 42.6851
# Swapping latitudes 43.0482 and 42.9596
# Error while correcting bounding box: 'NoneType' object has no attribute 'split'
# Swapping latitudes 43.0482 and 42.9596
# Error while correcting bounding box: 'NoneType' object has no attribute 'split'
# Error while correcting bounding box: 'NoneType' object has no attribute 'split'
# Error while correcting bounding box: 'NoneType' object has no attribute 'split'
# Error while correcting bounding box: 'NoneType' object has no attribute 'split'
# Error while correcting bounding box: 'NoneType' object has no attribute 'split'
# Error while correcting bounding box: 'NoneType' object has no attribute 'split'
# Error while correcting bounding box: 'NoneType' object has no attribute 'split'
# Error while correcting bounding box: 'NoneType' object has no attribute 'split'
# Swapping longitudes 50.0 and -169.0
# Error while correcting bounding box: 'NoneType' object has no attribute 'split'
# Error while correcting bounding box: 'NoneType' object has no attribute 'split'
# Error while correcting bounding box: 'NoneType' object has no attribute 'split'
# Error while correcting bounding box: 'NoneType' object has no attribute 'split'
# Error while correcting bounding box: 'NoneType' object has no attribute 'split'
# Error while correcting bounding box: 'NoneType' object has no attribute 'split'
# Error while correcting bounding box: 'NoneType' object has no attribute 'split'
# Error while correcting bounding box: 'NoneType' object has no attribute 'split'
# Error while correcting bounding box: 'NoneType' object has no attribute 'split'
# Error while correcting bounding box: 'NoneType' object has no attribute 'split'
# Error while correcting bounding box: 'NoneType' object has no attribute 'split'
# Error while correcting bounding box: 'NoneType' object has no attribute 'split'
# Swapping longitudes -21.0833 and -168.0333
# Error while correcting bounding box: 'NoneType' object has no attribute 'split'
# Swapping latitudes 44.6029 and 44.5131
# Swapping latitudes 44.6901 and 44.6011
# Swapping latitudes 44.6047 and 44.5148
# Swapping latitudes 44.6918 and 44.6029
# Swapping latitudes 44.7783 and 44.6901
# Swapping latitudes 44.6047 and 44.5179
# Swapping latitudes 44.6918 and 44.6047
# Swapping latitudes 43.6568 and 43.566
# Swapping latitudes 43.5673 and 43.5227
# Swapping latitudes 43.7014 and 43.6523
# Swapping latitudes 43.653 and 43.5653
# Swapping latitudes 43.566 and 43.5223
# Swapping latitudes 43.6423 and 43.5653
# Swapping latitudes 43.5656 and 43.4786
# Swapping latitudes 43.9979 and 43.9849
# Swapping latitudes 43.9978 and 43.9105
# Swapping latitudes 43.9978 and 43.9888
# Error while correcting bounding box: 'NoneType' object has no attribute 'split'
# Swapping latitudes 44.9453 and 44.858
# Swapping latitudes 44.946 and 44.8587
# Swapping latitudes 44.9464 and 44.8591
# Swapping latitudes 44.9464 and 44.8595
# Swapping latitudes 45.0293 and 45.0208
# Swapping latitudes 44.9172 and 44.8585
# Swapping latitudes 45.0351 and 45.0229
# Swapping latitudes 45.2071 and 45.1207
# Swapping latitudes 44.9466 and 44.8588
# Swapping latitudes 45.0326 and 44.9463
# Swapping latitudes 45.1207 and 45.0324
# Swapping latitudes 45.2071 and 45.1196
# Swapping latitudes 44.9466 and 44.8589
# Swapping latitudes 45.0323 and 44.946
# Swapping latitudes 45.1196 and 45.0317
# Swapping latitudes 45.2071 and 45.1173
# Swapping latitudes 44.946 and 44.8567
# Swapping latitudes 45.0316 and 44.9443
# Swapping latitudes 45.1176 and 45.0312
# Swapping latitudes 45.2053 and 45.1172
# Swapping latitudes 44.9443 and 44.8565
# Swapping latitudes 45.0311 and 44.9439
# Swapping latitudes 45.1176 and 45.0306
# Swapping latitudes 45.2049 and 45.116
# Error while correcting bounding box: 'NoneType' object has no attribute 'split'
# Swapping latitudes 44.8567 and 44.7693
# Swapping latitudes 44.7701 and 44.6825
# Swapping latitudes 44.6829 and 44.5954
# Swapping latitudes 44.5958 and 44.5089
# Swapping latitudes 44.8589 and 44.77
# Swapping latitudes 44.7703 and 44.6827
# Swapping latitudes 44.6829 and 44.5958
# Swapping latitudes 44.5964 and 44.51
# Swapping latitudes 44.8595 and 44.7703
# Swapping latitudes 44.7709 and 44.6828
# Swapping latitudes 44.684 and 44.5961
# Swapping latitudes 44.5975 and 44.5109
# Swapping latitudes 44.8595 and 44.7709
# Swapping latitudes 44.7714 and 44.684
# Swapping latitudes 44.5981 and 44.5114
# Swapping latitudes 44.8588 and 44.7714
# Swapping latitudes 45.7224 and 45.7061
# Swapping latitudes 45.8967 and 45.8093
# Swapping latitudes 45.9842 and 45.8963
# Swapping latitudes 46.0714 and 45.9835
# Swapping latitudes 46.1588 and 46.071
# Swapping latitudes 45.6352 and 45.6002
# Swapping latitudes 45.6352 and 45.6002
# Swapping latitudes 45.7224 and 45.635
# Swapping latitudes 45.7838 and 45.7222
# Swapping latitudes 45.8969 and 45.8327
# Swapping latitudes 45.9845 and 45.8967
# Swapping latitudes 46.0717 and 45.9838
# Swapping latitudes 46.1587 and 46.0712
# Error while correcting bounding box: 'NoneType' object has no attribute 'split'
# Swapping latitudes 45.8104 and 45.7508
# Swapping latitudes 45.8975 and 45.8102
# Swapping latitudes 45.9844 and 45.897
# Swapping latitudes 46.0717 and 45.984
# Swapping latitudes 46.1588 and 46.0715
# Swapping latitudes 45.7232 and 45.6845
# Swapping latitudes 45.8105 and 45.7227
# Swapping latitudes 45.8977 and 45.8101
# Swapping latitudes 45.9853 and 45.8975
# Swapping latitudes 46.0718 and 45.9843
# Swapping latitudes 46.1589 and 46.0716
# Swapping latitudes 45.87 and 45.8101
# Swapping latitudes 45.9855 and 45.8979
# Swapping latitudes 46.0724 and 45.9853
# Swapping latitudes 46.1591 and 46.0716
# Swapping latitudes 45.7229 and 45.6675
# Swapping latitudes 45.8102 and 45.7228
# Swapping latitudes 45.8983 and 45.8114
# Swapping latitudes 45.9854 and 45.8982
# Swapping latitudes 46.072 and 45.9851
# Swapping latitudes 46.1592 and 46.0718
# Swapping latitudes 45.6369 and 45.6255
# Swapping latitudes 45.7252 and 45.6369
# Swapping latitudes 45.8122 and 45.7241
# Swapping latitudes 45.8987 and 45.8113
# Swapping latitudes 45.9853 and 45.8984
# Error while correcting bounding box: 'NoneType' object has no attribute 'split'
# Error while correcting bounding box: 'NoneType' object has no attribute 'split'
# Error while correcting bounding box: 'NoneType' object has no attribute 'split'
# Error while correcting bounding box: 'NoneType' object has no attribute 'split'
# Swapping latitudes 41.8114 and 41.724
# Swapping latitudes 41.811 and 41.7235
# Error while correcting bounding box: 'NoneType' object has no attribute 'split'
# Error while correcting bounding box: 'NoneType' object has no attribute 'split'
# Error while correcting bounding box: 'NoneType' object has no attribute 'split'
# Error while correcting bounding box: 'NoneType' object has no attribute 'split'
# Error while correcting bounding box: 'NoneType' object has no attribute 'split'
# Swapping latitudes 41.8114 and 41.724
# Swapping latitudes 41.811 and 41.7235
# Error while correcting bounding box: 'NoneType' object has no attribute 'split'
# Error while correcting bounding box: 'NoneType' object has no attribute 'split'
# Error while correcting bounding box: 'NoneType' object has no attribute 'split'
# Error while correcting bounding box: 'NoneType' object has no attribute 'split'
# Error while correcting bounding box: 'NoneType' object has no attribute 'split'
# Error while correcting bounding box: 'NoneType' object has no attribute 'split'
# Error while correcting bounding box: 'NoneType' object has no attribute 'split'
# Error while correcting bounding box: 'NoneType' object has no attribute 'split'
# Error while correcting bounding box: 'NoneType' object has no attribute 'split'
# Error while correcting bounding box: 'NoneType' object has no attribute 'split'
# Swapping latitudes 44.7728 and 44.6848
# Swapping latitudes 42.9414 and 42.8545
# Swapping latitudes 42.9434 and 42.8549
# Swapping latitudes 42.9434 and 42.8549
# Swapping latitudes 41.908 and 41.8192
# Swapping latitudes 41.9951 and 41.9063
# Swapping latitudes 42.0825 and 41.9934
# Swapping latitudes 41.8192 and 41.7284
# Swapping latitudes 41.9063 and 41.8174
# Swapping latitudes 42.0804 and 41.9911
# Error while correcting bounding box: 'NoneType' object has no attribute 'split'
# Error while correcting bounding box: 'NoneType' object has no attribute 'split'
# Error while correcting bounding box: 'NoneType' object has no attribute 'split'
# Error while correcting bounding box: 'NoneType' object has no attribute 'split'
# Swapping latitudes 42.5403 and 42.4501
# Swapping latitudes 42.5385 and 42.4474
# Error while correcting bounding box: 'NoneType' object has no attribute 'split'
# Swapping latitudes 42.6274 and 42.5349
# Swapping latitudes 44.2629 and 44.1716
# Swapping latitudes 43.555 and 43.4668
# Swapping latitudes 43.6416 and 43.5536
# Swapping latitudes 46.506 and 46.4194
# Swapping latitudes 46.5931 and 46.5059
# Swapping latitudes 46.5925 and 46.5058
# Error while correcting bounding box: 'NoneType' object has no attribute 'split'
# Swapping latitudes 46.6795 and 46.5924
# Swapping latitudes 46.7649 and 46.6797
# Swapping latitudes 46.8517 and 46.7648
# Swapping latitudes 46.8516 and 46.7647
# Swapping latitudes 46.9386 and 46.8515
# Swapping latitudes 43.0303 and 42.9426
# Swapping latitudes 45.9837 and 45.896
# Swapping latitudes 46.071 and 45.9837
# Swapping latitudes 46.1583 and 46.0709
# Swapping latitudes 46.2451 and 46.158
# Swapping latitudes 46.2458 and 46.1581
# Error while correcting bounding box: 'NoneType' object has no attribute 'split'
# Error while correcting bounding box: 'NoneType' object has no attribute 'split'
# Error while correcting bounding box: 'NoneType' object has no attribute 'split'
# Error while correcting bounding box: 'NoneType' object has no attribute 'split'
# Error while correcting bounding box: 'NoneType' object has no attribute 'split'
# Error while correcting bounding box: 'NoneType' object has no attribute 'split'
# Swapping latitudes 43.5172 and 43.4283
# Error while correcting bounding box: 'NoneType' object has no attribute 'split'
# Error while correcting bounding box: 'NoneType' object has no attribute 'split'
# Error while correcting bounding box: 'NoneType' object has no attribute 'split'
# Error while correcting bounding box: 'NoneType' object has no attribute 'split'
# Error while correcting bounding box: 'NoneType' object has no attribute 'split'
# Error while correcting bounding box: 'NoneType' object has no attribute 'split'
# Error while correcting bounding box: 'NoneType' object has no attribute 'split'
# Swapping latitudes 45.8046 and 45.7729
# Swapping latitudes 45.2916 and 45.2719
# Swapping latitudes 45.6306 and 45.5716
# Swapping latitudes 45.6906 and 45.6905
# Swapping latitudes 45.7759 and 45.7699
# Swapping latitudes 45.779 and 45.7777
# Swapping longitudes -85.8245 and -86.0023
# Swapping latitudes 41.7612 and 41.7595
# Swapping latitudes 41.7612 and 41.7595
# Swapping latitudes 41.8972 and 41.8092

# %%
df['number'] = df['Identifier'].str.split('_').str[-1]
df['ID'] = df['Ark'].apply(lambda x: "ark-" + "-".join(x.split("/")[4:6]))
df['Identifier'] = df['Identifier'] + "|" + df['Ark']

# %%
def populate_parent_id(df):
    # Create a dictionary mapping 'number' to 'ID' for parent records
    parent_dict = df[df['additional_setSpec'].isna()].set_index('number')['ID'].to_dict()
    
    # Initialize the new 'Is Part Of' column to None
    df['Is Part Of'] = None
    
    # Function to map 'additional_setSpec' to parent 'ID'
    def map_to_parent_id(row):
        if pd.notna(row['additional_setSpec']):
            # Extract the digits at the end of 'additional_setSpec'
            number = row['additional_setSpec'].split('_')[-1]
            
            # Map to parent 'ID' using the dictionary
            return parent_dict.get(number, None)
        return None
    
    # Apply the function to populate 'Is Part Of' column
    df['Is Part Of'] = df.apply(map_to_parent_id, axis=1)
    
populate_parent_id(df)

# %%
# Function to append "06d-01" to existing values in "Is Part Of" column
def append_value(row):
    existing_value = row['Is Part Of']
    if pd.isna(existing_value):
        return "06d-01"
    else:
        return f"{existing_value}|06d-01"

# Apply the function to the "Is Part Of" column
df['Is Part Of'] = df.apply(append_value, axis=1)

# %%
df['Resource Class'] = "Maps"
df['Date Accessioned'] = action_date
df['Code'] = "06d-01"
# df['Is Part Of'] = "06d-01"
df['Member Of'] = "dc8c18df-7d64-4ff4-a754-d18d0891187d"
df['Accrual Method'] = "MODS"
df['Access Rights'] = "Public"
df['Provider'] = "Michigan State University"
df['Information'] = "https://d.lib.msu.edu/maps/" + df['number']
df['Manifest'] = "https://d.lib.msu.edu/maps/" + df['number'] + "/manifest"

# %%
df.to_csv(csv_file, index=False)
